# %% [markdown]
# # 멋진 단어사전 만들기 [프로젝트]
# - 1. SentencePiece를 이용하여 모델을 만들기까지의 과정이 정상적으로 진행되었는가?
# - 2. SentencePiece를 통해 만든 Tokenizer가 자연어처리 모델과 결합하여 동작하는가?
# - 3. SentencePiece의 성능을 다각도로 비교분석하였는가?
#
# ---
#
# 본 프로젝트는 한국어 형태소 분석기인 konlpy(okt, hannamum, komoran, mecab)과 sentencepice로 생성하여 토큰화한 사전과의 성능차이를 비교하고자 함

# %%
from konlpy.tag import Mecab
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

path_to_file = os.getenv('HOME')+'/aiffel/sp_tokenizer/data/korean-english-park.train.ko'
with open(path_to_file, "r") as f:
    raw = f.read().splitlines()

cleaned_corpus = list(set(raw))  # set를 사용해서 중복을 제거합니다.

max_len = 150
min_len = 10
filtered_corpus = [s for s in cleaned_corpus if (len(s) < max_len) & (len(s) >= min_len)]
# Out:
# ['즉, 값싸고, 사용하기 쉽고, 실제로 해독이 불가능한 암호화가 그것이다.',
#  '티베트 망명정부는 경찰의 진압과정에서 모두 80명이 사망했다고 밝혔으나 국영 신화통신은 13명이 사망했다고 보도했다.',
#  '유엔은 1987년 세계 환경보호가 500인 중 1명으로 힐러리경을 선정했으며 그는 세계 여러 대학에서 명예박사학위를 받았다.',
#  '이 영화는 오는 5월 18일 극장에서 개봉한다.',
#  '한편 경찰은 공항 인근서 시위를 벌인 샤리프 지지자 635명을 최루탄과 경찰봉을 이용, 체포했다.',
#  '호주 올디너리지수는 0.09% 하락했다.',
#  '심슨의 무장 강도 및 납치 사건이 라스베가스에서 마무리 단계에 접어들었습니다.',
#  '미국,일본, 유럽 상공회의소 대표들도 이번 회담을 성원했다.',
#  '현재 북한은 지난 2월 취임한 이 대통령의 대북정책에 강하게 반발하고 있다.',
#  '워싱턴에서 에드 도나휴였습니다.”',
#  '윌리엄스는 또 “2008년에는 더 좋은 모습으로 팬들 앞에 서겠다”고 덧붙였다.',
#  '이번 결정은 디트로이트가 16경기 시즌에서 단 1승도 못 올리는 최초의 NFL 팀이 된 지 하루 만에 나온 것입니다. 월가 소식입니다.',
#  '마몬홀딩스는 하야트 호텔 체인을 설립한 프리츠커 가문이 소유하고 있었다.',
#  '이후 4개월 간의 시험 이후 KT는 국방부와 협력, 개발한 이 위성을 통해 서비스를 제공하게 된다.',
#  '그는 “클린턴은 니거(nigger_흑인을 비하하는 표현)라고 불린 적이 없다”고 덧붙였다.',
#  '정부가 일주일전 발표한 집계보다 실종자 수가 1만7427명에서 1000명이상 증가했다.',
#  '허커비는 “누군가가 1191명의 대의원을 확보하기 전까지는 레이스가 계속 진행 될 것”이라고 말했다.',
#  '‘정치범 지원연합’은 윈 슈위가 아웅산수치 여사가 이끄는 민족민주동맹(NLD) 소속 의원이며 사가잉의 한 수용소에서 조사를 받았다고 설명했다.',
#  '이 지역 대부분이 모네 트로이스 피톤스 국립 공원에 포함되는 곳으로 유네스코 세계 문사유산 지역이다.',
#  'legacy 유산, 유증, 업적',
#  '스콜피언스의 지도자 슬로보단 메딕을 비롯 몇 명의 대원들은 징역 20년을 선고 받았으며 유일하게 희생자들에게 총격을 가했다고 시인한 페로 페트라세빅에게는 징역 13년이 내려졌다.',
#  '하지만 시간이 지나면서 그 병균들은 내성을 키워가며 맹위를 떨쳤다.',
#  '미 국방부에 의하면 이라크와 아프가니스탄 파병군은 복무 기간이 늘어나지만 파병 기간 만료 후 본국에서 1년 동안 근무할 수 있는 혜택이 주어진다.',
#  '직장 생활을 하는 전문직 여성들은 많은 면에 있어서 힘들기는 하지만, 이해 관계를 떨쳐 버리고 완전히 다른 일을 시도하는 데에는 남자들 보다 자유롭다.',
#  '펠레그리노(33)는 그와 파트너 숀 코헨이 인터넷 데이트 알선 사이트가 용감하고 필사적인 사람들을 끌어들이고 있지만 이들에게 특별한 매력이 없을 수 있다는 문제점을 인식하고 이 사이트를 만들었다라고 말했다.',
#  '이 두 전직 최고 경영자들은 엔론의 파산과 관련, 34개의 혐의를 받고 있었다.',
#  '산리오가 1974년 디자인한 헬로키티는 비닐 동전 지갑에 처음 등장했다.',
#  'South and North Korea had a summit anniversary event.남북 합동 행사 개최',
#  '노 대통령은 한나라당 후보들에 대한 부정적 발언으로 선거 경쟁에 영향을 미치려고 하는데, 이는 선거법 위반이다”라고 주장했다.',
#  '세게 (공식적으로) 비난하다 (=criticize somebody severely; 이 결의안은 북한정부가 사상 및 집회의 자유와 여권(女權)을 엄격히 제한할 뿐 아니라 죄수를 고문하고 공개 처형하며, 국내에서와 국경을 넘는 이전의 자유를 제한하고 있다고 비난했다.',
#  '유럽증시도 연방준비제도이사회의 이자율 인하를 기대하면서 대부분 상승세를 보였습니다.',
#  'Bad loan at domestic lender had shrunk in second quarter.2분기 부실 채권 비율 감소2005.08 원문 & 독해설명 인쇄',
#  '사르코지는 지난해 말 이집트 유적지를 돌아보는 등 공개적으로 데이트를 즐겼지만 결혼식은 조용하게 치렀다.',
#  '그러나 야누코비치가 속한 당이 총선에서 다수의석을 차지하면서 그는 지난해 총리로 정계에 복귀했다.',
#  '익명이 보장되는 ETC를 실현하기 위한 기술은 이미 존재하고 있다.',
#  '화재 사고 목격자인 홀은 “사람들이 동시 에 서둘러 대피하기 시작했고 응급상황이라고 생각하지 못한 사람도 있었으며 무슨 일이 벌어졌는지 실감하지 못한 사람도 있었다”고 말했다.',
#  "“어린이들이 'E' 단어를 듣고 있지만, 이는 '팔꿈치(Elbow)'의 E가 아니라 '경제(Economy)'의 E입니다.”",
#  '이로써 아시아의 4번째 경제대국인 우리나라가 정부에서 목표로 삼은 4~5%의 잠재 성장률을 달성할 가능성이 커졌다.',
#  '리처드슨 주지사, 상무장관직 사임',
#  '프란시스 베르메이렌 자벤텀 시장은 화물운송기가 이륙을 시도하자마자 추락했을 때 화재가 발생하지 않았다고 설명했다.',
#  '목격자들은 축출된 장 베르트랑 아리스티드 전 대통령의 지지자들로 보이는 무장 세력이 가두 행진 중인 시위대를 향해 총격을 퍼붓기 시작했다고 전했다.',
#  '이번 금지 조치가 “오키나와에서 복무하고 있는 모든 미군 병사들의 군기와 행실을 지배하는 절차와 명령들을 심도 있게 검토하는 기회를” 병사들에게 줄 것이라고, 이 명령에는 언급되어 있었다.',
#  '그러나 분석가들은 국제 사회에서 고립되어 있는 북한이 UN 안보리 회부나 북한 핵 시설에 대한 미국의 선제 공격 가능성 등의 위험 요소를 감안하여 언제 실험에 착수하게 될 지에 대해서는 의견을 모으지 못했다.',
#  '이들 "영상물 공급자들"은 신기술의 효과가 입증되기 전까지는 수지맞는 테이프 대여나 판매 시장을 잠식하거나, 아니면 DVD 영화에 많은 돈을 지출하기를 원치 않을 것이다.',
#  '시위대의 항복 시한은 지났으나, 많은 수의 경찰이 지역 수도의 거리를 순찰하고 있다.',
#  '과기부 관계자는 이번 사찰단이 이전에 이미 조사했던 사항을 재검하고 확인하게 될 것이라고 밝혔다.',
#  '신화통신은 2007년 관광객들이 같은 기간에 64억2000위안을 지출했다고 보도했다.',
#  '세스 쇼스탁 SETI 대변인은 “오래된 행성이기 때문에 뭔가 영리한 것이 이곳에 살 가능이 높아 보인다”고 설명했다.',
#  '이민국은 그를 석방했지만 곧 추방절차를 밟았다.',
#  '정부가 가능한 법적 처벌과 학교 이사장에 대한 불법 행위 여부를 조사할 것이라며 강력하게 대응함에따라 전국의 사립 학교들이 신입생 배정 거부 방침을 철회했다.',
#  'AIG bonus payments $218 millionAIG 상여금 2억1800만 달러에 이르러2009.06',
#  '손이 차면 마음이 따뜻하다?',
#  '미얀마 정부는 사이클론 ‘나르기스’가 2일과 3일 미얀마 중남부 지역을 강타해 2만2000명 이상이 숨졌다고 발표했으나 미얀마 주재 미국 대사는 사이클론 사망자가 10만 명을 넘을 수도 있다고 말했다.',
#  '터키 군은 자신들을 세속주의의 보호세력이라고 지칭하고 있다. 터키군은 지난 60년 이후 4번의 쿠데타를 일으킨 뒤 권력을 민정에 이양했다.',
#  '오바마의 대변인인 빌 버튼은 26일 “클린턴 선거캠프는 경선에서 승리하기 위해 모든 수단을 다 동원하겠다는 의도를 내비쳤다”고 밝혔다.',
#  'NTS imposes surcharge on foreign funds for their tax evasion.국세청, 탈세 외국계 펀드에 탈루 세금 추징',
#  '그러면 우리는 그 고통을 끝낼 수 있을지도 모른다는 것입니다 그리고 고통을 끝내는 것은 양측 모두에게 좋은 것일 겁니다.',
#  '이와 관련 이스라엘 국방부는 성명에서 가방을 들고 이스라엘군 병사쪽으로 향하던 팔레스타인 2명을 목표물로 삼았다고 설명했다.',
#  '클린턴은 민주당 대선 후보를 선택할 대표단을 뽑는 주 선거에서 그녀의 라이벌 뒤를 쫓아왔다.',
#  '유럽에선 프랑스 파리가 초고층 빌딩 혁명을 이끌고 있다.',
#  '당장 요구되는 경제적 생존과 환경보호를 위한 보다 장기적인 필요성 사이 에서 균형을 이루어야 할 필요가 있습니다."',
#  '북한 대변인은 이날 성명에서 “미국의 조치로 우리도 ‘행동 대 행동’원칙에서 영변핵시설의 무력화(불능화)를 재개하며 미국과 국제원자력기구 감시 성원들의 임무 수행을 다시 허용키로 했다”고 밝혔다.',
#  '그는 "제작자측은 이렇게 진전되면 다른 문제가 야기될 수 있으며 DVD와 인터넷과 관련된 추가 수익금 지급은 말이 안 된다”고 말했다.',
#  '시장 사무실은 도심을 지나가는 시민들에게 대중 교통을 이용하도록 권고했다.',
#  '감독으로서 호평을 받은 클린트 이스트우드 감독의 최신작 영화 ‘그랜 토리노(Gran Torino)’는 클린트 이스트우드 감독이 공동작사한 영화음악만 후보로 올라갔다.',
#  '예산은 3조 달러가 넘는 금액으로, 3뒤에 0이 12개나 붙으며, 여기에는 인디애나 주의 마이크 펜스 하원의원과 같은 공화당 소속 국회의원들에게는 너무나도 과도한 적자 재정이 포함되어 있습니다.',
#  '한국의 수출이 3월까지 연속해서 13개월 동안 감소했으나, 연중 가장 적은 폭의 감소였으며, 그로인해 빠르면 4월에 추세가 전환될 수 있다는 희망을 돋우어 주었다. 한국은 탄력 있는 국내 소비 때문에 아시아에서 전망이 밝은 몇몇 지역 중의 하나가 되었다.',
#  '칼라 레지나 피나코테카 도 에스타도 미술관 대변인은 이번 강도들이 유명한 브라질의 미술가 에밀리오 디카발 칸티와 라자르 세갈의 유화 2점도 훔쳤다고 전했다.',
#  '존 에드워즈 전 상원의원도 사우스캐롤라이나 예비선거의 승리를 따내 만능 3위의 이미지에서 탈피한다는 계산이다.',
#  '잠시디 대변인은 “그러나 이 법안이 의회 승인을 거쳐 법이 될 때까지 법원은 법원장의 권고안에 주의를 기울이지 않아도 되는 자주성을 갖고 있다”고 말했다.',
#  '연장된 배치 규정은 현재 이라크에 주둔중인 부대 및 앞으로 배치될 부대에 적용된다.',
#  '목격자들은 WKYC 방송에 출연해 범인인 학생이 주 초 폭행혐의로 정학처분을 받았다고 말했다.',
#  '정부, 독도 문제에 대한 태도 바꾼다.',
#  '로케의 이번 발언은 올림픽을 둘러싼 정치적인 움직임에 대해 가장 강력한 메시지로 그도 최근 사태의 심각성을 인식한 것으로 보인다.',
#  '“만약 일치가 이기심을 누르지 못하고, 사람들이 계속해서 자신의 잇속만을 챙긴다면 그는 세계가 분열되고 말 것이라고 말했습니다.”',
#  '이제, 여러분들은 이베이에서 상아 관련제품을 더 이상 살 수 없게 됩니다.',
#  'Senate demands on withdrawal of US troops from Iraq미 상원, 이라크 주둔 미군 철수 찬성2007.07',
#  '범유럽 FTS Eurofirst300 지수는 2% 하락하며 1,462.64를 기록했다.',
#  '주요 니케이 225 평균 지수가 거의 19년 동안 나타나지 않았던 수준으로 급락하면서 일본의 주식 시장이 혼란에 빠졌다.',
#  '미국과 북한의 상대 비방 발언 점차 심해져\xa0 \xa0 \xa0',
#  'AP의 아론 헬러 기자가 예루살렘에서 보도합니다.',
#  '차타흐는 레바논 보안군이 무장대원을 목표로 할 것이며 난민촌에서 무작위로 총격을 가하지 않을 것이라고 전했다.',
#  '반면 줄리아니는 여성, 북동부 및 중서부 지역의 유권자, 50대 이하의 보수층 무신론자들로부터 인기가 높았다.',
#  '지앙 유 중국 외교부 대변인은 "몇몇 사람들이 중국을 비난하기 위해 근거 없는 소문을 만들고 있다"고 밝혔다.',
#  '생부를 만난 이 날 도슨은 아버지에게 미국 국가대표 스키팀 로고가 새겨진 스웨터를 선물했으며 미국으로 돌아가기 전 가족과 많은 시간을 보내고 홀트 아동복지회도 방문할 예정이라고 전했다.',
#  '이 장관은 남북한이 협력, 6개국이 각자의 책임을 다할 것을 확실히 하는 것이 중요하다고 말했다.',
#  '성명을 통해 반란군은 “너희들과 우리의 싸움은 장기전이 될 것”이라고 전했다.',
#  '[[engineer]] 솜씨 있게 처리하다, 공작',
#  'universal health coverage 전국민 의료보험, 전 국민을 대상으로 한 통합 의료보험 제도, 기본적인 보건의료서비스',
#  '어린이들은 지난해 10월부터 차드 동부 아베체에 위치한 고아원에서 생활하고 있다.',
#  '신문은 그는 인터넷으로 너무 많은 시간을 보내 과로로 사망했을 가능이 있다고 보도했다.',
#  '그는 또 위엄 유지의 중요성을 강조했다.',
#  'health care 건강 관리의, 의료의',
#  '지난 겨울에는 브루셀라에 감염된 들소만 도살됐다.',
#  '그러나 이번 소동으로 여러 항공기의 출발이 지연됐고 몇 시간 동안 활주로가 폐쇄됐다고 애이런 애로라 공항 대변인이 밝혔다.',
#  '그는 “차 밑 에 깔려 잘려나가 살과 피부밖에 없는 다리를 봤다"며 "피가 흐르는 다리를 잡고 있었다”고 말했다.',
#  '미국과 이스라엘은 하마스를 테러 단체로 간주, 하마스 집권 이후 팔레스타인에 대한 지원을 중단하고 있다.',
#  '에탄올 개발에 합의하다',
#  '올해 34세인 하산우딘은 자카르타 법원에서 자신은 참수를 도왔지만, 주모자로 이를 지휘했다는 혐의는 부인했다.',
#  '일본의 과거 사죄로 한국 국민들 진정시키지 못해\xa0 \xa0 \xa0',
#  '경찰은 지난 주말 로리언에 대한 체포영장을 발부 받아 검거작전에 돌입했다.',
#  '알카에다는 5일까지 미군의 폭격으로 지난 2006년 6월 사망한 이라크 내 알카에다 지도자 아부 무사브 알-자르카위의 메시지 등 8편의 영상을 휴대폰 다운로드용으로 공개했다고 밝혔다.',
#  '게티 박물관은 50억달러(약 42조6345억원)의 기부금을 거둬 미국에서 가장 막강한 자금력을 갖고 있는 미술기관으로 인정받고 있다.',
#  '실종된 매들린 맥캔(4)의 부모는 딸을 찾기 위해 모금한 공적 기금을 자신들의 법적 투쟁에 필요한 자금으로 사용하지 않을 것이라고 밝혔다.',
#  '롤로프 말레르브와 샤크 반 데르 메르이는 성명을 통해 “자신들은 인종차별주의자가 아니다”며 “피해자들이 치욕이나 굴욕을 느끼게 하거나 그들의 존엄성을 해하려 했던 의도는 없었다”고 밝혔다.',
#  '이명박 대통령과 후쿠다 야스오 일본 총리는 월요일, 도쿄의 야스쿠니 신사 참배 논쟁으로 2005년 이후 중단된 두 아시아 국가 지도자들이 정기 회담을 계속하기로 하면서, 신세대 간의 교류를 확대하기로 합의했다.',
#  'The consumer confidence index plunged to its lowest in four years.소비자 만족도 4년 만에 최하 기록2005.08',
#  '한편 리비아 고위관리들은 토니 블레어 전 총리가 트리폴리를 방문했을 당시 이 문제에 대해 협의한 것으로 밝혀졌다.',
#  '한편 도메네크는 프랑스가 유로 2008 지역예선 홈경기에서 스코틀랜드에 0-1로 패한 이후 트레제게를 대표팀 명단에서 제외했다.',
#  '콘돌리자 라이스 미 국무장관은 29일(현지시간) 현 정부가 이라크 침략을 위해 조지 테닛 전(前) 미 중앙정보부(CIA)국장이 언급한 ‘슬램덩크’(Slam dunk) 라는 말을 이용한 적이 없다고 밝혔다.',
#  '하지만 미 국무부 국제안보 및 군비통제 담당 차관을 지낸 존 볼튼 전 유엔 주재 미 대사는 보도된 합의문 초안을 매우 안좋은 거래라고 밝혔다.',
#  '전미 크리스마스트리 연합은 2006년 2900만 가정이 새로운 크리스마스트리를 구매한 것으로 추산했다.',
#  '한 이슬람 무장단체가 이라크에서 실종된 미 해병을 참수하지 않았다고 주장하고 나섰다.',
#  '어제 아침 이를 보도한 세계 일보에 의하면 이 같은 노 대통령의 제안에 한국인들은 즉각적으로 부정적인 반응을 보였다.',
#  '팝스타 브리트니 스피어스측 변호인의 요청으로 미국 법원이 20일(현지시간) 브리트니 스피어스의 무면허 운전 관련 재판을 중단한다고 밝혔다.',
#  '최근 몇 달간 사망자 수가 감소 추세에 있지만 지난 봄 3개월 동안 평균 미군 사망자수가 100명을 넘기도 했다.',
#  '영국 언론매체는 해리포터의 작가 조앤 K. 롤링, 리처드 브랜슨 회장, 사이몬 코웰 판사 등이 260만 파운드(약 48억원)의 기부를 약속했다고 전했다.',
#  '기준금리 동결이 만장일치로 이뤄질 것이라는 전망이 나온 가운데 이번 통화정책회의는 2일간 진행됐다.',
#  '흄 교수는 호주 캔버라 소재 ‘오스트레일리아 아카데미 오브 사이언스(Australian Academy of Science, AAS)’에서 대기 중 이산화탄소의 증가가 유칼립투스 나뭇잎에 미치는 영향에 대한 연구 결과를 발표했다.',
#  '소아과 전문의며 \'Bady 411\'의 저자인 알리 브라운은 "당신 품에 작은 생명체인 아이를 안고 육아 책을 읽어도 어떻게 돌봐야 할 지 모르는 경우가 있다”고 말했다.',
#  '제시 잭슨 주니어 상원의원, 전 의원 후보자로 현재 로드 블라고예비치 일리노이 주지사를 보좌하고 있는 타미 덕워스 이라크 참전용사를 포함, 몇몇 일리노이주 민주당원들이 오바마를 위한 상원의원직을 승계할 유력 후임자로 언급되고 있다.',
#  '이 은행은 16일까지 긴급 금융을 끌어 들이지 않고 있다.',
#  '미국 에모리 대학교 내 마이클 C. 칼르로스 박물관이 주최하는 ‘투탕카문:',
#  '인류는 어업이 식량수급에 얼마나 많은 부분을 차지하고 있는지를 잘 알고 있다.',
#  '유네스코 세계유산목록은 역사적 리스트는 역사적이고 문화적인 유적지를 포함하지만 최근 몇 년간 유엔기구는 멸종 위기의 언어나 사라지는 전통 등 무형문화유산을 포함시키는 기록부를 만들기 시작했다.',
#  '한국, 북한, 일본, 중국, 러시아 및 미국이 참여하는 6자 회담은 북한의 핵무기 개발 분쟁을 해결하려는 취지 하에 작년 8월에 처음 개최되었다.',
#  '그러나 클린턴이 오바마보다 10명의 더 대의원을 확보한 미시간의 경우 클린턴 지지자들이 당헌당규위원회의 결정에 강한 불만을 표출하며 이에 맞서 대항할 것이라고 전했다.',
#  '전 영화배우였던 70세의 에스트라다는 2001년 대통령직에서 쫓겨나기 전에 8천만 달러(4천2백만 파운드)를 횡령한 것으로 밝혀졌다.',
#  '이와는 대조적으로 저개발지역에서의 인구는 꾸준히 늘어 2000년 49억 명에서 2050년 77억 명에 이를 것으로 예측했다.',
#  '멕시코 재벌 칼로스 슬림이 자산규모 678억달러(약62조원)로 마이크로소프트사의 빌 게이츠를 뛰어넘어 세계1위 부자로 등극했다고 멕시코 재무재산 관계자가 2일(현지시간) 발표했다.',
#  '한편 파커와 롱고리아는 지난 6월 프랑스 파리 루브르 박물관 인근 교회에서 결혼식을 올린 뒤 파리 교외 보르비콩트성에서 피로연을 열었다.',
#  'The Musical)를 관람한 후 자신들의 이름까지 기억하며 마술을 선보이는 웨이터들의 도움을 받으며 왕족 같은 저녁식사를 한다.',
#  '팔레스타인에서 공동내각을 출범한 목적은 심화되고 있는 하마스-파타간 내부분열을 진압하고 하마스 집권 이래 중단된 서방국의 지원을 다시 받기 위해서다.',
#  '이들 내용은 저명 경제학자들이 속해있는 한국경제학회가 주최하는 경제 세미나에서 경제학자들이 발표할 주제의 하나이다. 균열, 불화',
#  '야당 지도자 밋치 맥코넬은 "미군 사령관들이 바그다드에 평화를 불러오기 위한 지원을 요구한다"며 "미군 철수를 부르짖는 것은 이라크에 뿌리내린 알카에다에게 승리를 가져다줄 것"이라고 밝혔다.',
#  '파카크 소장은 이집트 문화재 당국이 이 같은 움직임으로 이집트 북부인 나일강 삼각주 동부에 더 많은 연구가 촉진되길 바라고 있다고 밝혔다.',
#  'I5 Interstate highway (주간 고속도로), 오리건주와 서부 워싱턴주를 남북으로 연결하는 주요 프리웨이',
#  '6개월동안 5번째로 경험한 10월의 한국 소비자만족도 하락은 아시아권 경제 규모 3위의 우리 나라 내수가 또 한 번 크게 하락할 조짐으로 비춰진다.',
#  '최근 레바논에서는 반 시리아 성향의 정치인을 겨냥한 폭탄테러가 연쇄적 으로 발생했다.',
#  '신혼부부는 27일 오전 구치소에서 나오면서 아무 말도 하지 않았다.',
#  '이곳은 세계 최대 투구게(Horseshoe crabs) 산란지로 유명하다.',
#  '클라렌스 미첼 맥캔 가족 대변인은 기자회견에서 “그가 어디에 사는 누군지 알고 싶다”고 밝혔다.',
#  '미시시피 관할 보안관과 군 대변인은 3일 오후 토네이도가 미시시피 남부를 강타해 군 부대 초소가 파손됐으며 이로 인해 14명이 부상했다고 전했다.',
#  '정부는 토플 및 토익과 같이 국제적으로 인정받는 시험을 대체하기 위한 목적으로 시범 영어 시험을 주관할 예정이다.',
#  'AP 라디오 뉴스입니다.',
#  '중국, 불임 수술 강요\xa0 \xa0 \xa0',
#  '한편 시카고 경찰은 실종된 허드슨의 조카에 대한 대규모 수색작전에 비행기를 동원했다.',
#  'Ted Haggard says his sexual identity cannot be put into stereotypical boxes테드 해거드, 자신의 성 정체성을 고정관념의 틀에 가둘 수 없다고 말해2009.01',
#  '쿡은 조사자들이 베이비 시터가 태만했거나 부주의했다고 결론을 내릴 경우 판결은 형사상 혐의를 배제하지 않을 것이라고 밝혔다.',
#  '그러나 미국과 북한은 이 목록에 어떤 항목을 포함시킬지 합의에 이르지 못했다.',
#  '미국 국제개발처(USAID)는 만약 세계식량계획(WFP) 관계자들이 추방되면 북한내 배급활동의 중단이 불가피할 것으로 수요일날 발표했다.',
#  '공정위는 3개 신문사의 47개 지국에 총 1억8천만 원의 과징금을 부과했다고 밝혔다.',
#  'Highest-level military generals from the two Koreas began talking남북한 장성 회담 개시2007.10 원문 & 독해설명 인쇄',
#  '그리고 동네에서 소니의 아이보보다 더 똑똑한 로봇과 함께 있는 최초의 사람이 된다는 특권을 잊지 말라.',
#  '지바에서 한 신문가판대를 운영하고 네모토 히로푸미(48)는 “아베 총리는 헌법 개정이나 교육 개혁을 주요 정책으로 삼고 있다”며 “민주당은 국민 개개인의 삶이 우선시돼야 한다고 주장하고 있으며 그 말에 동의한다”고 전했다.',
#  '태국 당국은 헬기 3대를 동원해 솜차이 총리가 안전하게 빠져 나오도록 했다.',
#  '이 프로그램으로 인해 연간 소득이 6만달러 이하인 가정의 학생들은 수업비를 내지 않아도 된다.',
#  '사람이 상어 서식지를 위협했을 때 보통 상어의 공격이 일어나며 그렇지 않으면 일어나지 않는다.',
#  '1.자신의 성과를 계속 기록하지 않는 것',
#  '22개의 소프트웨어 온라인 서비스 회사들과 출판업자들이 표준 기술을 개발 중에 있습니다 컴퓨터 통신망으로 유통되고 있는 정보를 분류하기 위한',
#  '다상(22)은 전화 인터뷰에서 “우리는 대규모 인원이 참석하는 평화로운 집회를 계획하고 있다”며 “미국은 물론 전세계적으로 많은 티베트인이 이 집회에 올 것이라고 들었다”고 설명했다.',
#  '런던석유거래소(ICE)의 북해산 브렌트유는 그리니치 표준시로 17시 32분 배럴당 1.76달러 상승, 74.81달러로 올랐으며 미국 원유 가격은 32% 인상, 배럴당 71.73달러가 됐다.',
#  '유럽 환경청은 승객용 차량과 밴이 2004년 현재 유럽 이산화 탄소 배기 가스의 14%를 구성한다고 밝혔다.',
#  '파키스탄 방송은 신드주와 발루치스탄주에서 PPP가 강세를 보였다고 보도했다.',
#  '첼시는 이날 경기를 승리할 경우 1위에 오르면서 리버풀이 2위가 될 수 있었지만 전날 런던에서 열린 아스널 원정에서 승리한 리버풀은 첼시보다 승점 1점이 앞서 1위를 지켰다.',
#  '펑크록 밴드인 카우치의 두 멤버는 생방송에서 또 다른 펑크 밴드인 럭스의 무대에 올라 춤을 추던 중 갑자기 하의를 벗어 성기를 노출했다.',
#  '그는 왜 사람들이 위원회가 불공정하다고 부르는지를 이해할 수 없다고 말했다.',
#  '존 매케인 애리조나 공화당 상원의원은 폭스 뉴스를 통해 GM과 크라이슬러가 생존할 수 있는 가장 좋은 방법은 파산신청을 통해서라고 말했습니다.',
#  '흉기로 사람을 해하는 사건이 급증하면서 안전한 도시라는 런던의 명성이 흔들리기 시작했다.',
#  '이라크 내무부는 폭탄테러 사건이 바그다드 중앙부에 위치한 만수르 지역에서 일어났다고 밝혔다.',
#  "신 오키프 항공우주국 국장은 ''우리는 국가를 위해 기도하는 자들이 그들 및 그들 가족과 함께 할 것이라고 믿는다.",
#  '브렌다 바톤 대변인은 이드리스 오스만이 23일 오전 소말리아 수도내 WFP 직원에게 인계됐다고 말했다.',
#  '김영식 교육부 차관을 단장으로 하는 범 정부 대책단은 서울 도심에 있는 정부 중앙청사에서 첫 회의를 개최할 예정이다.',
#  '전투에 스파르타군은 디지털로 재구성됐다. 영화‘300’이 개봉 첫 주 7000만달러(약 665억원)를 넘어서는 수익을 올리며 2007년 첫 블록버스터로 떠올랐다.',
#  '월요일에 유엔 원자력 감시 기구는 영변의 주 원자로 폐쇄를 논의하기 위해 다음 주 북한을 방문할 것이라고 확인했다.”',
#  'CNN의 모회사인 터너사 대변인은 총을 소지한 용의자가 결국 1996년부터 터너사 보안을 책임져온 오델 아담스 경비원의 총에 맞았다고 전했다.',
#  '마크 스미스 AP 백악관 특파원이 이에 관한 내용을 실시간으로 전해 드립니다.',
#  '37세의 범인은 오늘 아침 4시간의 대치 끝에 경찰에 투항했습니다.',
#  'conglomerate 집단, 복합 기업, 복합적인, 덩이지다, 응집하다',
#  '이와 관련 하마스의 대변인은 ‘이슬람 군대’ 조직원 2명을 체포한 사실이 있다고 전했다.',
#  '결의안에 의하면 유엔과 아프리카연합(AU)은 2만6000의 연합 병력을 구성, 다르푸르 지역에 파견하기로 했다. 이들 병력은 다르푸르에 12월 31일까지 주둔할 예정인 7000명의 AU 병력을 대체하게 된다.',
#  '미셸 오바마가 10살의 사샤를 시드웰 프렌즈 중학교로 데려다 주었으며, 7살의 말리아는 길을 따라 메릴랜드에 있는 부속 초등학교에서 새로운 학교생활을 시작합니다.',
#  '관제탑 직원들의 허술한 안전 점검과 불충분한 교육이 이날 모든 사람들을 위기로 몰아넣을 뻔 했다.',
#  '더 타임스는 ‘반지의 제왕’에 대해 경이로운 뮤지컬이었으며 아름답고 유머가 넘쳤다고 보도했다.',
#  '윕 에릭 캔터 민주당 하원의원은 미국을 빚더미에 몰아넣을 너무나도 막대한 양이 지출이 계획에 포함되어 있다고 말했습니다.',
#  '아타 장군의 참모는 “알가즐 시장에서 발생한 테러 용의자는 소위 ‘미친 여자’로 불리던 여성이었으며 두 번째 테러의 범인은 선천적 정신지체 장애우”라고 전했다.',
#  '아바스 수반은 로드맵에따라 10일 이스라엘을 방문했다. 미국은 2003년 합의한 평화협상안을 지지했다.',
#  '호나우두는 1968년 윙 선수 조지 베스트가 선정된 이후 맨체스터 유나이티드 소속 선수로서 ‘발롱도르’를 4번째 수상했다.',
#  '“자동차회사를 보유하고 있는 세계의 국가들은 자국의 자동차회사들이 위기를 극복할 수 있도록 지원하고 있는데, 이는 그들이 자동차업체가 경제, 취업, 그리고 국방에 중요하다는 것을 알고 있기 때문입니다.”',
#  '그러한 헌신으로 당신은 모든 이들에게 귀감이 됐습니다.”',
#  'Sick Hostage Sacrificed Herself for Release of Colleague˝건강 악화된 인질, 동료의 석방 위해 자기 희생˝2007.11 원문 & 독해설명 인쇄',
#  '이번 시위는 유엔창설 62주년 기념일에 맞춰 열렸다. 시위를 주도한 사람들은 유엔 안전보장이사회에 해결책 마련을 촉구하고자 이같은 시위를 활용했다고 말했다.',
#  '그러나 마을 주민들이 이 사실을 해병대에 알리면서 이에 대한 조사가 시작되었다.',
#  '미국 필라델피아 선거관리위원회 관계자들은 힐러리 클린턴 후보에게 매우 중요한 이번 예비선거가 접전을 거듭하며 매우 ‘인내’를 요하고 ‘예측불허’라고 전했다.',
#  '원문기사보기 호주 수영선수 그랜트 해켓이 10년간 석권해왔던 수영 남자 자유형 1500m 종목에서 아슬아슬하게 올림픽 3연패를 놓치고 난 후 은퇴했다.',
#  '중국 보건당국은 오염으로 인한 암 발병이 중국의 주요 사망 원인이 되고 있다고 보고했다.',
#  '실리콘 벨리 사무실 앞에는 검은 마스크와 레이저검을 들고 있는 다스베이더의 모습이 한 눈에 들어온다.',
#  '로딕은 강력한 서비스와 송곳 같은 포핸드 스트로크로 여러 차례 걸쳐 러브 게임을 따냈다.',
#  '그는 “유산 가능성의 증가가 카페인 때문인지 임산부의 음료 습관 때문인지를 중점적으로 조사할 수 있었다”며 “다른 연구에서도 같은 결과가 나왔지만 이번 조사는 습관에 관한 연구였다”고 말했다.',
#  '당나귀는 18일 게라로 베즈퀘즈(63)의 가슴을 발로 차 넘어뜨렸으며 당시 그를 구하려던 안드레스 헤르난데스(52)도 발로 차 다리 골절상을 입혔다.',
#  '코리아 타임즈는 인터넷에서 소프트웨어를 불법으로 다운로드하여 유포한 혐의로 9개 회사 직원 259명이 경찰에 불구속 입건됐다고 수요일에 보도했다.',
#  '새 교황이 선출되었다는 소식이 로마 전역으로 퍼지자 수천 명의 신도들은 성 베드로 광장에 모여 발코니로 나온 새 교황을 맞이하며 큰 소리로 환영했다.',
#  '한 교원 단체는 교육부의 이러한 방침이 위선적이며 교사의 사기를 저하할 것이라고 비난했다. 위선적인',
#  '당국은 그가 해외에서 수입한 고양이과 동물을 보호하는 팬더리지 야생동물 보호센터를 운영하고 있었다고 밝혔다.',
#  '북한과 같이 통제가 심한 국가들은 전형적으로 그러한 민감한 질문은 의식적으로 피한다.',
#  '최근 정신적 운동이 뇌에 유익할 수 있다는 증명이 정신건강 산업의 번창에 기여했다.',
#  '한편 서방 언론으로부터 독재자와 경제 파탄의 주범으로 인식되고 있는 무가베 대통령은 내년 실시되는 5년 임기의 대통령 선거에 재출마 할 뜻을 내비쳤다.',
#  '해외 거주 미국 시민은 정확히 알려지지 않았지만 해외로 파병된 수많은 군인들까지 약 400만명에서 500만명으로 추산되며 이들은 자신들의 주소지가 있는 주(州) 투표 당국에 우편을 보내 투표하는 부재자투표를 했다.',
#  '전 파나마 독재자인 노리에가(73)는 건강상 문제가 있으며 여생을 파나마에서 보내길 원하고 있다.',
#  '버지니아주 커밍에 살며 피아노와 기타, 하모니카를 연주하는 허친스는 그 당시를 회상하며 "그 일 이후 잠시 그들의 음악을 듣지 않았다"고 말했다.',
#  'Philippines marines protest Gen Marinda’s removal 마린다 사령관 해임에 해병대 반발\xa0 \xa0 \xa02006.04',
#  '일부 기업 경영 자들은 주요 금융 중심지인 홍콩에 필수적인 정보의 자유로운 유통에 대해 우려하고 있다.',
#  '미국 정부가1992년 한반도 비핵화 공동 선언을 전폭 지지한 이후 주한미군은 한반도에 핵 무기를 보유하고 있지 않다고 주한미군 최고위 관리가 재확인했다.',
#  '현오석 한국무역협회 국제무역연구원장은 어제 한국의 비싼 생활비가 외국인들의 방문을 막아, 서비스 분야 수지를 악화시키고 있다고 말했다.',
#  '카무다는 데이튼이 타이타닉과 관련된 기사나 이야기를 피했고 자신의 죽음이 언론에 공개되기 전에 장례식을 치러달라고까지 강력히 요구했다고 말했다.',
#  '“조정이 이뤄진다면 주한미군 숫자는 현재 합의된 2만5천명선 이하로의 감축이 이뤄질 것이다.”',
#  '한미 양국이 주한미군 감축에 대한 공식 협상에 들어감에따라 정부가 주요 외교 문제와 국가 안보 문제 협의를 위한 고위급 위원회를 구성했다고 국가안전보장이사회가 어제 밝혔다.',
#  '이번 주 언론의 공격 속에 케네디는 힐러리 클린턴 국무장관 내정자의 후임으로 뉴욕주 상원의원에 유력시 되는 인사들과 차별화하는데 노력해왔다.',
#  '수십명의 기자들과 카메라맨들이 경계선 부근에서 취재 활동에 열을 올린 가운데 베컴 부부는 경호원들의 보호를 받으며 SUV 차량에 올라탔다.',
#  '미국이 배포한 비디오 자료에는 목요일날 폭발 당시 유리 조각, 자갈 및 열기에 휩쓸려 안구와 안면에 입은 상처를 압박 붕대로 감싼 환자들이 누추한 병원에서 침상 하나에 두 명씩 비좁게 누워 있는 장면이 고스란히 담겨 있다.',
#  '“난 그 잡지가 너무 커서 읽지 않을 거라고는 생각하지 않아요.”',
#  '박-이 두 체제는 당 내부의 경선룰 중재안에 대한 지질한 공방으로 당 분열과 약화를 초래할지에 대해 우려하고 있다.',
#  '의사들은 치료 부위에 그것을 문질러 바릅니다 그리고는 한 시간을 기다립니다',
#  '윈스톤의 숙박시설에 나는 친구들과 짐을 풀었다.',
#  '테일러는 현재 온라인 롤플레이 게임인 월드 오브 워크래프트(World of Warcraft)에서 미국소녀가 만났던 남성과 관계를 갖고 있다.',
#  '경찰 기동대는 부토 전 총리가 이끄는 파키스탄인민당(PPP) 지지자들 약 50명이 부토 전 총리의 주택 주변 에 철조망을 제거하려고 하자 이들을 향해 폭력을 행사했다.',
#  '그는 “최우선 과제는 계속 진행되는 반도핑 문제”라고 강조했다.',
#  '롬니는 19일 플로리다에서 “미시간과 네바다주에서의 승리는 연합전선을 구축했다는 의미로 파악할 수 있다”며 “따라서 백악관 진출에 유리한 교두보를 마련했다고 볼 수 있다”고 강조했다.',
#  '약간의 국제적 긴장 상황이 발생했습니다.',
#  'South Korea expresses resentment to Japan’s claim to Dokdo 한국 정부, 일본의 독도 소유권 주장에 강한 분노감 표명\xa0 \xa0 \xa02006.05',
#  '화재가 발생한 창고 인근서 근무하고 있는 자동차 판매원 다니엘 샤히드는 “소방관들이 불에 타고 있는 창고에서 4명을 구조해내는 것을 목격했다”며 “그들은 힘들게 점원들을 구조했고 까맣게 그을린 소방관 옷을 입고 있었다”고 말했다.',
#  '그러나 오는 31일로 예정된 AC밀란과의 유러피안 슈퍼 컵은 예정대로 진행된다.',
#  '태즈메이니아 박물관측은 “죽은 채 발견된 이 오징어는 외투막 직경이 90cm, 길이는 약 8m이며 오션비치(Ocean Beach)해안가에서 한 주민이 발견했다”고 전했다.',
#  '미군 관계자에 의하면 미 국방부는 중국으로부터는 어떤 무기류도 직간접적으로 구입해서는 안 된다.',
#  '밀스(39)가 건물로 들어갈때 한 남성이 검정천을 들어 그를 사진기자들로부터 보호했다.',
#  '지금 까지 국회의사당에서 제리 보드랜더 AP 특파원이었습니다.',
#  '피해자들은 지난밤 시의 서쪽에 위치한 2세대 주택의 꼭대기 층에서 발견되었습니다.',
#  '이로 인해 만성적인 자금난을 겪고있는 북한이 타격을 입은 것으로 전해졌다.',
#  '소식통에따르면 신원이 밝혀지지 않은 이 요원은 북으로 돌아가 북한 정보 기관에 정보를 전달하기 위해 북으로 돌아간 것으로 알려졌다.',
#  '아직 구입하지 않았으면 적어도 1천달러를 더 지출할 계획을 세워라.',
#  '그 결과로서 그들은 지금 단순히 상품 뿐만아니라\xa0사상까지도 수출하고 있는 것이다.',
#  '미국 캘리포니아주 산타바바라에 본사가 있는 카본 사이언스(Carbon Sciences)사의 데릭 맥클레이시 사장은 “연구소에서 우리가 알게 된 사실들에 매우 흥분했다”며 “일부 기대되는 연구 결과을 얻었다”고 밝혔다.',
#  '하지만 조사 위원회의 한 EPP 의원은 다른 입장을 보였다.',
#  '한 구호단체는 소말리아인 난민의 규모가 이미 100만명을 넘어섰다고 밝혔다.',
#  '노무현 대통령, 말아톤의 실제 주인공 배형진 군 만난다.',
#  '˝말레이시아에서는 영국으로부터의 독립 50주년을 기념하는 이틀간의 사치스러운 축제가 진행중이다.',
#  '파키스탄 내무부는 부토 전 총리가 목에 총상을 입고 사망했다고 밝혔다.',
#  '북한이 남측의 답신 내용 수용을 거부한다며 군사적 대응 조치를 취하겠다는 비난 섞인 답신을 3일 보내온 것으로 알려졌다.',
#  '후진타오 중국 주석은 정치국 긴급회의를 소집해 귀성길에 차질이 생기지 않도록 신속한 조치와 빠른 복구를 약속했다.',
#  '며칠에 걸쳐 기술자들은 ‘오퍼튜니티’의 장치를 확인하고 크레이터의 상태에따라 명령을 조절할 계획이다.',
#  '칸나바로는 2006년 독일 월드컵에서 팀을 우승으로 이끌었으며 그해 골든볼을 수상하며 세계 최고의 수비수라는 찬사를 받았다.',
#  '바그다드 남쪽에 위치한 디와니야에는 미국과 이라크군들이 알 사드르의 민병대 마흐디군을 상대로 3일째 전투 중이었다.',
#  '정부 관계자는 이 센터가 이주노동자들의 한국사회 적응을 돕기 위한 것이라고 말했다.',
#  '이전 다니던 마이애미 대학은 신호용 조명등과 경찰과 바로 연결되는 직통전화가 곳곳에 설치 돼 있었다.',
#  '전과 같이 공연중인 작품들, 주로 연극, 의 장사는 파업 때문에 더 잘 되었다.',
#  '이가운데 부시 정부의 한 관계자는 “이란과 알카에다와 관련된 수니 이슬람 반군이 현재 진행중인 테러진압 작전에 도움이 안 될뿐더러 테러행위를 부추기고 있다”며 “이와같은 현실로 2003년부터 미군 병사 3천5600여명이 목숨을 잃고 있다"고 말했다.',
#  '이 사원은 지난해 2월에도 공격을 받아 당시 이라크내 종파갈등의 도화선이 됐다.',
#  '현재 프랑스는 200여개의 부대를 지난해 말 아프간에서 철수시켰으나, 아직 1000여개의 부대가 아프간에 주둔하고 있는 것으로 알려졌다.',
#  '카스트로 의장(80)은 3일(현지시간) 농득마인 베트남 공산당 서기장을 면담한 자리에서 누구의 도움 없이 혼자 서있었으며 시종일간 웃음을 잃지 않는 등 활기찬 모습을 보였다.',
#  '총인구의 약 1/3 즉 농촌 지역에 사는 700만 명도 안되는 사람들이 이런 시장에서 물건을 살 수 있다.',
#  '미국 정부가 25일(현지시간) 대량살상무기 개발과 테러 관련 활동을 해온 혐의로 이란 혁명수비대와 대다수 은행에 대해 제재조치를 발표했다.',
#  '유엔주재 싱가포르 대사는 유엔임시총회에서 이번 사태를 정치적 문제로 삼지 말 것을 촉구하며 미얀마에 대한 비난을 자제했다.',
#  '화나게 하다 (=stir to anger;',
#  '이슬람 저항세력은 자신들의 목표를 밝히지 않았지만 급진적인 이슬람 이데올로기에 기반한 주의 독립을 위해서 싸우는 것으로 추정된다.',
#  '오바마의 지지자들로부터 사퇴압력을 받고 있는 있는 클린턴은 부시 행정부의 석유정책을 강도 높게 비난했다.',
#  '1년 과정의 한국학 석사와 3년 과정의 동양학 박사학위 과정-가 있다.',
#  '힐러리경은 1990년 가까운 동료이자 탐험가인 피터 멀그로의 전 처였던 준 멀그로와 재혼했다.',
#  '태풍은 7일 오전 중국 온주시 해안에 상륙했으며 중국 해안경비대는 7일 기계고장으로 난파된 홍콩 화물선에서 선원 27명을 구조했다고 신화통신은 보도했다.',
#  '미 의회는 2차 세계대전 당시 구리, 아연, 니켈 가격의 급상승으로 철로 만든 페니를 줄이고 니켈에 철을 사용하기로 한 개혁안을 결정한 바 있다.',
#  '이스라엘군은 부다리를 체포한 후 템플 마운트로 끌고 갔다.',
#  'ISLAMABAD, Pakistan (CNN)/권성근(JOINS)',
#  '모세 웨탕굴라 케냐 외무장관이 케냐 내 정치적 위기 해결을 위한 회담을 준비하고 있는 코피 아난 전 유엔 사무총장에게 높은 기대감을 드러냈다.',
#  '그러나 4년 전, 영화 ‘반지의 제왕-왕의 귀환(원제:',
#  '짐바브웨 정부가 31일(현지시간) 지난 주말 치른 의회 선거 결과 일부를 공개했지만 대선에 대해서는 어떤 자료도 내놓지 않았다.',
#  '아래쪽은 멋진 폭포와 인적이 드문 모래사장이 있다.',
#  '태국 OG 269편은 16일 오후 방콕에서 이륙해 푸켓으로 향할 당시 승객 123명과 승무원 7명을 태웠다.',
#  '빌 클린턴의 인기도 힐러리의 압승에 한 몫 했다.',
#  '국영 이타르타스는 볼쇼이발레단의 아나톨리 익사노프 감독의 말을 인용, 그의 죽음은 볼쇼이 극장과 러시아 문화 전체에 큰 손실이라고 보도했다.',
#  '소말리아 해적들은 최근 1억 갤런의 석유를 싣고 있는 사우디아라비아의 초대형 유조선을 납치했습니다.',
#  '세계보건기구(WHO)는 2003년 이후 H5N1형 바이러스 감염으로 206명이 사망한 것으로 추산했다.',
#  '오바마는 버몬트 프라이머리에서 승리함으로서 경선 12연승을 거뒀으며 공화당 대선 후보가 유력시되는 매케인은 대의원 17명을 추가로 확보했다.',
#  'WMUR 방송은 웹사이트를 통해 “6개월과 8개월 된 유아를 동반한 젊은 여성이 눈물을 흘리며 가게로 뛰어 들어왔다”며 “그는 한 남성이 힐러리의 사무실에 들어와 코트를 벗고 가슴에 있는 테이프로 감싼 폭탄을 보여줬다고 말했다”고 보도했다.',
#  '미국 공화당의 대통령 후보인 존 매케인 상원의원은 자신이 ‘매칭 펀드’ 형태의 연방자금 지원 철회에 대한 권한을 갖고 있다고 주장했다.',
#  '뉴저지주 이스트로 러더퍼드에 있는 자이언트 스타디움에도 강풍이 불어 경기 전후 접대행사에 사용하는 직물로 된 구조물 천장이 무너졌다.',
#  '이번의 중대한 발전은, 많은 질병에 대한 새로운 치료법을 연구하는 데에 사용될 세포들을 풍부하게 공급해 줄 새로운 공급원이 될 것으로 보인다.',
#  '나는 가난을 위해 일할것이며 상처를 보듬을것이다"고 라모스 홀타는 10일(현지시간) 당선 연설을 했다.',
#  '한편 슬로바키아와의 친선경기에서 갈라스외 에 줄리앙 에스퀴데와 릴리앙 튀랑이 출전할 수 없을 전망이다.',
#  '코밑 에 수염을 그리고 작은 경찰과 작은 군인으로 분장한 소년 2병이 당당하게 행진하며 경례 했다.',
#  "미국 교수들은 이에 대해 ‘인종 차별적’ 발언이라고 격렬하게 비난하고 동료 과학자들도 '유전학적인 넌센스' 논리라고 무시했다.",
#  '영국 런던 중앙에서 12일(현지시간) 보수공사 중이던 건물 맨 위 두개 층이 붕괴됐으며 건설 인부들이 부서진 돌더미 속에서 위험에 처했다고 경찰이 밝혔다.',
#  '어떤 서양의 중국학자들은 팔룬 공의 원리에 대한 과학적 근거로 팔룬 공을 칭송하기도 한다.',
#  '호주의 국적항공사 콴타스 항공은 6일(현지시간) 111억불 규모에 달하는 맥쿼리 은행 컨소시엄의 차입매수 방안이 실패했다고 밝혔다.',
#  "그 영화는 스콜세지의 최대 흥행작이 되었고 비평가들은 이 선명한 유혈 범죄 장르에 찬사를 보냈다. 스콜세지는 '택시 드라이버'나 '좋은 친구들'같은 영화를 통해 이 분야를 개척했다.",
#  'FBI는 그가 출판사와 타블로이드 신문에 녹음내용을 제공하는 대가로 50만달러(약 7억원)에서 300만달러(약 43억원)까지 요구했다고 밝혔다.',
#  '그는 마틴 루터 킹 목사와 그의 인권운동을 지지하는 유명인사 중 1명이었다.',
#  '한국 문화 컨텐츠 진흥원 및 영화 진흥회를 포함한 30여 개의 공공 기관이 문화체육관광부 산하에 있다.',
#  '육상 및 항공 교통에서 증가하고있는 CO2 배기가스는 이 지역 온실 가스 효과를 줄이기 위한 EU의 노력을 위협하고 있다.',
#  "중남미 최빈국인 볼리비아의 에보 모랄레스 대통령은 이번 출범식을 '역사적인 순간'이라고 표현했다.",
#  '사르코지와 마찰을 빚기 전 콜 사진기자는 뉴햄프셔주 경비정에 자신의 신원을 밝힌 뒤 위니페소키 호수에 있어도 된다는 허락을 받았다.',
#  '피셔-프라이스 완구업체를 계열사로 갖고 있는 마텔은 납 성분이 함유된 페인트 관련 리콜은 처음이며 1998년 피셔-프라이스에서 만든 ‘파워 휠스’(Power Wheels) 1000만대 리콜 사태 이후 가장 큰 규모이다.',
#  "“그러다, 그는 그의 가장 유명한 배역인 드라마 '힐스트리트 블루스'에서의 하사관 역을 맡게 되었습니다.”",
#  'pit ~ against ~ ~와 ~를 싸우게 하다, 대항시키다',
#  '학교에서 하루에 너댓 시간을 영어공부에 쏟는 니키군은 \'\'매우 어렵다"면서 \'\'문법 외우는게 너무 싫고, 학교 선생님들도 정말 지겹다"고 말한다.',
#  '은색 눈 화장과 반짝이는 립스틱으로 치장한 안나 이바노바(19)는 “여자는 수감생활을 해도 밖에서 생활했을 때처럼 예쁘게 꾸며야 한다”고 말했다.',
#  '리누아트 장군은 또 “정찰위성이 발사됐던 북미지역으로 떨어질 수도 있다”며 미 국토안보부(DS)와 연방위기관리국(FEMA)이 캐나다 및 멕시코 정부와 대책을 마련하고 있다고 전했다.',
#  '법에 대한 지식은 물론 대중의 삶과 공감하는 자질, 그리고 이 법이 어떻게 작용할지에 대한 실용적인 감각이 있어야 합니다.”',
#  '중국어선은 난파된 한국어선 선원들을 그 자리에서 구조하지 않고 사건현장을 떠났다는 사실도 늑장보도의 추론이다.',
#  '가장 수익을 올린 구단주가 영국 축구팀에 혜택을 주었을까?',
#  '좌파인 차베스 대통령은 대통령의 권력을 늘리고 자칭 개혁을 진보시키며 OPEC 국가에 대한 사회주의 국가를 강건히 하는 내용의 많은 개헌을 위한 국민투표에서 승인을 얻으려고 하고 있다.',
#  '그가 속한 그룹은 12차례 이동했으며 오토바이를 타거나 걸어서 이동했다고 덧붙였다.',
#  '민주당 대선주자들은 지난해 여름 CNN이 주최한 포럼에 참석해 자신들의 종교관과 더불어 종교신념과 정책 추진의 연관성에 대해 의견을 밝히기도 했다.',
#  '프랑스 파리 외각에 위치한 샤트네- 말라브리 연구소가 변형 에리스로포이에틴(EPO•헤모글로빈 생성을 돕는 금지약물)인 ‘세라(CERA)’를 감지하는 최신 검사 약물을 사용할 수 있게 하면서 올해 투르 드 프랑스 참가 선수들의 샘플을 재검사했다.',
#  '〔슬픔 따위〕를 가라앉히다;',
#  '남북은 16일 제1차 남북총리회담에서 개성~신의주 철도에 대한 개보수 공사를 내년에 착공하기로 합의했다.',
#  '케냐 정부는 지금 까지 최소 208명이 숨졌으며 칼로 무장한 젊은 폭력배들이 거리를 활보, 주민 7만5000명이 피난했다고 밝혔다.',
#  '상용항공제조업자협회는 “항공기 제조업계가 지난해 모두 합쳐 항공기 885대를 제조, 약 15조를 벌어들였다”며 “올해 1/4분기에는 이미 항공기 211대를 제작했다”고 발표했다.',
#  '이들 커플은 30년 전 엘리트 관료 배출학교인 국립행정학교(ENA) 동기생으로 4명의 아이를 낳았지만 결혼은 하지 않았다.',
#  '잭슨은 구체적으로 밝히지 않은 병 때문에 미국에서 동영상으로 연결해 심의에 응할 수 있도록 해달라고 요청했으나 로버트 잉글하트 잭슨측 변호사는 20일(현지시간) 법원에 잭슨의 주치의가 2일간 여행을 할 수 있음을 증명했다고 전했다.',
#  '중동의 온화한 기후에 익숙해져 있던 이스라엘인들은 눈이 내리자 흥분을 감추지 못하며 거리로 나왔다.',
#  '이란 관영 IRNA 통신은 아마디네자드 대통령을 인용 “미 정보기관의 보고서는 이란 국민이 옳다는 것을 보여줬다”고 밝혔다.',
#  '케리 후보, 민주당 대통령 후보 지명 수락\xa0 \xa0 \xa02005.08',
#  '게이츠는 “미군과 나토군 지휘관들은 지난해 이룩했던 군사적인 업적을 이어나갈 필요가 있다는데 공감했다”며 “앞으로 탈레반 세력을 압박하면서 아프간 보안군의 훈련에 공을 들일 것”이라고 말했다.',
#  '평소 통행량이 많은 샌프란시스코 고속도로에서 29일(현지시간) 가솔린을 실은 트럭이 전복, 불길에 휩싸였다고 당국자들이 밝혔다.',
#  '이란과 IAEA는 7월과 이달 초 이미 회담을 가진 바 있다.',
#  '5월 31일(현지시간)에 열렸던 행사에서 관객들은 루가스 워서의 다리에 새겨진 문신, 스테인 글라스에 새겨진 요셉과 마리아와 아기 예수 작품이나 장 비숍의 팔에 새겨진 밀림에 나타나는 고양이 31마리가 새겨진 문신에 감탄했다.',
#  '한편 FARC가 프랑스, 스위스, 스페인의 협상제의를 거부하면서 베탕쿠르 조기석방에 대한 기대는 벽에 봉착했다.',
#  '부시 미 대통령이 김정일 북한 국방위원장에게 북한 핵프로그램의 완전한 신고를 촉구하는 친서를 보냈다고 백안관이 6일(현지시간) 밝혔다.',
#  '맨체스터 유나이티드,리버풀,첼시, 아스날이 전체 총 채무액의 1/3을 차지고 있는 것으로 확인됐다.',
#  '참석자들은 상으로 선물 증서를 기증한 뉴욕 시의 바와 레스토랑들에 박수를 보냈습니다.',
#  '이는 농담이 아니고, 공석인 주 상원직을 경매에 부친 라드 블라고예비치 일리노이 주지사의 체포 소식에 12명 이상의 사람들이 분노하고 있습니다.',
#  '존 포럴(59)은 무혐의 판결을 받았다.',
#  '이 같은 통계는 여자가 남자보다 평균수명이 더 길기 때문이라고 해석할 수도 있다.',
#  '이전 야당인 민주당은 2011년까지 아프간 내 주둔군 철수를 주장했고 여당은 재검토 하겠다는 입장을 발표했었다.',
#  '한편, 사드르의 보좌관은 미군이 사원에 난입해 무장하지 않은 무고한 사람들을 죽였다고 비난했다.',
#  '한국인 약 430만 명이 인터넷 중독\xa0 \xa0 \xa02005.08 ',
#  '빌 클린턴의 ‘지지선언 발언’은 그가 최근 캘리포니아의 수퍼대의원들과 접촉한 자리에서 나왔다.',
#  '독일 벤더스 감독은 괴한의 추격을 받는 사진작가의 이야기를 담은 ‘팔레르모 슈팅’을 에고얀 감독은 사이버공간에서 자신을 재발견하는 청년의 모습을 그린 ‘동경’을 각각 선보인다.',
#  '이슬람 무장 단체 웹사이트를 통해 발표한 성명에따르면 아부 함자 알 무하지르는 지식이 풍부하고 성전聖戰(지하드) 경험이 많다.',
#  '이들이 병원으로 들어올 당시 아버지는 아이의 손을 잡고있었다.',
#  '마라도나와 빌라르도는 그론도나 회장과 회의를 마친 후 감독직을 수용 여부에 대해 언급하지 않았다.',
#  '올 시즌 한 차례도 등판하지 않으며 재활에 집중했던 실링은 공을 던질 때 통증이 발생해 결국 지난주 수술을 결심했다.',
#  '법원 대변인은 런던 중앙형사재판소 배심원들이 5개월 간의 공판 이후 유죄 판정을 내렸다고 밝혔다.',
#  '극단적 국수주의자 이해찬 국무총리, 조선일보와 동아일보 신랄하게 비판\xa0 \xa0 \xa02005.08',
#  '한편, 세계보건기구는 돼지 독감의 유전자가 돼지에게서 나왔을지라도, 이 전염병이 돼지로부터 발생한다는 아무런 근거가 없다고 밝혔습니다.',
#  '수색 중인 지역은 그녀 핸드폰의 신호가 마지막으로 끊긴 곳이라고 경찰은 밝',
#  '그것은 분명히 많은 미국인들이 느끼는 엄청난 불안의 중심에 자리잡고 있다.',
#  '게이머가 우주 괴물들이 지금 도쿄 타워나 세븐일레븐 편의점 주변을 서성거리고 있는 가리키는 변칙적인 경보를 빨리 입수한다.',
#  '코리아 타임즈는 정부가 저소득층 생활 증진을 위해 원유 및 기타 원자재가 상승으로 인한 소비자 물가 상승 중에, 공공요금과 교통요금을 동결할 예정이라고 보도했다.',
#  '당국은 이 건물, 건물의 소유주, 건물이 붕괴된 상황 등을 밝혀낼 계획이다.',
#  '시나리오 작가들의 파업으로 NBC 인기 시트콤 ‘더 오피스’(The Office)을 비롯, 프라임 타임 프로그램 8편의 제작이 중단됐다.',
#  '그러나 다른 자선단체는 아이들을 조사한 결과 아이들 대부분이 수단 아닌 차드 출신이었으며 적어도 한쪽 부모가 있는 아이들이었다며 이들의 주장을 반박했다.',
#  '쿠비아크 대변인은 라보프가 경찰서에 연행된 이후 예의 바르고 공손한 모습을 보였다고 설명했다.',
#  '얀 피터 발케넨더 총리는 헤이그에서 “군사령관의 아들이 이번 폭탄테러로 숨졌다는 정보는 얻지 못했다”고 말했다.',
#  '포기어드 전 회장은 주식을 팔려는 시기에 에어버스 출시 연기 발표라는 악재가 우연히 맞아 떨어졌다고 주장했다.',
#  '앨프레드 무투아 정부측 대변인은 시위대가 법적으로 불만사항을 해결해야 한다는 키바키 대통령의 견해를 되풀이하며 “행정부는 언제든 대화할 용의가 있다”고 전했다.',
#  '영화에서 윌슨의 형 역할을 맡아 그와 함께 작업했던 동료 애드리안 브로디는 그와의 작업에 대해 "윌슨은 유머에 천부적 소질이 있으며 장난꾸러기 같다"고 말했다.',
#  '뉴질랜드행 항공료는 10월이 가장 저렴한 편이다.',
#  '그는 또 "사람들이 보통 잠을 자는 것에 대해 게으른 것이라 생각하는데 취침은 다이어트에 가장 좋은 방법이다"고 설명했다.',
#  '그는 76세의 나이에도 여전히 건강하고 (대통령으로서) 적합하다는 것을 보여주기 위해서 노력하는 보좌관들에 의해 내세지고 있는 명목상의 우두머리로 전락하였다.',
#  '화성 표면에 미생물이 존재할 가능성이 있는 것으로 30년 전 수집한 데이터 자료 분석 결과 나타났다.',
#  '증거 테이프를 파괴한 CIA의 행위가 세 개의 서로 다른 수사의 주제가 되고 있다.',
#  '피타르카치 쉬빌리는 지난해 친 서방 세력인 미하일 사카쉬빌리 그루지아 대통령을 몰아내기 위한 쿠데타 모의 혐의와 조기 대선을 요구하는 반정부 시위를 조직적으로 확산시킨 혐의를 받고 있다.',
#  'CBS는 현재 61개의 라디오 방송국을 소유하고 있으며 처음에는 그가 진행하는 방송을 2주간 중단하겠다고 발표했다.',
#  '그러나 버냉키는 금융시장 위기가 일부 해소됐다며 12월 11일 연방공개시장위원회에서 금리를 추가로 인하하지 않겠다고 밝혔다.',
#  '카발호 경관은 카라우라이 시 인근에서 가진 전화인터뷰를 통해 “아이는 아버지를 따라 밀림으로 들어가 길을 잃었었다” 고 전하며 “며칠 뒤 사냥을 나갔던 그의 사촌에 의해 발견됐다” 고 말했다.',
#  '소설가 폴 더로우는 예전 자신의 책에 묘사 된 옛 싱가폴이 그립다며 사람들은 항상 새로운 것을 찾기 위해 옛 것을 버린다고 비판했다.',
#  '당시 그들은 몸값을 지불하고 무사히 석방됐다.',
#  '이들은 또한 리프트 계곡에 있는 서부도시 키수무를 순찰했다. 이곳 상점은 폭력사태가 예상돼 문을 닫았다.',
#  '그는 "진짜 치아를 다시 이용하는것은 매우 중요했다"며 "포름알데히드안에 동물들이 있는 것처럼 당신은 그 안에 실제 동물을 가지고 있는 것이고 그것은 묘사가 아니다.',
#  '또한 중국의 타이어 제조업체는 출시 전 이뤄진 안전 테스트에서 불합격 판정을 받았으나 그대로 시장에 출시한 것으로 드러나 뉴어크 연방법원으로부터 고소당한 상태다.',
#  '대부분 시아파 의원들로 구성된 이라크 정부는 후세인 독재가 끝난 이후 처음으로 이라크를 방문한 이란 대통령을 환대했다.',
#  '천정배 법무부 장관은 미국 입국 비자 면제 프로그램(VWP)을 논의하기 위해 알렉산더 버시바우 주한미대사를 만날 것이라고 법무부 관계자가 밝혔다.',
#  '미국 캘리포니아주 새크라멘토의 고속도로를 달리던 트럭 1대가 16일(현지시간) 전복되며 실려있던 벌통이 떨어져 꿀벌들이 도망치는 사고가 발생했다.',
#  '그러므로 포커게임 역시 컴퓨터가 인간보다 더 잘하게 될 것은 물론이며 중요 관심사는 얼만큼 빨리 인간의 실력을 따라잡을 것인가 이다.',
#  '작년에 런던에서 알렉산더 리트비넨코를 살해한 혐의를 받고 있는 전 KGB 요원을 모스크바가 인도하기를 거부한 후 이러한 결정은 내려졌다.',
#  '뉴욕시 라이커스 아일랜드 교도소에서 신종 플루가 발생했습니다.',
#  '뉴욕 운송노조 간부들이 파업 3일 만에 파업을 철회해 수백만의 이용자들은 더 이상 걷거나 자전거를 이용하고 스케이트를 타거나 승용차를 함께 타지 않아도 되게 됐다.',
#  '관계자들의 말에 의하면 폭발이 일어난 곳은 자이툰 부대에서 아르빌 시내쪽으로 약 800미터 떨어진 곳으로 24마리의 양떼가 죽었지만 인명 피해는 없었다고 코리아 헤럴드는 보도했다.',
#  '시장조사기관인 글로벌인사이트의 전문가들에따르면 뉴욕은 플로리다 올랜도를 제외하면 그 어떤 도시보다 외국이나 국내 여행객이 많다.',
#  '더욱 중요한 것은 새로운 아이디어와 새로운 기업모델이 빠른 속도로 시장에 진입하도록 자금을 공급함으로서 벤처자본은 기술 변화의 속도를 엄청나게 가속시키고 있다.',
#  '미 고위관리는 이날 CNN과의 인터뷰에서 지난해 9월 이스라엘의 폭격을 당했을 때 이 원자로는 완공을 몇 개월 앞두고 있었다고 주장했다.',
#  '그녀는 남편이 결혼과 가정을 위기에 빠뜨리리 라고는 믿지 않았다.',
#  '더스 아인체르는 항공 승무원 조합의 편에서 궁극에는 납세자들이 지불해야만하는 고액의 보상금을 비판했다.',
#  'Two Koreas agree to resume bilateral talks남북회담 재개키로2007.05 원문 & 독해설명 인쇄',
#  '이날 경매에 낙찰된 작품은 1971년 뉴욕 경매에서 32만달러에 팔렸으며 그 이후로 일반인에게 공개되지 않고 있었다가 이번 경매에 공개됐다.',
#  '1950년대 공장 지대였던 이곳은 갤러리, 카페, 서점, 야외 조각 전시장으로 변모했으며 오래된 공장 벽에는 예술적인 낙서가 있다.',
#  '35살의 경비원은 쇼핑 센터로 들어가려는 사람들에게 밀려 벽돌 기둥에 눌려 사망했다.',
#  '소렌스탐은 최근 두 차례의 크라프트 나비스코 우승으로 동일 메이저 대회 3년 연속 우승을 기록하는 첫 LPGA 선수가 되려고 노력하는 중이었다.',
#  '미국은 18일 팔레스타인 자치정부가 하마스와 결별함에따라 팔레스타인에 대한 정치적, 경제적 제재 조치를 풀었다.',
#  '약 절반 가량의 호주 의회 소속의원들이 민주당이 장악한 미국 의회에 서한을 보내 관타나모 수용소에 감금되어 있는 유일한 호주 출신 테러 용의자의 송환을 촉구했다고 관계자들이 2일 (현지 시간) 전했다.',
#  '5가지 연속 실험에서 동성애 남성과 색맹인 남성을 제외한 이성애자 남성 약 150명이 빨간색, 흰색, 회색, 청색 사진의 여성 사진과 빨간색 셔츠와 청색 셔츠를 입은 여성 사진들을 평가했다.',
#  '영국 정부는 법안 검토의 일환으로 성 매매를 법으로 처벌하는 스웨덴과 사창가에 대한 면허를 주는 네델란드를 포함 주변 국가들의 사례를 살펴봤다.',
#  '드림웍스와 패러마운트사가 공동제작한 공상과학 영화 ‘트랜스포머’(Transformer)는 이번주 3600만달러(약 330억원) 상당의 수익을 내며 1위 자리를 해리포터에게 내줬다.',
#  'UK troops begin Basra withdrawal 영국군 바스라에서 철군 시작\xa0 \xa0 \xa02007.12',
#  '페샤와르는 아프가니스탄 국경지역에 위치하고 있으며 부족 세력이 집중 거주하고 있다.',
#  '서방의 일부 국가들이 아프간 여행을 금지시켰다.',
#  'BBC 시리즈 완결판(Planet Earth:',
#  '그는 “우리는 이에 대해 매우 낙관적”이라며 "종양의 크기는 매우 작다"고 강조했다.',
#  '심사의원인 코웰은 29세의 테네시주 브랜트우드 출신으로 코러스 가수를 했던 두리틀에 대해 많은 관심을 보여왔다.',
#  '윌슨은 “고래들이 움직이기 시작한다면 과학자들도 뭉쳐서 해결 방안을 모색할 것”이라고 덧붙였다.',
#  '휘발유 판매가가 갤런당 4달러(약 4200원)에 육박한 가운데 정유회사인 엑손모빌이 충분한 수익창출 불가를 이유로 자사 직영 주유소를 매각할 예정이다.',
#  '그를 태운 차량은 경찰차 수십대의 호위를 받으며 급하게 떠났다.',
#  '무니르 만갈 내무부 차관은 28일 로이터와의 인터뷰에서 협상이 결렬될 경우 무력사용도 배제하지 않겠다는 입장을 밝혔다.',
#  '결의안은 WHO 회원국들이 협의한 끝에 작성된 것으로 알기 쉬운 일반적인 표현으로 작성됐으나 공정한 분배가 무엇을 의미하는지는 밝히지 않았다.',
#  '“우리는 중산층에 집중할 것입니다.',
#  '카스트로는 장출혈로 수술을 받은 후 휴식을 위해 임시로 동생인 라울에게 권력을 이양했다.',
#  '그는 “버락 오바마 당선자가 주간 유튜브(YouTube) 동영상 연설을 시작하고 국민들이 그가 답할 수 있는 질문을 여과할 수 있도록 하는 21세기용 노변담화를 시작해도 그리 놀라지 않을 것”이라고 덧붙였다.',
#  '이날 버몬트주뿐만아니라 오하이오주, 텍사스주, 로드아일랜드주에서도 이른바 ‘미니 수퍼 화요일’ 경선이 치러졌다.',
#  '한편 프랑스군 약 1600명은 은자메나에 살고 있는 외국인 수백명이 대피하는 것을 도와주고 있다.',
#  '이번 결정에서 리치(43)는 하루 안에 미국을 떠나기로 동의했으며 8일 스코트랜드로 떠날 예정이다.',
#  '이라크 의회가 오늘 내각을 통과한 미국과의 신규 안보협정을 승인할 것으로 예상되고 있습니다.',
#  'breakdown 붕괴, 분열, 파손',
#  'A international conference on North Korea’s human rights hold in Washington.워싱턴에서 북한인권국제회의 열려2005.09',
#  '반도체 전문가인 찰스 무어의 이름을 본따 1970년대에 명명된 무어의 법칙에 의하면, 실리콘 반도체에 의해 작동하는 컴퓨터 프로세서의 능력과 속도는 18개월마다 두 배가 된다고 한다.',
#  '대만의 신임 총통이 중국과 보다 나은 경제적 정치적 유대 관계 정립하겠다고 약속했다.',
#  '로드리게스는 24일 축하의 의미로 양키스 클럽하우스에서 동료 선수들에게 시가를 돌렸다.',
#  '과학자들은 대서양 건너에 있는 동료들이 가하는 힘을 느낄 수 있을 뿐 아니라, 그들이 느끼고 있는 대상체의 질감도 느낄 수 있다.',
#  '북한은 남한 당국자 추방에 대해 김하중 통일부장관의 지난주 발언을 이유로 들었다.',
#  '샤킬과 쇼니는 결혼 후 4명의 아이를 낳았으며 2002년 12월 26일 결혼식을 올리기 전에 각각 1명의 아이를 두고 있었다.',
#  '중국에서는 여전히 6천만명의 중국인들이 까다로운 고대 한자를 이름에 사용하고 있어 컴퓨터가 이를 인식하지 못하는 행정적인 어려움에 처해 있다고 리 부처장은 말했다.',
#  '브리아나 모리슨이 여섯 쌍둥이를 임신하자 담당 의사들은 선택적으로 아기를 줄일 것을 충고했었다.',
#  '필립 알스톤 사법권외의 살인 관련 유엔 특별 보고자는 필리핀군이 상당히 많은 비사법적 살해를 저질렀다고 밝혔다.',
#  '미군이 벌인 것으로 추정되는 미사일 공격으로 파키스탄 탈레반 훈련기지가 파괴되면서 무장세력으로 의심되는 29명이 목숨을 잃었다고 알려졌습니다.',
#  "와인하우스는 올해 미국에서 데뷔앨범 '백 투 블랙(Back to Black)'을 발표하고 많은 사랑을 받았으나 자주 물의를 일으켜 재능이 빛을 잃었다.",
#  '오하이오 주립대학에서 동물 헌혈 프로그램을 연구하고 있는 길레모 쿠토 수의사는 그레이하운드가 또한 목에 큰 혈관이 있어 채혈이 쉽다고 말했다.',
#  '당국은 벌떼로 인한 피해를 막기 위해 운전자들에게 창문을 닫고 에어컨을 가동하지 않은 채 주행할 것을 권고했다.',
#  '영국 왕립조류보호협회(Royal Society for the Protection of Birds, RSPB)의 연구소는 이는 남대서양 중앙 고프섬에 서식하고 있는 트리스탄 신천옹에겐 악재라고 지적했다.',
#  '언론 보도를 통해 통일부에서는, “북한이, 연초라 준비할 것이 더 있다고 이야기하며 회담의 연기를 통보해 왔다”고 언급했다. inauguration 공산주의(자)의(식)',
#  'structural problem 구조적인 문제 ditch 수렁',
#  '다리우즈 칵퍼치크 소령은 폴란드 수도 바르샤바에서 “10월 31일을 끝으로 폴란드 군은 이라크에서 완전히 철수할 것이다”고 말했다.',
#  'Finance-Economy Minister suggests to invite N K to the APEC Finance Minister’s Meeting.재경부 장관, APEC 재무장관회의에 북한 초대 제안 2005.10',
#  'Canucks 벤쿠버 커넉스(NHL 서부컨퍼런스 북서부지구 아이스하키팀)',
#  '중동 지역에 폭설과 강풍 피해가 잇따르는 가운데 30일(현지시간) 예루살렘에서도 눈보라가 쏟아져 대중 교통이 마비되고 학교는 휴교령이 내려졌다.',
#  '일본인 부부가 남편의 정자와 익명의 기증자의 난자를 인도 대리모의 자궁에 이식시키는 인도의 한 병원에 이에 대한 비용을 지불하면서 수정란 착상에 성공한 것이 바로 만지다.',
#  '영국의 한 모터 사이클 선수가 곡예 운전을 하는 장면을 인터넷 사이트‘유튜브(YouTube)’에 올렸고 당시 시속 210km로 과속 주행한 경범죄 위반 사실을 경찰에 자백해 구속됐다.',
#  '구체적인 건설 비용 또한 일반에게 공개된다.',
#  '그러나 대량 학살의 직접적인 책임자인 믈라디치와 그의 정치적 지도자인 라도반 카라치크는 아직까지 체포되지 않았다.',
#  '지난 주 사임한 엘리엇 스피처 전 주지사 후임인 데이비드 페터슨 뉴욕 주지사는 이번 사건은 건물에 균형을 유지하던 크레인이 붕괴되면서 발생했다고 전했다.',
#  '오무라 요시푸미 하노이 소재 일본 국제협력은행(Japanese Bank for International Cooperation, JBIC)은 이 공사 프로젝트에 85% 이상인 2억1800만달러를 융자해줬다고 밝혔다.',
#  '하산 알 시네이드 누리 말라키스 총리의 보좌관은 이번 사건은 내부인의 도움이 절대적으로 필요하다고 여겨 식당 종업원 3명과 경비원들을 추궁하고 있다고 밝혔다.',
#  '미국에서는 최소 59명, 3명이 사망한 카나다에서는 37명이 SARS의 감염의심자로 조사됐다.',
#  '지금은 270포인트 이상 떨어진 상태입니다.',
#  '유럽 및 아시아 주둔 미군, 본토로 철수 예정\xa0 \xa0 \xa02005.08',
#  '한편 케르치 해협에서는 거센 폭풍으로 터키 범선과 그루지야 선박들이 육지로 발길을 돌렸다.',
#  '혼다는 제네바에서 연료 전지 엔진 차량을 전시, 인기를 누렸지만 이는 아직까지 시험 준비단계에 있는 고성능 실험용 원형 차량이다.',
#  '올로우는 시메티딘이 사마귀를 만들어 내는 바이러스에 대한 신체 면역체계를 회복시키는데 도움이 되는 것이 아닌가 생각하고 있다.',
#  '이 버스는 정원이 45명이었으나 버스에는 순례자 80명이 탑승한 것으로 밝혀졌다.',
#  '오바마 선거캠프는 또 빌 클린턴 전 대통령이 억만장자 친구의 투자회사인 유카이파(Yucaipa)의 수석자문역을 그만두면서 2000만 달러의 몫을 받았다며 클린턴 부부가 세금 환급 자료를 공개해야 하는 이유를 설명했다.',
#  '소매 판매고는 10월 들어 최고 수준의 하락을 기록했는데, 이는 금융 위기와 크게 나빠진 경제상황이 소비자들로 하여금 소비를 급격하게 줄이게끔 만들었기 때문입니다.',
#  '이 미스터리를 풀기 위해 과학자들은 투탕카멘 미라를 석관에서 옮겨와 2005년 3차원 이미지를 얻기 위해 휴대용 CT로 촬영했다.',
#  '한편, 가이와 스피어먼의 코치인 랑스 브라우만은 공금 횡령과 사기 혐의로 수감되었다가 28일 석방됐다.',
#  '미국 공군이 대륙간 탄도미사일(ICBM)의 기폭장치를 대만에 잘못 전달한 것으로 밝혀졌다고 25일(현지시간) 미 국방부가 밝혔다.',
#  '불가리아의 서부에 위치한 트란에서 발생한 이번 총기난사 사건의 동기는 즉각 밝혀지지 않았다.',
#  '그는 이 곳에서 총278명의 대의원 수를 확보했다.',
#  '그는 또 “조가 총을 갖고 수업에 들어오는 것을 대배해야 했다”고 밝혔다.',
#  '“볼의 크리스털 수를 672개에서 2668개로 늘렸습니다.”',
#  '곤잘레스는, 자신이 아무런 잘못이 없다고 거듭 주장했다.',
#  '월스트리트의 오전 거래장에서는 다우지수가 172포인트 하락했습니다.',
#  '집 나간 삼촌 사진처럼은 안 보이지만, 인간 가계의 구석 깊은 곳에서 나왔음직한 화석 하나가 학계에 공개되었습니다.',
#  '수소 황화물 기체는 무색에 달걀 썩은 냄새와 비슷하다.',
#  '우리 정부와 주한미군의 협상이 만족할만한 결과를 내지 못할 경우 노조는 5월부터 총파업에 들어가겠다고 밝혀 긴장이 고조되고 있다.',
#  '교토통신은 여학생이 욕실문을 닫고 문 밖에 ‘가스가 나온다’는 글을 붙여놨다고 보도했다.',
#  '대법원은 이 사건을 서울고등법원으로 돌려 보냈다.',
#  '로이 보스톡(Roy Bostock) 야후 회장은 “지난 1년 반 동안 특별히 어렵고 혼란한 상황에도 불구하고 제리 양은 야후가 개선된 지출과 수입의 조정뿐만아니라 오픈 플랫폼의 모델로서 다시 입지를 다지는 일을 주도했다”고 말했다.',
#  '키스 오스카 에케리 수족관 관장은 지난 주말 범인이 우리의 자물쇠를 부수고 타겐을 데려갔다고 전했다.',
#  '생크와 그의 가족들에게 일어났던 사건 중 가장 큰 사건은 월마트와의 보험금 소송이었다.',
#  '공부를 위해서만 이용하겠다고 말입니다.',
#  '내무부는 또 사고 몇시간 전 바그다드 중심부에서 폭탄 폭발로 인해 오토바이가 뒤집혀 3명이 목숨을 잃고 11명이 다쳤다고 덧붙였다. BAGHDAD, Iraq (CNN)/ 이정인(JOINS)',
#  '클린턴은 “이것은 잔인한 일”이라며 “많은 사람들이 그녀가 후보가 되길 바라고 있다.',
#  '이와 더불어 ASEAN 회원국들은 이재민의 의료 서비스를 위해 의료진 30명 등 총 270명의 구호 요원을 미얀마에 파견했다.',
#  '메르켈 총리는 또 지난해 11월 미 매릴랜드 아나폴리스에서 논의됐었던 이스라엘과 팔레스타인간의 분쟁 해결을 지원할 것이라고 밝혔다.',
#  '북한이 8일(현지시간) 소말리아 해상에서 해적에 나포됐던 북한 선적을 도와준 미국에 감사를 표했다.',
#  '다우지수는 오전에 300포인트가 넘는 3.5% 이상 하락했습니다.',
#  '헤이든 국장은 서신에서 "필수 사항을 준수하기 위해 CIA는 적절한 심문 과정을 계획했다"며 "이 방법을 사용하기 전 CIA는 이를 재검토하고 사법부와 다른 행정부의 승인을 얻었다"고 밝혔다.',
#  '한요셉 한국 대우 증권 전략투자 담당자는 FRB의 전격적인 금리인하에 대해 “올바른 결정”이라고 평했다.',
#  '과우 투는 반 정부 운동가이자 코미디언으로 알려진 그의 동료 자가나와 함께 숨어 있다가 지난 달 26일 체포됐다.',
#  '지난해 브릿 어워드에서 여성 솔로 아티스트 상을 수상했던 와인하우스(24)는 지난 1년간',
#  '누리 알 말리키 이라크 총리는 이번 테러와 관련, 과격 수니파들을 비난했다.',
#  '우울하고 귀에 거슬리는 음악이 흐르는 이 영화는 한국의 건국 신화를 소재로 하여 인간이 낙원에서 타락한 현대 생활로 추락하는 것을 묘사하고 있는 것일 뿐 결코 성애를 다룬 것이 아니다.',
#  '얼마전 이란은 이라크 군을 훈련시키고, 군수물자를 제공하겠다는 제안을 한 바 있다.',
#  "식품의약국은 '캔 속 스피드', '액상 코카인', '코카인 순간 돌진' 등의 문구를 포함한 음료 라벨과 웹사이트를 증거로 언급했다.",
#  '지난 토요일, 정상들은 기후 변화에 대응할 조치의 필요성에 대해 합의했다.',
#  '일간 미니반은 웹사이트에서 "가윰 대통령이 이번 공격 후 대국민 라디오 연설에서 자이샴에게 감사를 전했으며 국민에게 냉정해지라는 요구를 했다"고 전했다.',
#  '2교대, 3교대 근무를 하는 어른들은 자신들이 완전히 시간감각을 잃었다는 것을 종종 알게 된다.',
#  '지난 5월 대규모 지진으로 7만명 사망하고 수많은 이재민이 발생한 재해지역 복구 작업에 대한 지출도 가속화될 예정이다.',
#  '끼니를 거르는 빈민층이 많은 인도 사람에겐 야구가 가난에서 벗어 날 수 있는 기회를 상징했다.',
#  '인간에게도 치명적일 수 있는 H5N1 바이러스로 영국에서 격리 중이었던 앵무새가 죽은 뒤 애완용 새를 통한 감염 우려가 거세졌다.',
#  '편 이날 오전 10시 미 인구조사국은 지난 3월의 새로운 주택시장 판매 가격을 공개했다.',
#  '나초를 준비하셨나요? “오늘은 43회 슈퍼볼이 있는 주의 중간지점인데 아직 두 가지 의문점이 남아 있습니다.',
#  '24시간 사업은 서비스 분야에서 진정한 성장을 하였다.',
#  '결국 그는 이 노래를 롱아일랜드 출신의 싱어송라이터 캐스 딜런(21)에게 양보했다.',
#  '우리가 기지를 살펴보고 있을 때 흰색 차량을 탄 경비원들은 멀리서 우리를 지켜보고 있었다.',
#  '수색반은 8일 밤 사망자 7명의 시신과 함께 이 비행기의 잔해를 발견했다.',
#  '리스는 1997년 8월 31일 교통사고로 심한 부상을 입었고 사고 이후 침묵하라고 위협하는 익명의 전화와 서신을 받았다고 진술했다.',
#  '알지베리 분석가는 “아시아 회사들은 비종교적인 문제나 인종 문제와 연루되지 않았다"며 "이같은 조건은 그들에게 유리하다" 고 말했다.',
#  '필립 젤리코우 진상조사위원장은 “이런 급박한 상황에 대비한 훈련을 받지 못했거나 이를 겪어보지 못한 못한 정부 당국이 섣부른 시도로 임시 방편적인 방어를 했다”고 전했다.',
#  '이 보고서의 공동집필자이며 콜로라도 국립 대기 연구소의 패트리시아 로메로 랑카오는 온난화 폐해가 진행되고 있으며 예상보다 빨리 진행되고 있다고 말했다.',
#  '매케인은 이날 미국 네바다 레노에서 열린 선거유세에서 “오바마 상원의원은 2년도 더 지난 시기에 한 차례 이라크를 방문한 적이 있다”며 “이후 데이비드 퍼트레이어스 장군이 증인으로 참석한 청문회에 참석했을 뿐 이라크에 다시 가지 않았다”고 말했다.',
#  '코소보 내 소수 세르비아계는 코소보의 독립을 반대한 반면 다수인 알바니아계는 코소보의 독립을 원해왔다.',
#  '캔자스 검찰은 기소장을 통해 공화당 소속 마크 델리 실잰더 전 미시건 하원의원에게 돈세탁, 사법방해 등 모두 42개 혐의가 적용됐다고 밝혔다.',
#  '부시 대통령은 "새로운 심문 과정에서 주바이다로부터 입수한 정보로 알카에다 요원 람지 빈 알 시브를 조사하게 됐고 주바이다와 알 시브에게서 입수한 정보로 2001년 9.11테러를 주도한 카리드 세이크 모하메드를 조사하게 됐다”고 밝혔다.',
#  '한편 템펠호프 공항은 지난 1923년 개항했으며 나치 정권에 의해 거대한 말편자 모양으로 재건축됐다.',
#  '반기문 유엔 사무총장은 9일 소말리아에 인도주의적 위기가 증가하고 있다고 경고하고 150만명에게 인도주의적 지원이 필요하다고 밝혔다. 유엔은 또한 올해 초 이후 난민이 50% 증가했다고 말했다.',
#  '이레주 바라수아는 경관은 “피랍된 여아의 이름은 마가렛 힐이며 교통정체로 서있는 자동차에서 낚아채 납치됐다”고 설명했다.',
#  '정부는 전국 매춘 시장 규모가 10억파운드(약 2조원)에 달한다고 밝혔다.',
#  '그들이 여자가 아니었다면, 우리는 그 자리에서 살해했을 것이다.”',
#  '체세포 복제 배아줄기세포 연구를 조작한 행위로 황 교수를 비롯, 교수의 동료들에게 형사상의 책임을 물어야 하는지 결정하기 위해서이다.',
#  '백두산은 북한에서 가장 높은 산이고, 한라산은 남한에서 가장 높은 산이다.',
#  '오는 17일 뉴델리에서 열리는 베이징올림픽 성화 봉송 행사를 주관하는 인도 올림픽 위원회는 이번 성화봉송주자로 인도의 유명한 운동선수인 축구선수 부티아를 비롯, 육상선수 P.T.',
#  '항공사는 유럽행 비행기표용 총계 견적서 발생 필수',
#  '하지만, 평양은 이 송금을 확인하기 전까지는 사찰단의 방문을 확인하지 않겠다는 입장이다.',
#  '미 공군 예비군 비행대는 성명에서 지난 8일 F-16 전투기들이 텍사스 시골마을인 스티븐빌 부근 브라운우드 군사구역 상공에서 야간 훈련을 벌였다고 발표했다.',
#  '달라이라마는 또 “국제사회는 중국 정부가 화합적인 사회와 평화적인 권리를 지향하기를 기대하고 있다”고 주장했다.',
#  '그리스 남부에 한 차례의 강력한 지진과 동일한 강도의 여진이 14일 정오(현지시간) 발생했다고 미국과 그리스의 지질 전문가가 밝혔다.',
#  '그는 농득마인 서기장을 면담하면서 흰 가두리 장식을 넣은 검은색과 적색이 혼합된 보온복을 착용했다.',
#  '이 결의안은 또한 과거 마약 밀매 및 위조등을 포함한 불법 행위를 했던 것으로 믿어지는 북한 노동당 부서가 폐지되었다는 증거도 요구했다.',
#  '˝이스라엘 수상 에후드 올메르트는 팔레스타인 지도자 마흐무드 압바스가 이끄는 파타 무장 세력 중 수감된 250명을 석방하기로 계획하고 있다고 밝혔다.',
#  '이 前 시장은 한국 경제발전에 충주적인 역할이 될 것임을 밝혔다.',
#  'The U.S. troops in Korea will cut the number by one-third.주한 미군, 3분의 1로 감축 예정2005.08',
#  '˝파키스탄의 북 와지리스탄 지역의 탈레반 지지 무장 단체는 정부와의 휴전 협정을 종결시켰다고 발표했다.',
#  '흑색종을 치료하거나 그 상태에서 활동을 멈추게하는 보다 좋은 방법을 찾고 있는 중이다.',
#  '귀국 전, 송 교수는 외국에 거주하면서 수십 년 간 자발적 망명 생활을 했었다.',
#  '이에앞서 이슬람 근본주의 세력이 19일 빈 라덴의 육성이 곧 공개될 것이라고 주장했다.',
#  '사마귀를 위한 시메티딘, 불면증을 위한 클로니딘, 그리고 언어장애를 위한 베싸네콜은 아직은 Drug Evaluations나 US Pharmacopoeia Drug Information에 게재되는데 성공하지는 못했다.',
#  '상사라면 문제를 피해야 한다.',
#  '폭격 후 발견된 비디오를 분석한 결과 이라크 알카에다가 한 때 동맹관계를 맺었던 수니파 무슬림을 적으로 간주하기 시작했다고 연합군 정보장교가 밝혔다.',
#  '이는 내가 미군을 보호하려 노력한다는 것을 의미한다"고 그는 말했다.',
#  '연구진은 GPS로 야행성 동물에 대한 자료 수집에 한계가 있으나 8분간격으로 수집된 자료에서 밤 동안 얼룩말 행동양식를 연구했다.',
#  'IMF는 올 미국의 경제성장률은 0.5%로 17년 만에 최악을 기록할 것이라고 예상했다.',
#  '일부 근로자들은 정신적인 질환도 앓고 있으며 고독감으로 인해 사망할 수 있다.',
#  '2주 전에는 장난감에서 유해한 납 성분의 페인트가 발견돼 150만개 이상의 장난감이 리콜 처리됐다.',
#  '그들 중에 김지원씨가 있었다.',
#  '1960년대 미국 예일 대학의 한 젊은 심리학자가 현재 심리학 분야에서 가장 전반적으로 인정 받고 있는 실험을 시작했다.',
#  '그러나 WHO는 보고서에서 1차 보건 위생의 보급에 대한 전반적인 개혁을 요구하는 반면 정부 지출이 항상 문제가 되지 않는 점도 지적했다.',
#  '엘리자베스가 태어난 뒤 워커는 상대자와 헤어졌다.',
#  '아마도 그들이 정원에서 놀고 있을지 모른다.',
#  '경찰은 버스 정거장에 있는 노왁을 발견했다.',
#  '조 토리 다저스 감독은 내일 필라델피아에서 양 팀의 경기가 있다고 언급하면서 팀이 다시 실력을 회복해야만 할 것이라고 말했습니다.',
#  '부시 대통령은 여러차례에 걸친 회담의 시작으로 올해 가을 주요 온실가스 방출국을 한자리에 모으기로 했다.',
#  '로한(21)은 LA카운티 린우드 교도소에 16일 오전 10시30분에 수감됐다.',
#  '아메리칸 리그가 10일(현지시간) 열린 메이저리그 올스타게임에서 올스타 역사상 첫 그라운드 홈런을 기록한 스즈키 이치로의 활약으로 내셔널 리그를 5 대 4로 제압했다.',
#  'put out 진화하다, 불을 끄다',
#  '스티븐 호킹, 미국의 이라크 침공 비난2005.08',
#  '대통령 선거전이 막바지에 이름에따라 더 많은 신문들이 지지 후보를 밝히고 있습니다.',
#  '2018년 동계올림픽 유치에 경쟁하고 있는 세계 도시는 카자흐 공화국의 알마티, 한국의 평창, 독일의 뮌헨, 미국 네바다주 리노타호 등이다.',
#  '남성은 여성보다 키스를 하지 않고 성관계를 갖는 경우가 많을 뿐 아니라 매력을 느끼지 못 하는 상대나 키스를 못하는 사람과도 성관계를 맺는다.',
#  '중국이 한국과 중국 간의 고대사를 왜곡하려는 시도와 관련, 정부 여야가 한 목소리로 비난하고 나섰다.',
#  '그녀는 아이에게 "그건 내가 너를 무시해서가 아니란다.',
#  '그는 책을 본 뒤 이 책에 있는 사실을 알려야겠다고 생각했다.',
#  '2개의 이동병원을 추가해 운영하고 있는 이 병원은 당나귀에게 편자를 끼우는 방법과 적절한 치료법을 가르치고 있으며 이를 전국적으로 알리려 노력중이다.',
#  '코리아 타임즈는 외교통상부가 공식 웹 사이트를 통해 “외국인 을 상대 로 한 테러 공격과 납치 사건이 이 기간 동안 더욱 많아질 것으로 예상된다”며 주의를 당부했다고 보도했다.',
#  '“생산직 근로자에 이어 저희는 오로라, 디케이터 그리고 피오리어 동부에서 416명의 지원직과 관리직 인력에게 사직 통보를 한 상태입니다.”',
#  '이 작품은 NBC의 공상과학 시리즈의 히트작으로 TV 산업의 기대와 상상력을 북돋았다.',
#  '교착상태에 빠진 북핵 문제에 대한 6자회담의 참가국들은 주말 동안 양자 접촉과 실무급 회의에 전념하며 첫 합동 결의문인 공동문건 초안을 놓고 협의를 계속하여 그 결과 네 차례의 협상이 끝날 것으로 보인다.',
#  '그는 지구 위치 시스템과 기상 관측소의 네트워크를 통해 얼음의 변화를 모니터했다. 그 결과 1990년대 중반부터 기온이 극적으로 높아진 것으로 확인됐다.',
#  '고 토니 스노우 백악관 대변인이 기자회견을 통해 말했다.',
#  '“이라크 내무부는 종파로 분열돼 기능장애를 겪고 있으며 경찰은 해산 후 재소집 할 필요가 있다”',
#  '그는 오랫동안 쿠르드족을 이끈 자신의 아버지가 요르단 수도 암만으로 떠났다고 해서 그의 건강상태가 위중한 것은 아니라고 밝혔다.',
#  '한림원은 수상 이유에 관해 “자유 무역과 세계화의 효과에 대한 정의와 세계적 도시화 뒤에 숨겨진 추진력이 무엇인지 설명하기 위해 파울 크루그먼 교수는 이들 문제에 대한 해답을 위한 새로운 이론을 체계화했다”고 설명했다.',
#  '붕괴된 다리는 약 100m 길이며 수르켓에 내린 눈이 녹아 흘러드는 베리 강에 세워졌다.',
#  '750만 인구로 캐나다에서 두번째로 많은 인구를 차지하고 있는 퀘벡주를 기반으로 하는 이 당은 그동안 퀘벡주의 독립을 요구했다.',
#  '요세프는 이란에 있는 친척들을 보호하기 위해 성은 밝히지 않았다.',
#  '매일 평균 600만명의 발이 돼 인도 뭄바이 경제를 쉬지 않고 돌아가게 해주는 원동력이 있다.',
#  '한편 로이 학장은 “조는 똑똑한 학생이었다”며 “그러나 친구들과 교수들을 무기력하게 만들었다”고 지적했다.',
#  '루이스 의원은 일찍이 공화당 대선 운동의 부정적인 어조는 인종차별주의자인 조지 월레스 주지사가 1960대에 조성했던 불쾌한 상황이 연상된다고 말했었습니다.',
#  '모스 대변인은 “테네시주 르느와르시에 거주하는 버거는 큰 부상을 입지 않았다”고 26일 전했다.',
#  '이스라엘 라디오 방송은 미국이 이 레이더를 운영할 전문가들도 보냈다고 보도했습니다.',
#  '130달러 (약 19만원) 소프트웨어의 유형성에 대한 다른 의견을 가진 사람들을 위해 아이파이(Eye-Fi)는 최근 이전 모델보다 용량을 2배 확장한 4기가 기념 버전 SD메모리카드를 공개했다.',
#  '벨기에에서 5일 발표 예정인 기후 변화에 관한 두 번째 보고서의 중요 요소는 온도상승 정도와 지구 온난화를 정밀하게 표시한 차트다.',
#  '과학과 오락물을 접목시키는 크라이튼의 능력은 블록버스터 영화로도 제작된, 그의 가장 유명한 공룡 소설에서 극에 달했습니다.”',
#  '우주비행사 빌 앤더스와 짐 러벨이 성서구절을 각각 읽은 다음 지휘관 프랭크 보먼은 작별인사를 했습니다.',
#  '아마도 느껴보지 못한 사람은 모를것이다.',
#  '범인은 경찰들이 건물을 에워싸기 전까지 몇 시간 동안 교회에 숨어 있었다. 교회 안에서 다른 남자의 시신이 발견되었다.',
#  '볼티모어 레이븐스는 타이탄스와의 AFC 경기를 위해 테네시에 와 있습니다.',
#  '이라크 정부 고위관계자는 무술이 최근 이라크에서 활동하고 있는 알카에다의 최대 거점이라고 말했다.',
#  '그는 “악천후로 지정된 투표소가 폐쇄된 제퍼슨 카운티 주민들은 스튜벤빌 군청 소재 선관위 사무실에서 투표를 할 수 있다”고 전했다.',
#  '안보리는 이미 이란이 유엔 핵 파수꾼인 국제원자력기구(IAEA)의 회담 요구를 거절한 것에 대해 제재를 가한 바 있다.',
#  '교황 요한 바오로 2세, 급작스러운 호흡 곤란으로 응급 수술\xa0 \xa0 \xa0',
#  '35세의 이 여성은 서울에서 부산으로 가는 비행기 안에서 승무원의 제지를 무시하면서 회사 동료와 약 5분 간 통화를 계속했다.',
#  '지난 1월 3일 캘리포니아주 할리우드에서 민주당 대선후보 토론회가 열린 후 많은 변화가 있었다.',
#  '위성미는 LPGA 투어에서 공동7위에 올랐으며 그의 젊음과 패기 때문에 가장 많은 갤러리를 몰고 다녔지만 그에 대한 특별 대우 때문에 선수들로부터 존중 받지 못했다.',
#  'GM, 포드, 그리고 크라이슬러는 의회에 사업개선에 대한 청사진을 제시할 것이라고 확답했습니다.',
#  '미국 내 에서 실시된 여론조사에따르면 천주교도의 50%가량이 낙태를 지지하는 것으로 밝혀졌다.',
#  '호킹 박사(65)는 24일 AP 통신과의 인터뷰에서 “나처럼 근육이 잘 움직이지 않는 사람이 무중력 상태를 체험하는 것은 큰 행복”이라고 말했다.',
#  '도시와 지방간 이분법적 논리는 빈부격차를 더 심화시킨다.',
#  '하와스 위원장은 투탕카멘 미라가 석관에서 이관된 2년 전부터 과학자들이 파손된 이 미라의 복원작업에 착수했으며 최초로 CT 촬영을 했다고 말했다.',
#  '9/11 테러 3주년 추도식이 뉴욕시와 알바니에서 거행된다.',
#  '떼뽀스떼코(Tepozteco)',
#  "“동성결혼의 지지자들은 '동성애자 없는 날'을 선포하고 결근과 불매운동, 자원봉사, 그리고 시위 등을 벌였습니다.",
#  '한때 위험했던 허리케인 팔로마는 오래 지속되지 않을 열대 폭풍우로 변했습니다.',
#  'AP News Minute(US Navy Warship Has Arrived off the Coast of Somalia and More)AP 뉴스 미닛(미 해군 전함, 소말리아 연안 도착 외)2009.04',
#  '수사관들은 아이의 할아버지가 거래상들로부터 수백만 달러를 훔쳤을 가능성이 있다고 전했습니다.',
#  '유럽, 미국, 호주에서 온 도움의 메세지들이 이 사이트에 올려졌다.',
#  '탁신의 부인인 포자만은 국유지 매입 자격이 없는데도 불구하고 방콕의 대지를 정부 산하기구인 ‘금융기관개발기금’으로부터 시중보다 낮게 매입한 것으로 드러났다.',
#  '수십 년간 독재정권을 장악해온 로버트 무가비 짐바브웨 대통령을 상대로 대선에서 승리했다는 모건 츠방기라이 야당 지도자의 주장과 대선공식결과 발표가 늦춰지자 국민들의 원성을 늘어나고 나라 곳곳에서 폭력사태가 발생했다.',
#  '일부에서는 이 승용차가 안전과 배기 기준을 맞췄는지 많은 의심을 하고 있다.',
#  '한편 슈퍼볼 경기 중 방영되는 중간광고의 가격은 30초당 270만 달러에 거래됐다.',
#  '블랙스버그 병원 의사는 16일 자신이 목격한 환자의 모습은 놀라울 정도였으며 범인은 잔인한 인물이라고 말했다.',
#  '키트는 특이한 목소리로 유명하며 자신을 TV 연속극 ‘배트맨’에 나오는 캣우먼(Catwoman )이라고 칭했다.',
#  '이들은 주식을 헐값에 사들이기 위해 투자자들에게 허위 정보를 제공함으로써 2003년 11월 외환카드 주가를 조작했다는 혐의를 받고 있는데, 이중 법원은 스티븐 리에 대한 영장신청을 제외한 나머지 인원에 대한 영장 청구는 기각한 것이다.',
#  '그는 “농민을 지원할 모든 노력을 다할 것이며 더 이상 식량 부족 사태가 없도록 할 것”이라고 밝혔다.',
#  '14년만에 처음으로 빌 게이츠 마이크로소프트 회장과 나란히 앉아 인터뷰를 나누게 된 잡스는 미리 게이츠에 대해 관대한 평가를 내렸다.',
#  '매카트니는 수상소감에서 “영국 음악이 최고라 생각한다”고 밝혔다.',
#  '아랍계 방송 알-아라비아는 26일 자신의 이름을 피터 무어라고 밝힌 한 영국인이 8개월 째 감금되어 있다는 말을 전하는 동영상을 공개했다.',
#  '게다가 수백만 명의 사람들이 수입과 일자리를 찾아 도시 지역으로 이주하였다.',
#  '호나우두는 첫 골을 성공시킨 후 3분만인 전반 13분에 멋진 프리킥으로 제임스 골키퍼를 꼼짝하지 못하게 만들었다.',
#  '영국, 프랑스, 독일, 이탈리아, 스페인에서 영국 파이낸셜타임즈가 실시한 여론조사 결과 응답자의 70%가 이 조약에 대한 비준을 투표로 정해야 한다고 생각하는 것으로 나타났다.',
#  '영국의 인종 평등을 위한 위원회는 채널 4는 이 문제를 해결하기 위해 발빠르게 대처, 문제는 완화됐다고 성명했다.',
#  'IFAW 소속 긴급구조 담당자인 루오폴로 박사는 기름 유출로 피해를 입은 펭귄과 다른 동물 구조에 대한 경험이 많았다.',
#  '관리자는 나체 사진에 나온 여학생들은 자신의 사진을 남자친구인 남학생들에게 보냈고 이들 남학생들이 다른 학생들에게 이들의 사진을 보냈다고 밝혔다.',
#  '고유가, 수요 증가, 불공정 무역거래, 근거 없는 소문에 의해 사재기 등이 전세계적으로 식료품 가격 폭등을 몰고 왔다.',
#  '토마스 스테처 형사는 기자회견에서 “범인은 거의 무표정했다”고 전했다.',
#  '라이스 장관은 바바칸 장관과의 회담에 앞서 오는 5일 조지 W 부시 대통령과의 회담을 앞두고 있는 에르도간 총리를 접견했다.',
#  '샌안토니오는 15일(현지시간) 열린 클리블랜드 원정경기에서 시리즈 MVP에 빛나는 토니 파커가 24점, 동료인 마누 지노빌리는 4쿼터에서만 13점으로 넣으며 27점을 올려 팀이 83-82로 승리하는데 결정적인 역할을 했다.',
#  '팀 도너히는 13년간 NBA 경기를 맡아온 베테랑 심판이며 지난해 7월 9일 사직했다.',
#  '파키스탄 야당 지도자인 임란 칸 역시 미군이 대규모 병력을 파키스탄-아프간 부족지역에 보낼 경우 상황은 더 악화될 것이라고 주장했다.',
#  '나는 체코 공화국의 작은 마을에 있는 술집에서 돼지고기와 토마토를 먹고 있었다.',
#  '유엔 인권위원회가 희생자 및 목격자들의 증언을 토대로 작성한 보고서에따르면 지난해 12월 반군이 장악하고 있는 다르푸르 남부 데리바트에서 50명의 여성이 민병대로부터 성적 노예 역할을 강요당했다.',
#  '노스캐롤라이나 징계법원의 배심원단은 노스캐롤라이나 더햄 카운티의 주법무장관인 마이크 니퐁 검사가 무죄가 입증된 선수들을 상대로 10여 차례 윤리 강령을 위반했다고 지적했다.',
#  '리셴룽 총리와 그의 아버지인 리콴유 전 총리는 치순주안 싱가포르 민주당 대표와 당 위원들이 국립신장재단과 관련, 논란에 대한 정부의 처리를 비난하는 기사를 작성한 것에 대해 소송을 제기한 상태이다.',
#  '산부인과 전문의이며 여성 보관에 관한 3권의 책을 집필한 크리스티안 노스럽 박사는 보안의학과 대안 치료에 대해 집중 소개하는 불임전문센터 ‘퍼틀 소울 앤드 퍼틀 하트(The Fertile Soul and Fertile Heart)’를 추천했다.',
#  '교황이 사제로부터 성추행을 당한 신도를 만나 위로하는 것은 이번이 처음이다.',
#  '그는 “사람들과 기본으로 돌아가고 있다”며 “사람들은 생활활동에서 저렴한 가격들로 구매하려고 하고 좀더 적당한 가격에 구매할 수 있는 기회를 얻을 수 있는 방향으로 나아가고 있다”고 말했다.',
#  '한국과 유럽 연합은 지난 목요일, 양측간의 자유 무역 협정에서 관세 절감을 위한 협상을 계속하였으나, 해결책을 찾는 데 실패했다고, 한국측 협상단장이 발표했다.',
#  '넬슨은 “딸이 산타클로스가 형제가 있을까 물었을 때 산타클로스는 형제가 있다고 말해주고 곰곰히 생각했다”며 “산타클로스는 완벽하기 때문에 그의 형제는 매우 힘들었을 것"이라고 밝혔다.',
#  '그는 “오바마 당선인은 많은 사람들에게 희망을 줬으며 국가에는 이득이다”러고 말했다.',
#  '마크 비트너는 "11월 CCI 상승은 미국 대선이 끝나고 이에 대해 저절로 반응했던 것으로 보인다”며 “11월의 잘못된 분석이 예상치를 너무 높게 끌리면서 12월에는 실망감으로 이어졌다”고 덧붙였다.',
#  '짐바브웨의 야당 지도자와 정부 장관은 로버트 무가베 대통령 퇴진에 대해 협상이 타결되었다는 보도를 부인했다.',
#  '중소기업의 절반이 2년 이내 해외 이전 계획\xa0 \xa0 \xa02005.08 ',
#  '정부가 테러범들을 비난했을 때 정부가 거짓말을 했다고 말한 것 때문에 사과해야 하느냐”고 말했다.',
#  '어린이들은 따라하기 쉽고 도덕이나 가치 시스템이 채 정립되지 않았기 때문에 아무런 질문이나 저항없이 말문이 막힌다고 그녀는 말했다.',
#  '그러나 시디크 대변인은 추방된 2명이 탈레반과 접촉하려했다는 사실은 부인했다.',
#  '나는 갈수록 점점 더 화가 났다.',
#  '앤더슨 대변인은 파커(25)를 인용 “나는 부인을 사랑한다”며 “그녀는 내 인생에서 그 무엇보다 소중하며 이렇게 행복했던 적이 없었다”고 밝혔다.',
#  '마리아 슈라이버 캘리포니아 주지사 부인 등 500명여명의 입장객들이 티켓 값으로 2500달러(약 230만원)를 지불했다.',
#  '우고 차베스 베네수엘라 대통령은 21일(현지시간) 쿠바에서 열린 중남미 석유정상회담을 주관한 자리에서 더 많은 국가가 값싼 석유 대금을 현금 대신 상품과 서비스로 지불할 수 있도록 하겠다고 밝혔다.',
#  '한편 34일간의 전쟁으로 1035명에서 1191명의 레바논 시민과 119명의 이스라엘 군인들, 39명의 민간인으로 구성된 전투자들이 숨졌다.',
#  '한국의 국가 이미지는 일본이나 미국보다 덜 우호적”이라고 말했다.',
#  '미탈리포브 박사는 “만일 1회 연구분량의 세포를 얻기 위해 난자 10개가 필요한 것을 5개로 낮추는 연구가 진행된다면 임상에 적용하기가 더 쉬워질 것”이라고 말했다.',
#  '영국에서 발생한 테러와 관련된 8번째 용의자가 2일(현지시간) 호주에서 체포되며 런던 중심가와 스코틀랜드 글래스고 공항 테러 시도와 관련된 수사망이 전세계적으로 넓혀졌다.',
#  '처음으로 경제부총리가 2007년 한국 경제성장률을 올해보다 낮게 전망했다.',
#  '코리아 타임즈는 북한이 미국의 대북한 적대정책에 대한 전쟁 억제력으로 폐연료봉 8천개의 재처리를 완료해서 “무기화했다”는 북한 고위 관리의 주장에 한국이 큰 신경을 쓰고 있지 않다고 보도했다.',
#  '화환에는 “명예로운 죽음을 기억하며” 라고 적혀있었다.',
#  '백악관은 성명을 통해 “부시 대통령은 또한 중국 정부에 달라이라마측 대표단과의 실질적 대화를 촉구하고 언론과 외교 관계자들의 현장 접근을 허용해 줄 것을 요청했다”고 전했다.',
#  '악천후와 가혹한 환경 때문에 적은 수의 구조대만이 추락 지점에 도달할 수 있었다.',
#  '국회 국세청 감사에서 이주성 국세청장은 “올해 내로 조사를 끝낼 것”이라고 전하며 지난 몇 달 동안 대규모 외국계 펀드 2곳과 중소 외국계 펀드 4곳에 대해 세무 조사를 실시해 왔다고 밝혔다.',
#  'FBI는 중국 광동 지방의 소프트웨어 생산 공장을 급습하기 전에 수년간 불법 복제 조직을 대상으로 수사를 해 왔다고 말했다.',
#  '이번 집회는 하마스가 가자지구를 점령한 이후 처음 열린 파타 주재의 집회로 이미 총격전이 있을 것으로 예상됐었다.',
#  '경찰은 총격을 입은 49세의 여성과 12세의 남자아이가 중태라고 발표했다.',
#  '수사관은 지난 열차 폭탄 테러가 알-카에다 테러 단체 소속 이슬람 투사들의 소행이라고 추정하고 있다.',
#  '정부 수사팀과의 공조수사로 검찰은 2005년 7월 이후 부동산 투기와 관련하여 불법을 저지른 9,789명을 찾아냈으며, 그중 344명을 구속했다.',
#  '한편 민주당 거점인 샌프란시스코에서는 민주당이 공화당에게 무릎을 꿇자 부시의 승리에 크게 실망한 사람들이 선거 결과에 따른 지역 득표율 결과를 수정하는 것조차 할 분위기가 아니었다.',
#  '런던 국제석유거래소(ICE)에서 북해산 브랜트유는 전거래일 전일 종가대비 14센트 내린 98.42달러에 거래를 마쳤다.',
#  'rocket-propelled grenade 로켓발사 유탄, 휴대용 로켓 발사기, 휴대용 대전차 로켓',
#  '내 블로그에 저장 美 유력 신문사, 경기악화로 신문배달 중단',
#  '지역 교육청의 오완수 수석 주임은 “교장, 선생, 학생들에 대한 조사가 마무리되자 마자, 책임이 있는 사람들은 중한 처벌을 받게 될 것”이라고 언급했다.',
#  '이번 주 버락 오바마는 (대출금 상환불능에 따른) 주택 압류에 대해 90일의 지불 유예 기간을 줄 것과, 새로운 일자리를 창출하는 기업에 대해서 2년간 세금 우대를 해주는 방법을 제안했습니다.',
#  '극우익인 샘 브라운백 상원의원은 월요일 상원 결의안 399를 제출했고 지금 까지 단 세 명의 발기인을 모았다.',
#  '그러나 홍콩의 미니 헌법 역시 체제 전복 금지법을 통과시키도록 규정하고 있다.',
#  '보석과 지갑 조각 등 아프리카 상품을 취급하는 ‘아프리칸 파라다이스’(African Paradise)는 내년 1월 중순까지 27W.',
#  '프레이저는 지난 4월 약 30년간 짐바브웨를 통치한 무가베에 대해 “선거결과를 부정하고 있다”며 “국민들과 선관위 관계자들을 협박하고 있다”고 지적했다.',
#  '윌리엄 왕자는 치누크 헬기를 여자친구인 케이트 미들턴의 가족 소유지에 착륙시키면서 조종사 훈련에 대한 논란을 일으켰다.',
#  '러시아와 이란, 핵 연료 공급 협정 체결\xa0 \xa0 \xa0 ',
#  '그는 정오부터 오후 7시까지 매주 2번 오전 7시부터 다음날 오전 10시까지 1번 모두 3일을 아이들과 보낼 수게 된다.',
#  '그는 이라크 주둔 미군 2개 부대가 16개월에 걸쳐 철수 한다는 것에 지지의 입장을 밝혔다.',
#  '일본 화재 재난 관리 본부는 재난 구조를 위해 군인 약 30명을 파견했고 군 항공기는 피해지역을 조사하고 있다.',
#  '북한이 마카오 은행에 동결된 250만 불을 회수할 때까지 핵개발 폐기를 위한 6자 회담에 참여하기를 거부하자 베이징 6자 회담은 난항에 빠졌다.',
#  '미 국무부, “6자회담도 소용 없어질 수 있다”\xa0 \xa0 \xa02005.08',
#  '하지만 부시 대통령은 14일 미국이 이란과의 전쟁 명분을 만들고 있다는 것은 터무니 없는 주장이라고 이와같은 사실을 일축했다.',
#  '연비가 낮은 이들 "경 트럭"의 판매량은 1996년에서 1999년 사이에 2배 이상 늘어 났다.',
#  '오늘날 공산국 점원들은 서울의 백화점 사원처럼 계산기로 신속하게 미(美) 달러와 유로 및 한국 원화까지 취급했다.',
#  '야후 대변인인 짐 쿨리넌은 국제앰네스티 미국 지부가 샌프란시스코 지방 법원에 소송을 제기한 것에 대해 언급하지 않은 채 “이 문제는 법적인 방법보다는 외교적인 차원에서 해결하는 것이 적합하다”고 밝혔다.',
#  '투시 카메라를 설치할 때 보행 흐름이 밀리는 장소, 횡단보도 앞 신호등 대기장소, 보안 검색대에는 되도록이면 설치하지 않는다.',
#  '안톤 샤로노프 지방정부 대변인은 러시아의 수도 모스크바 남동부에 위치한 펜자의 한 동굴에서 그들과 함께 생활하던 중 밖으로 나온 비탈리 네도곤이 러시아TV와의 인터뷰에서 종말론자 2명이 숨졌다고 전했다.',
#  '일본 천황탄생일인 12월 23일과 신년인 1월 2일만 왕궁을 일반에 공개하면 왕실은 먼 곳에 온 방문객의 방문을 맞이한다.',
#  '이 수치는 미국의 두뇌 집단인 지구개발센터가 취합하였다.',
#  '그는 “콩고에서의 소년병 모집은 위법이며 시에라리온에서는 소년병을 모집한 것에 유죄를 선고한 판결이 있다”고 말했다.',
#  'freight 화물(운송), 화물을 싣다, (책임, 부담 등을)지게 하다, 수송하다',
# ...
#  '15세 이상 여성의 경우 취업률이 48.8%에 그친 데 비해 남성은 71.3%로 한참 앞서고 있다.',
#  '잘 팔린 다른 제품은 가민(Garmin) GPS 시스템, 애플 맥북(MacBook), 키친에이드(KitchenAid) 믹서기였다.',
#  '기자는 관할 공산당 서기관이 이번 행사를 정치 선전으로 이용했다고 주장했다.',
#  '그러나 베컴은 레알 마드리드의 라인업에 복귀했고 지난해 팀이 프리메라리가를 우승하는데 기여했다.',
#  '인질들의 건강 상태는 양호한 것으로 알려져 있지만, 무력으로 그들을 구출하려는 시도가 있거나 정부가 탈레반 수감자들을 조속히 석방하지 않으면 이들을 살해하겠다고 반군 측에서는 협박하고 있다.',
#  '그는 “우리는 1명 당 컴퓨터 1대를 대수롭지 않게 여길 것"이라며 “상호작용이 가능해 컴퓨터를 사용하는 환경에서 여러 사람들이 같이 업무를 하게 될 것”이라고 말햇다.',
#  '여야, 12개 부처 이전에 합의\xa0 \xa0 \xa0',
#  '스펙터 의원은 “상원의원으로서의 책임 및 업무를 다하고 6선을 위해 선거운동도 할 것이다”며 “동시 에 12주간 지속될 키모요법치료를 받을 예정이다”고 전했다.',
#  '그러나 사인을 조사하던 중 사건은 미궁에 빠졌다.',
#  '그레이스 랜드에서는 1주일에 걸쳐 현악기 콘서트, 댄스 파티, 영화 상영 등의 특별 행사가 열릴 예정이다.',
#  '그러나 불스는 경기 종료 10분전 안드레스 노치오니의 3점포로 리드를 잡았으며 경기 막판 게임의 주도권을 장악했다. 불스는 경기 종료 전 기록된 8골을 모두 넣었다.',
#  '▶관련 동영상 보기 ##http://article.joins.com/article/cnn_e/article.asp?cat_code=22&Total_ID=2668116',
#  '바예스테로스는 지난주 마드리드 바라자스 공항에서 쓰러져 뇌종양 진단을 받았다.',
#  '이날 파키스탄 북서부 지역에서 발생한 또 다른 폭력사태로 군인 3명이 사망하고 민간인 4명이 부상했다.',
#  '장관과 재계인사 등 30여명이 노대통령을 수행하고 있다.',
#  '그는 “사람들은 내가 안테나 회사를 운영할 것이라고 말하자 비웃었다”고 밝혔다.',
#  '매퀸는 협상이 불가능한 300만달러를 제시했으며 더군다나 그는 필리핀 밀림에서 4개월간 계속되는 총격전을 하고 싶지 않았다.',
#  '파키스탄의 이번 미사일 시험은 인도발 파키스탄행 열차에서 폭탄테러가 발생한지 며칠 만에 이뤄진 것이다. 이 열차 사고로 69명이 사망했으며 사망자 대부분은 파키스탄인이었다.',
#  '갑작스런 조기 총선을 일주일 앞두고, 수 만명의 태국 시위자들이 방콕의 중심 쇼핑가를 행진했다.',
#  '하마스를 포함한 과격단체들은 자신들만의 1주일이 넘는 휴전을 선포하였으며, 이는 이스라엘이 10일간의 일방적인 휴전을 선포한지 수 시간 뒤에 발표되었습니다.',
#  '1987년 6월 10일, 일반 시민들과 함께 학생들과 노동자들이 국가의 경찰 기동대에 맞서 국가의 심장부를 향한 상징적인 전투를 벌였고, 이러한 대규모 시위에 대한민국 전체를 사로잡았다.',
#  '이날 수백 명의 조문객들이 세비오르 대성당으로 모여든 가운데 의장대와 군인들을 앞세운 장례행렬이 대성당에 도착했다.',
#  '상원은 모두 60석이다.',
#  '구스타보 랑겔 브리세노 베네수엘라 국방부 장관은 “미군이 의도적으로 베네수엘라 영공을 침범한 것으로 보인다”며 “미국 대사를 외무부로 소환해 설명을 요구할 것이다”고 수도 카라카스에서 열린 기자회견에서 발표했다.',
#  '이탈리아 시칠리아에서 한 어머니가 늦게까지 돌아다닌 다는 이유로 61세 아들의 집 열쇠를 가져가고 용돈도 끊은 채 아들을 경찰서로 데려갔다.',
#  '의문사한 안나 니콜 스미스(왼쪽), 하워드 K. 스턴과 대니얼린 회의 탁자 주변 에서 여러명의 변호사들이 시끄럽게 주장을 하자 래리 세이들린 판사는 얼키고 설킨 이해와 논쟁을 분류하려고 했다.',
#  '바바라 미컬스키 메릴랜드 주 민주당 소속 상원의원과 카이 베일리 허치슨 텍사스 주 공화당 소속 상원의원은 이달 백악관과의 우주항공 관련회의에서 10억달러(약 9384억원)의 NASA 예산 증가를 제시했었다.',
#  '올해 주한미군 방위 분담금 8.9% 감액\xa0 \xa0 \xa0 ',
#  '세 명의 네팔 직원과 세 명의 승무원, 통역, 정비사들은 아직 국적이 알려져 있지 않다.',
#  '앞으로 신병 모집에 비만이 가장 큰 걸림돌이 될 것이라고 육군 고위 모병 담당자가 밝혔습니다.',
#  '천 대변인은 피랍자 인도 계획과 관련 “납치세력과 협의할 것”이라며 “가급적 빨리 석방되도록 최선을 다할 것”이라고 말했다.',
#  '콜롬비아 중부지역에 지난주 내린 홍수로 14명이 사망하고 100명이 부상했으며 10만의 이재민이 발생했다고 당국이 28일(현지시간) 밝혔다.',
#  '국회의사당에는 자유당 소속의 데이비드 로이드 조지, 노동당 소속의 클레멘트 애틀리 전 수상들의 동상도 있다.',
#  '양측은 이미 5월초에도 합의안을 만들었지만 그 내용을 공개하지 않아 분열을 초래했다.',
#  '본 데 웨그는 리본에 독수리 한 마리가 새겨진 메달은 붉은 가죽 박스에 들어있으며 앞으로 마운튼버넌에 전시될 예정이라고 전했다.',
#  '레바논 남부에서 온 존경받는 시아파 성직자 알리 아민은 시아파 후원을 받는 야당인 헤즈볼라와 아말(Amal)이 정부와 합의 체결에 실패했다며 비판했다.',
#  '크레디 아그리콜 소속 후스호브드는 2005년 결승점 350m를 남겨놓고 스프린트를 해 남아공 출신 발로월드 소속 로버트 헌터를 추월, ‘그린 유니폼’을 입은 바 있다.',
#  '이번 국회의장 당선은 야당 지도자 라일라 오딩가의 승리였다.',
#  '카리 유수프 아마디 탈레반 대변인은 카르자이와 부시간 회담이 아무런 성과가 없었으며 수감자를 풀어주지 않을 경우 안좋은 결과가 발생할 것이라고 말했다.',
#  '금속제품 거래상인 오마르 오사마빈라덴(27)은 영국 태생의 부인과 함께 영국에서 거주하기를 희망했다.',
#  '치아파스 자연사 및 생태 연구소의 게라르도 카르보트는 이번주 디스커버리호에서 크라우가스터들이 지금 까지 이 지역에 서식하고 있다고 발표했다.',
#  "이씨는 이 같은 모진 시련 내내 '' 남한으로 돌아가 아들을 찾겠다’’는 남모르는 꿈이 자신을 지탱해 주었다고 말한다.",
#  '그는 할렘 마약밀매업자로 근육질의 몸을 보인 영화 ‘아메리칸 갱스터(American Gangster)로 골든글러브 후보에 오른 것에 대해 기뻐했다. 그러나 영화 ‘그레이트 디베이터스’가 골드글러브 최고 영화상 후보에 오른 것에 더 만족해했다.',
#  '주방쪽 문에 붙어있는 누렇게 바랜 포스터를 내려다보며 그 플루트 연주자는 황제처럼 자신의 덥수룩한 턱수염을 뽐낸다.',
#  '미셀리는 네스토르 키르츠네르 아르헨티나 대통령의 요청으로 자금 출처에 대해 밝히려 하고 있었다며 “이 자금에 대해 부인할 수 있었으나 사실을 말하는 것이다” 고 말했다.',
#  '약 220만명의 이라크인들이 요르단, 시리아 등 인접 지역으로 피난했으며 또다른 190만명은 이라크 내 에서 피난한 것으로 조사됐다.',
#  '셀틱은 지난 1967년 유러피언 컵을 들어올렸던 구장에서 벤피카를 만나 설욕전을 치를 예정이다.',
#  '하리리와 22명은 2005년 2월 14일 베이루트 중심가에서 자동차 퍼레이드 도중 폭탄 테러로 즉사했다.',
#  '개는 또한 스스로를 자학하는 등 더한 스트레스 증상을 보였다',
#  '아베 총리가 10개월 전 총리직에 오른 후, 두 명의 다른 장관들이 사임했다.',
#  '갈라스는 칼리 신부가 6000m 높이로 떠올랐다가 그가 예상했던 자신의 지역 교구에서 북서쪽으로 750km 떨어진 도라도스까지 2500m 높이로 비행 중 이었다고 전했다.',
#  'FDA는 멜론에 의한 살모넬라균 등 식중독균 감염 예방법을 권고했다.',
#  'AFP 통신에서는, 일몰까지 23명의 한국인 인질들을 살해하겠다고 무장 단체에서 협박한 후, 구출 작전을 위해 군 부대가 아프가니스탄의 탈레반 은신처를 포위하고 있다고 보도했었다.',
#  '우리가 선택한 것들 중 몇 가지는 어려운 일이 될 것입니다.”',
#  '민주당 대선후보 결정에 가장 중요한 예비선거는 오는 3일(현지시간) 몬타나주와 사우스다코타주를 마지막으로 막을 내린다.',
#  '공익을 위한 납세자 모임(Taxpayers for Common Sense)의 스티브 엘리스는 의원들이 이 법안을“ 많은 미심쩍은 프로그램들”을 모두 포괄적으로 포함하는 법안으로 이용하고 있다고 말합니다.',
#  '존 F. 케네디 대통령의 딸인 캐롤라인은 지난 1월 말 오바마 지지선언을 했으며 당시 뉴욕타임스는 이를 두고 ‘나의 아버지와 같은 대통령’(A President Like My Father)라는 제목이 붙인 기사를 실었다.',
#  '소식통은 새로운 국정원장으로 김만복 국정원 제1차장이 유력한 후보자라고 밝혔다.',
#  '이에앞서 부시 대통령은 “어떤 시점…',
#  '이는 지난 월요일 선관위에서, 정부 관료는 선거를 앞두고 중립을 지켜야 한다는 법률을 노대통령이 위반하였다고 판정을 내린 이후에 제기되었다.',
#  '“ 가장 대단하다고 생각하는 사람을 팬들이 직접 뽑아야죠.”',
#  '탕 대변인은 스톤은 영화제 주최측에게 자선사업을 하겠다는 의사와 2006년 영화제 참석했다는 사실 등을 언급한 그의 사과 발언에 매우 놀랐다고 밝혔다.',
#  '이날 싱가포르의 뉴욕상업거래소(NYMEX) 장외시장에서 서부텍사스 중질유(WTI) 6월 인도분 선물가격은 8센트 내려가며 125.72달러에 거래됐다.',
#  '러시아를 처음 방문한 사르코지 대통령은 이란 핵활동 접근 방식에 있어서 양국 정상간에 차이가 있었지만 그 간격을 좁혔다고 밝혔다.',
#  '이렇게 오래된 지하철을 처음 본 조세프 살몬드는 “지하철 운전수가 내가 도착해야 할 23번가 지하철역에 도착할 때까지 지하철을 잘못 타고 있는 것으로 생각했다”며 “영화 ‘백 투더 퓨쳐(Back to the Future)처럼 느껴졌다”고 지하철을 타본 소감을 밝혔다.',
#  '“ 소수인종이 호흡기, 중환자실 입실 및 인공영양 등 더 많은 말기 치료를 받고 있는 것 같습니다.',
#  '한국 정부는 동해에 있는 독도에 보다 많은 한국인들의 방문을 허용하는 것을 포함하여 일본의 도발적 움직임에 더욱 공격적으로 대응할 방안을 고려하고 있다고 정부 소식통이 전했다.',
#  '대통령은 최근의 위조 학위 파문의 중심에 있는 신 씨를 변 씨가 보호해왔다는 보고를 받은 후, 이러한 지시를 내렸다.',
#  '만약 검사과정이 순조롭게 이뤄져 보존할 수 있는 상태이면 박물관에 전시될 예정이다.',
#  '비록 오늘날의 전쟁터에서는 여성들도 사상자들 중에\xa0포함되기는 하지만 여성들은 여전히 직접적인\xa0전투 임무에서 배제되고 있다. 번역 :',
#  '조지 워싱턴 전 미 대통령이 프랑스 혁명 군인정치가로 미국 혁명을 지원했던 마르퀴 드 라파예트에게 수여한 금메달이 11일(현지시간) 소더비 경매에서 530만달러(49억원)에 낙찰됐다.',
#  '차베스 대통령과 스톤 감독은 지난주 베네수엘라 수도 카라카스에서 처음 만나 서로 존경하는 마음을 표했다.',
#  '야당인 통합민주당은 유 장관이 “민주적인” 세력을 축출하려고 한다고 비난했다.',
#  '연방 정부 관계자들이 생태계 복구를 위해 그랜드 캐년에 물을 붓기 시작했다.',
#  '모델 겸 영화배우인 폭스(21)는 안젤리나 졸리(12위), 리한나(14위), 킴 카다시안(17위), 패리스 힐튼(77위)과 지난해 1위를 한 제시카 알바(3위)를 따돌렸다.',
#  '이번 테러는 미국이 폭동을 진압하기 위해 팔루자 수니 지역을 급습한 이래 가장 피비린내 나는 사건으로 지난 7월 이후 폭탄으로 인한 사망자 수가 최고를 기록했다.',
#  '데이비드 스튜어트 미군 대위는 양국군 모두 방위 태세가 확고하다고 밝혔다.',
#  "“일리노이 대학의 한 연구에 의하면 '스테잉 얼라이브'는 분당 103비트를 가지고 있다고 합니다.",
#  '저명 인사 관련 뉴스 사이트 TMZ.com은 어머니 캐시와 함께 차 안에 있는 힐튼을 포착해 공개됐다.',
#  '2000년과 2050년 사이에 8개국 _ 인도, 파키스탄, 나이제리아, 미국, 중국, 방글라데쉬, 에티오피아 및 콩고 _ 이 예상되는 세계 인구 증가의 반을 차지할 것으로 예측됐다.',
#  '전체의 32퍼센트로 가장 많은 외국인들이 비자 서비스를 만족스럽게 여겼으나, 이것 역시 1년 전보다 약 6퍼센트 감소한 수치이다.',
#  '지구 온난화가 힘들고 가난한 나라들을 만들고 이에따라 대규모 이주가 늘어나고 있다고 26일(현지시간) 미국 국가정보위원회 회장이 밝혔다.',
#  '해외 문제로는 이란 핵 프로그램 문제가 대부분을 차지했다.',
#  '제나디 쉬베츠 러시아 올림픽 위원회 대변인은 성화 봉송행사 취소를 전혀 고려하지 않고 있다고 밝혔다.',
#  '티셔츠 아이디어는 그의 최신 홍보방법이며 그는 자신의 차량에 이력서를 붙이거나 고용할 업체에 엽서를 보냈다.',
#  '판 니스텔로이는 12일 미국 콜로라도주에 있는 스테드만 박사 병원에서 “물론 작은 행운을 바라며 이 부상으로 8주 이상 몇 달 동안 움직이지 못하게 된다”고 밝혔다.',
#  '무샤라프 대통령은 “솔라나 대표가 복잡한 파키스탄 상황을 너무 잘 알고 있었다"며 “언제나 의견의 합치를 보기 때문에 솔라나 대표와의 회담은 항상 만족스럽다”고 말했다.',
#  '최신 패션이 실용기술을 받아들이는 데 시간이 걸리는 반면 디자이너들은 눈부신 새로운 스타일을 창조하는데 실용기술을 받아들이는데 민첩했다.',
#  '실제로 텔리콤 산업은 현재 미국 경제가 겪고 있는 어떤 종류의 심대한 변화보다도 좋은 사례이다.',
#  '그의 형들은 모두 죽었다.',
#  '골드는 월요일에는 대부분 출장을 가기 때문에 휴대용 컴퓨터를 사용한다. 그는 회사측에 블랙베리 서비스가 또 다시 중단될 경우를 대비해 RIM의 경쟁사인 팜의 트레오(Treo) 구입을 요청한 상태다.',
#  '유로는 항상 0.9722파운드가 높았기 때문에 유로와 파운드는 별차이가 없어 보였다.',
#  '그는 “이 시스템의 장점은 재활용한 연료를 유통하고 판매하고 활용하는 전반적인 기반시설이 이미 적절하게 마련됐다는 점”이라고 밝혔다.',
#  '서울대학교 교수들이 지난 월요일, 다른 대학교들과 네트워크를 구축하여 이명박 대통령 당선인의 한반도 대운하 프로젝트를 반대하는 캠페인을 조직적으로 실시하겠다고 선언했다.',
#  '한편 영국 국방부는 헬만 남부지역에서 일어난 로켓 공격으로 2명의 영국 병사가 사망했다고 발표했다.',
#  '유엔 난민 고등 사무소(UNHCR)가 집계한 난민의 수는 2006년 990만 명으로 14%나 증가했다.',
#  '페르난도 토레스는 전반 33분 독일 수비의 뒷공간을 파고들며 달려오던 옌스 레만 골키퍼를 넘기는 슈팅으로 독일의 골 네트를 갈랐다.',
#  '테러리스트로 의심되어 관타나모 기지 수용소에 갇혀 있던 세 명의 영국 거주인이 4년 이상의 감금 이후 수요일 영국에 도착했으며, 두 명은 즉시 체포되었다고 경찰이 밝혔다.',
#  '그는 쿠바에서 철권통치를 일삼았으며 자신을 축출하기 위한 미국의 통상금지조치에 맞섰다.',
#  '대부분의 사람들이 맑은 하늘과 따뜻한 날씨를 즐기기 위해 라스베이거스를 방문 한다.',
#  '따라서 의원들은 이전까지 새로운 대통령을 선출해야 한다.',
#  '불가리아는 오는 9월 8일 G조 3위인 네덜란드와 원정경기를 치른다.',
#  '클로랜 부행정장관은 스탤론에게 2500달러의 벌금을 부과했으며 법정 비용으로 8200달러를 납부하라고 촉구했다.',
#  '게이츠 국방장관은 미 국방성에서 “우리의 정책은 현지 주둔 기간을 늘리는 대신 가족들과 함께 할 수 있는 시간도 늘려주는 것”이라고 말했다.',
#  '북한은 지금 까지 생산한 플로토늄 총량이 담긴 핵신고서를 26일 6자회담 의장국인 중국에 전달한다.',
#  '이번 시위가 스페인, 스웨덴, 헝가리, 프랑스, 이탈리아, 인도, 미국 등에서는 소규모로 진행된 반면 콜롬비아의 수도와 남아메리카에서는 대규모로 진행됐다.',
#  '이라크 북부에서는 반군이 국경을 순찰을 위해 이동 중이던 병사 5명과 민간인 1명이 살해당하는 사고가 공격이 발생했다.',
#  '시가총액 기준 프랑스 2위 은행인 소시에테 제네랄(SG)은 24일(현지시간) 금융 사기사건으로 49억 유로(72억 달러)의 손실이 발생했다고 밝혔다.',
#  '청와대에서 매주 열리는 내각 회의에서 노무현 대통령은 FTA 협상을 책임지고 있는 장관들에게 마감 시한뿐만아니라 정치적 문제, 국내의 FTA 반대 시위 등 다른 요소에 개의치 말고 오직 경제적 이익에만 주안을 두라고 지시했다.',
#  '지난 1960년대 초 최초로 쏘아 올린 통신위성은 그의 아이디어를 바탕으로 제작됐다.',
#  '이 학교는 지난주 개학한 뒤 수업을 진행할 예정이었다.',
#  '구조대원들과 목격자들은 또다른 11명이 번개를 맞아 숨졌다고 전했다.',
#  'South Korea is not shifting its foreign currency reserves out of the dollar.정부, 외환 보유액 다변화 정책 시행 않는다.',
#  '새로운 신문법은 신문사로 하여금 정부 부서의 신문발전기금을 받을 수 있도록 하고 있다.',
#  '국제 수사관들이 아동 성학대가 성행하는 인터넷 대화방을 적발, 어린이 31명을 구출하고 700여명의 용의자를 확보했다.',
#  '프리미어리그(EPL) 사무국은 지난 19일(현지시간) 리버풀 안필드 스타디움에서 열린 첼시와 리버풀의 경기에서 주심이 페널티킥을 선언한 것은 오심이었다며 롭 스타일스 심판을 징계할 것이라고 밝혔다.',
#  '미국 협상자들은 한국에 미국 자동차를 더 많이 팔기 위해서, 그리고 지적 재산권에 대한 보호를 강화하기 위해 계속 압력을 가할 것으로 예상된다.',
#  '북한은 중국 국경 근처에 위치한 인구 13만 명 규모의 도시인 룡천에 지난 주 열차가 폭발한 사고를 “1톤짜리 폭탄 100개”가 동시 에 떨어진 것과 같다고 밝혔다.',
#  '클린턴은 5일 "미국은 경제를 바꾸고 미국을 예전으로 돌려 놓을 수 있는 최고의 사령관인 대통령이 필요하다"고 말했다.',
#  '그리고 GDP의 마이너스 성장률이 시장의 전망치보다 작아, 월스트리트는 상승세로 장을 열었습니다.',
#  '그때에는 20명 정도의 농부들이 있었다.',
#  '그는 치료를 받은 이후 오타와타운티 교도소에 수감됐었다.',
#  '이 기지는 거의 대부분이 해병대로 구성돼있으며 1만명의 군이 주둔해 있다.',
#  '게이츠는 퀘벡에서 아프간 남부에 병력을 배치한 각 연방국가의 국방장관들과 회의를 마치고 돌아오는 중이었다.',
#  '5월 14일 백악관에서 있을 조지 W 부시 미 대통령과 노대통령간 정상회담의 핵심 의제는 북한의 핵위기 해소를 위한 상호 수용 가능한 방법을 도출해내는 것으로, 양측은 북한 정부에 관한 자신들의 견해를 숨김없이 토로할 것으로 알려졌다.',
#  'Beijing pressed the World Bank to remove pollution research˝중국, 공해 관련 보고서 삭제하도록 세계 은행에 압력˝2007.09',
#  '머독이 다우존스 인수가격으로 제안한 50억 달러는 그에게 쉽게 모을 수 있는 자금으로 여겨진다.',
#  '마하일 사카시빌리 대통령의 측근인 니노 부르자나제 의장은 "16일 국가 비상사태가 철회될 것"이라며 “이후 정상생활로 돌아갈 것"이라고 말했다',
#  '그는 테러리스트 혐의자들을 감시가 삼엄한 미국 내 교도소에 구금한다면 전혀 문제가 되지 않을 것이라 주장합니다.',
#  '조는 이어 “남들이 내가 맡은 배역을 다 아는 것은 스타트랙에 출연한 이번이 처음” 이라며 약간 부담스럽다는 심정을 전했다.',
#  '를 외친 사람은 없지만 올해는 외칠 수 있을 것이다.',
#  '그는 만보계 내장 신발, 아이팟(iPod) 제어 일체 통합된 활동성 의류의 생산 등 스포츠와 체력단련 산업이 의복 기술에 접목되는 방법을 이끌어가고 있는 반면 패션 산업은 최근 이보다 뒤쳐지고 있다고 말했다.',
#  '국제올림픽위원회(IOC)는 2011년에 2018 동계올림픽 개최도시를 선정할 예정이다.',
#  '미군은 자르카위의 조직 내부로부터 정확한 정보를 입수한 후 기습을 단행하였다고 관계자는 밝혔다.',
#  '“ 그것은 우리 미래를 위한 경제의 청사진입니다.',
#  '닌텐도가 당신의 거실을 새로운 운동 공간으로 만들어내고 있다.',
#  '웹사이트는 또한 투표를 기다리는 시간을 측정하기 위해 트위트를 활용한다.',
#  '그는 이라크 주변국들로부터 지지를 얻는 것이 이라크연구그룹의 주요 권고사항이었다고 밝혔다.',
#  '지난 29일 열린 세리에 A 칼리아리전에서 동점골을 넣으며 1-1 무승부를 이끌었던 토티는 왼쪽 장딴지 근육통으로 8강 1차전 출장이 불가능해졌다.',
#  '기관사가 뒷쪽의 객차로 불길이 번지는 것을 알지 못하고 운행을 계속하자 승객들은 불길을 피하려고 기차에서 뛰어내렸다.',
#  '이라크 전쟁은 지난주 5주년을 맞았다.',
#  '이번 급습 전까지 중국 불법 복제 조직은 20억 달러 어치 이상의 소프트웨어를 판매하고 배포한 것으로 알려져 있다.',
#  'Obama says he will not speed up the withdrawal of troops from Iraq오바마, 이라크 철수 앞당기지 않겠다고 말해2009.06',
#  '애완동물이 어지럽힌 것을 청소하는 방법은?',
#  '국영 BBC는 잉 대사가 이미 불참을 결정했으나 대사관 측이 불참 여부를 놓고 고민하고 있다고 전해왔다고 보도했다.',
#  '니콜 스미스의 전 남자 친구, 래리 버크해드는 이번 심리에서 대니엘이 약물남용과 과음을 즐기는 문제가 있던 젊은이였다고 진술했으나 스턴은 대니엘의 부검결과에 대해 당황했다며 대니엘이 약물을 복용하는 것을 본 적이 없다고 증언했다.',
#  '사용자가 편집을 할 수 있도록 구성한 온라인 페이지인 위키(Wikis)는 온라인 백과사전이 위키피디아(Wikipedia) 덕분에 사용자들 사이에 인기가 높아졌다.',
#  '맥캔은 매들린이 4번째 생일을 앞둔 지난 5월 3일 휴가를 보내고 있던 포르투갈 동부 프레이라 다 루즈에서 실종됐다고 전했다.',
#  '소방관들이 25~30cm 크기의 소방 호수를 통해 파이프에 250갤론의 물을 뿌리자 놀란 새끼 고양기가 맨홀 안에서 대기하고 있던 케빈 시어스 소방관의 팔에 안겼다.',
#  '그들은 지지자들이 대거 집회에 참여하도록 독려했다.',
#  '양국은 경쟁 분야(반독점 정책)에 대한 최종 합의에 도달해 세계 기준에 맞는 규정을 적용하기로 했다고 한다.',
#  '베이징은 몇년 전 인력거 면허 취득을 중지시켜 비합법적으로 인력거를 끄는 사람이 늘어났지만 경찰은 여행객이 타고있을 때를 포함, 이같은 행위를 눈 감아준다.',
#  'complaint 불만, 불평',
#  'N Korea fund transfer under way북한 자금 송금 진행중2007.08 원문 & 독해설명 인쇄',
#  'Cannibalistic Instincts)’이라는 제목의 소설 초안을 발견했다고 말했다.',
#  '자녀 1명은 사망했다.',
#  '이날 일본 하네다 공항에 도착한 힐 국무부 차관은 기자회견에서 “북한이 앞으로 3주 안에 영변 핵시설을 폐쇄 할 것을 약속했다”며 “시한은 22일부터 시작됐다”고 설명했다.',
#  '에이즈 환자는 구호기구나 정부가 지원하지 않은 약물 치료에 매달 29달러(약 4만4000원)를 지불한다.',
#  '국회 내 에서 세 번째 투표를 거쳐, 명백한 다수의 지지를 얻어 승리한 그가 취임했다.',
#  '지난달 27일에는 중국 군함이 제2차 세계 대전 이후 처음으로 일본에 입항했다.',
#  '파키스탄군은 "이번 시험발사는 전략적 미사일 시스템 기술을 개선하고 강화하는 지속적 절차의 일환이었다"고 밝혔다.',
#  '그는 “고유가도 OPEC의 원유 증산 합의에 영향을 미쳤다”며 “우리는 소비자들에게 신경을 쓰고 있다는 점을 보여주려 했다”고 덧붙였다.',
#  '버락 오바마 미국 대통령 당선인의 아내 미셀 오바마는 올해 대통령 선거운동 기간 동안 패선 블로거를 떠들썩하게 만들며 이목을 끄는 색상과 여성스러운 머리모양으로 험난한 길을 활주로로 바꾸었다.',
#  '헤틀 대변인은 또 파키스탄 만세라에서도 닭을 도살한 남자가 H5N1 바이러스 양성 반응이 나왔다고 설명했다.',
#  '소물리에는 포도주를 만드는 포도농장부터 최고의 앙트레 요리에 맞는 포도주까지 포도주에 대한 모든 것을 알고 있다.',
#  '라고 말하는 장면을 상상할 수 있냐”며 “세상의 일은 그런 식으로 돌아가지 않는다”고 말했다.',
#  '그러나 그것을 믿지 않는 사람들은 어설픈 의문점들을 제기하기 시작했으며, 그것이 바로 NASA가 대응하려고 하는 것이다.',
#  '이날 스위스 로잔 IOC 본부에는 승려를 포함 100명이 현수막과 티베트 국기를 들며 티베트 사태에 대한 관심을 촉구했다. IOC 본부에서는 티베트의 올림픽위원회 관계자들이 IOC 위원들을 만나 티베트 올림픽 참가를 공식 요청했다.',
#  '민주당 대선후보인 힐러리는 이날 오후 3시께 민주당 전국 의원회 행사에서 연설을 가질 예정이었으나 이 인질극으로 인해 연설을 취소했다.',
#  '톰 크루즈와 로버트 다우니 주니어는 영화 ‘트로픽 썬더’로 남우주연상 후보가 됐지만 영화는 코미디나 뮤지컬 부문 작품상 후보작으로 선정되지 않았다.',
#  '인도네시아에서 여객선은 일반적인 운송수단으로써 탑승인원 초과로 인해 종종 사고가 발생하고 있다.',
#  '이에따라 군에서는 범인을 잡고 무기를 회수하기 위해 강원도 일대에 보안 경보를 발령했다.',
#  '이러한 절차는 집 안으로 들어가 모든 작업을 실내에서 하는 것과 같다.',
#  '이미 대부분 아시아 태평양 국가 증시도 이날 급락했다.',
#  '그는 한국에서의 부유층과 빈곤층의 격차는 경제협력개발기구(OECD) 회원국들 중 최악이라고 밝혔다. 넓히다, 넓어지다',
#  '이 용의자는 다음 날 체포되었다.',
#  "'에코이스트'의 공동 설립자인 조나단 마르코셰머는 “우리가 폐품에 의지하는 것은 신뢰성이 높고 풍족하기 때문”이라며 “앞으로 몇 년 후면 이런 폐품을 활용한 물건이 넘칠 것으로 확신한다”고 말했다.",
#  '여론조사 결과 오바마는 펜실베이니아주의 새로운 민주당 유권자로부터 많은 표를 얻은 반면 클린턴은 선거 캠페인 막바지 후보를 결정한 유권자의 표를 석권했다.',
#  '이슬람 근본주의 학생들과 파키스탄 경찰의 갈등은 몇 개월 째 지속되고 있다. 이들 학생들은 민간인과 중국 관리 그리고 파키스탄 경찰을 납치한 혐의를 받고 있다.',
#  '오늘 아침 공화당으로부터 많은 이야기가 나오고 있지 않습니다만, 어제 밤 하원을 통과한 대통령의 경기부양책이 공화당의 지지를 받지 못하고 있다고 민주당 측은 말하고 있습니다.',
#  '나사는 이른 오후 플로리다 케네디우주센터로 계획되어 있는 착륙에 좋은 날씨라고 밝혔습니다.',
#  '한국의 대부분 일간지를 포함하고 있는 한국온라인신문협회에서는 지난 토요일 구글을 법정에 세울 것을 고려하고 있다고 발표했다.',
#  '38개국의 군축회의는 적어도 네 가지 문제에 있어서의\xa0교착상태를 타개하기 위한 시도로, 드물게 주말 회의를 계획했다.',
#  '무료 인터넷 사용:',
#  '이에앞서 호츠는 T-모바일 네트워크상에서 이용이 가능하도록 조작된 아이폰을 온라인을 통해 3개의 업체에 보낼 것이라고 말한 바 있다.',
#  '또한 그는 국내에서 가장 비싸거나 가장 저렴한 휘발유를 찾는 법도 소개했습니다.',
#  'The Lord of the Rings:',
#  '그는 "케네디 의원은 현재 안정을 취하며 가족들과 함께 레드삭스의 경기를 보고 있다”고 덧붙였다.',
#  '경제적으로 생존해나가려고 애쓰는 나라에서는 큰 댓가를 치르고 난 후에야 환경 법규가 생겨나게 된다.',
#  '야자유는 포테이토칩, 크림치즈와 같은 식품은 물론 생물 연료 생산에도 이용된다.',
#  '그리고 이 그룹은 이런 고정관념을 바꾸기위해 노력해왔다.',
#  '그린스펀, 現 `신용쓰나미`에 자신의 실수 인정',
#  '이라크 국영방송국은 이날 모국국기를 어깨에 걸친 축구대표팀 선수들이 경기장에서 우승컵을 들며 환호하는 장면을 방영했다.',
#  "그녀는 NBC의 '투데이쇼(Today Show)'를 통해 산모는 가족들의 도움이 필요하다고 말했습니다.",
#  '만치니 감독은 또 “AS 로마 선수들의 동기부여가 더 잘 된 것 같다”며 “2차전에서 기적을 기다릴 수 밖에 없다”고 덧붙였다.',
#  'An Chinese activist is jailed중국인 인권운동가 구속2006.10',
#  'N. Korean leader visits the Chinese Embassy in Pyongyang 김정일 국방위원장 평양주재 중국대사관 방문\xa0 \xa0 \xa02007.05',
#  '이것은 콘돌레자 라이스 미 국방 장관이 연주한 음악입니다.',
#  '당시 촬영된 영상에따르면 그는 빨간 티셔츠와 어두운 색의 반바지, 그리고 야구모자와 선글라스를 착용하고 있었으며, 교황 의전용 차량이 다가오자 깃발과 현수막을 들고 있는 인파 사이를 튀어나와 차량에 다가갔다.',
#  '지미 카터 전 미국 대통령은 12일 (현지 시간) 아프리카에 만연한 예방 가능한 질병의 퇴치를 위해 보건 교육과 위생 관리를 증진해야 한다고 촉구했다.',
#  '이란은 지난 몇주간 원심분리기 수백대를 설치했으며 다음달까지 3000번의 작업을 가질 계획이다.',
#  '이 기록은 뉴욕 메디슨스퀘어가든 경기장에서 벌어진 (뉴욕 닉스와의) 경기에서 레이커스의 코비 브라이언트의 손끝에서 나왔습니다. 월가 소식입니다.',
#  '그는 “누구도 실제 진실을 좋아하지 않지만 누구든 진실을 말해야 한다”고 덧붙였다.',
#  '파키스탄 라호르에서 16일 경찰이 야당 지도자인 베나지르 부토 전 총리에 대한 가택연금을 해제, 그녀는 13일 이후 처음으로 자유를 되찾았다.',
#  '케리 후보는 이번 민주당 전당 대회의 절정인 후보 수락 연설을 통해 “미국은 결코 전쟁을 원하지 않으며 그렇기에 불가피한 상황이 아니면 전쟁을 하지 않을 것”이라고 말하며 이라크 전쟁과 관련해 부시 대통령에게 도전장을 내밀었다.',
#  '와도씨는 \'\'자연적 재생이 산림을 키우는 최선의 방책"이라며 \'\'그러나…',
#  '한편 부시 대통령은 이라크전 목표 진행 과정에 대한 보고서를 오는 7월과 9월 제출해야 한다.',
#  '“콜로라도 서부와 아이다호 동부에 눈보라가 몰아치고 있으며 그 세력이 유타에도 뻗어가고 있습니다.”',
#  '총 527명의 주민들이 심각한 소음에 대한 보상을 받기 위해 5월 3일 정부에 소송을 제기할 것이다.',
#  '아스날은 지난 4월초 이후 28경기에서 무패를 기록하며 프리미어리그에서도 선두를 달리고 있다.',
#  '중국 정부를 위해 북한의 핵 프로그램을 연구하는 한 기관의 중국의 물리학자 리공량은 "북한이 핵 시설을 사찰단에 공개하지 않고 이 시설의 가동을 중단했고 다른 시설은 폐쇄했다고 말하고 다른 국가들에 자신들을 믿으라고만 한다면 어떻할 것인가? "라고 말했다.',
#  '부토 전 총리는 이슬라마바드 외곽 파키스탄 군부대가 있는 라왈판디 인근에서 파키스탄의 비상사태에 대해 반대하는 집회에 참석하기 위해 집을 나서려 했었다.',
#  '다나 페리노 백악관 대변인은 성명에서 “부시 대통령과 오바마 당선자는 장시간 회동을 가졌으며 부시 대통령은 이날 회동이 좋았고 건설적이었으며 편하고 호의적이었다고 설명했다”고 전했다.',
#  '그러나 그것을 가지고 있는 사람들과 얘기를 해 보면 그것이 결국 그렇게 신비스러운 것이 아니라는 것을 알게 된다.',
#  '상상 속에는 도처에 화려한 동상이 세워져 있다.',
#  '시오콘은 “이 동물의 크기 외 에는 현존하는 자이언트 판다와 매우 흡사하다”고 덧붙였다.',
#  '이 회사는 주민들이게 배상금을 지급했가.',
#  '깡마른 산꼭대기에 퍼부운 억수 같은 비는 협곡에서 흐르는 물과 같았고 도시로 바로 퍼붓는 거친 비는 수로를 이루어 마른 강바닥을 적셨다.',
#  '상승이 둔화되고 하락으로 바뀌기 전까지 전날 모든 주요 지수는 상승했다.',
#  'JPM 모건 체이스의 경제 전문가인 제임스 글로스멘은 “미팅에서 금리를 0.5% 인하하는 방안이 우선적으로 거론될 것”이라며 “그러나 시간이 아직 있으므로 비율이 어느 정도 될지 짐작하기는 쉽지 않다”고 설명했다.',
#  '마리베스 무어는 어머니의 헤어드레서가 소개한 남성에게서 전화를 받은 뒤 그의 존재에 대해 알게됐다.',
#  '그녀는 인종차별 정책 때문에 조국인 남아프리카 공화국에서 약 30년간 입국이 금지되었습니다.',
#  '지난 주 런던을 방문한 중국 관광객 중 다수는 영국이 중국인들에 반감을 가졌다고 느꼈다고 푸잉 대사는 덧붙였다.',
#  '"우리는 분명 DVD를 요즈음 출하되고 있는 CD-ROM의 대체품으로 보고 있습니다. "라고 Apple의 제품 담당부장은 말한다.',
#  'A correctional officer sexually harased 12 female inmates교도관, 여성재소자 12명 성추행2006.04',
#  ...]

# %%
import tensorflow as tf
import numpy as np
import matplotlib as plt
import konlpy

print(tf.__version__)
print(np.__version__)
print(plt.__version__)
print(konlpy.__version__)
# Out:
# 2.6.0
# 1.21.4
# 3.4.3
# 0.5.2

# %%
def tokenize(corpus):  # corpus: Tokenized Sentence's List
    tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')
    tokenizer.fit_on_texts(corpus)

    tensor = tokenizer.texts_to_sequences(corpus)

    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')

    return tensor, tokenizer

# %%
import sentencepiece as spm
import os
temp_file = os.getenv('HOME')+'/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp'

vocab_size = 8000

with open(temp_file, 'w') as f:
    for row in filtered_corpus:   # 이전에 나왔던 정제했던 corpus를 활용해서 진행해야 합니다.
        f.write(str(row) + '\n')

spm.SentencePieceTrainer.Train(
    '--input={} --model_prefix=korean_spm --vocab_size={}'.format(temp_file, vocab_size)    
)
#위 Train에서  --model_type = unigram이 디폴트 적용되어 있습니다. --model_type = bpe로 옵션을 주어 변경할 수 있습니다.

# !ls -l korean_spm*
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp --model_prefix=korean_spm --vocab_size=8000
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp
#   input_format:
#   model_prefix: korean_spm
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/sp_tokenizer/data/korean-english-park.train.ko.temp
# trainer_interface.cc(385) LOG(INFO) Loaded all 76908 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=4996369
# trainer_interface.cc(477) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1317
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 76908 sentences.
# unigram_model_trainer.cc(139) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(143) LOG(INFO) Extracting frequent sub strings...
# unigram_model_trainer.cc(194) LOG(INFO) Initialized 174340 seed sentencepieces
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 76908
# trainer_interface.cc(537) LOG(INFO) Done! 237965
# unigram_model_trainer.cc(489) LOG(INFO) Using 237965 sentences for EM training
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=92555 obj=14.853 num_tokens=523272 num_tokens/piece=5.65363
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=82083 obj=13.516 num_tokens=525776 num_tokens/piece=6.40542
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=61555 obj=13.5533 num_tokens=546907 num_tokens/piece=8.88485
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=61506 obj=13.5101 num_tokens=547350 num_tokens/piece=8.89913
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=46126 obj=13.6926 num_tokens=575369 num_tokens/piece=12.4739
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=46126 obj=13.6493 num_tokens=575466 num_tokens/piece=12.476
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=34594 obj=13.8894 num_tokens=606014 num_tokens/piece=17.5179
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=34594 obj=13.8387 num_tokens=606012 num_tokens/piece=17.5178
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=25945 obj=14.1301 num_tokens=637532 num_tokens/piece=24.5724
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=25945 obj=14.0747 num_tokens=637568 num_tokens/piece=24.5738
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=19458 obj=14.4091 num_tokens=670960 num_tokens/piece=34.4825
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=19458 obj=14.3468 num_tokens=670999 num_tokens/piece=34.4845
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=14593 obj=14.7196 num_tokens=705636 num_tokens/piece=48.3544
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=14593 obj=14.648 num_tokens=705645 num_tokens/piece=48.355
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=10944 obj=15.0875 num_tokens=741620 num_tokens/piece=67.765
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=10944 obj=15.007 num_tokens=741624 num_tokens/piece=67.7654
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=8800 obj=15.3757 num_tokens=769363 num_tokens/piece=87.4276
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=8800 obj=15.307 num_tokens=769367 num_tokens/piece=87.4281
# trainer_interface.cc(615) LOG(INFO) Saving model: korean_spm.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: korean_spm.vocab
# -rw-r--r-- 1 root root 376816 Nov  6 16:38 korean_spm.model
# -rw-r--r-- 1 root root 146213 Nov  6 16:38 korean_spm.vocab

# %%
s = spm.SentencePieceProcessor()
s.Load('korean_spm.model')

# SentencePiece를 활용한 sentence -> encoding
tokensIDs = s.EncodeAsIds('이건 왜 이렇게 되는걸까')
print(tokensIDs)

# SentencePiece를 활용한 sentence -> encoded pieces
print(s.SampleEncodeAsPieces('이건 왜 이렇게 되는걸까',1, 0.0))

# SentencePiece를 활용한 encoding -> sentence 복원
print(s.DecodeIds(tokensIDs))
# Out:
# [25, 509, 3395, 4631, 1314, 3510, 2097]
# ['▁이', '건', '▁왜', '▁이렇게', '▁되는', '걸', '까']
# 이건 왜 이렇게 되는걸까

# %%
def sp_tokenize(s, corpus): 

    tensor = []

    for sen in corpus:
        tensor.append(s.EncodeAsIds(sen))

    with open("./korean_spm.vocab", 'r') as f:
        vocab = f.readlines()

    word_index = {}
    index_word = {}

    for idx, line in enumerate(vocab):
        word = line.split("\t")[0]

        word_index.update({word:idx})
        index_word.update({idx:word})

    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post')

    return tensor, word_index, index_word

# %%
corpus = ['이건 왜 이렇게 되는걸까']
tensor = []
for sen in corpus:
    tensor.append(s.EncodeAsIds(sen))

# print(tensor)
print(sp_tokenize(s,['이건 왜 이렇게 되는걸까'])[0][0])

print(s.SampleEncodeAsPieces('이건 왜 이렇게 되는걸까',1, 0.0))

s.SampleEncodeAsPieces('이건 왜 이렇게 되는걸까',1, 0.0)

# dogs['jindo']

sp_tokenize(s, ['corpus'])[2][509]
# Out:
# [  25  509 3395 4631 1314 3510 2097]
# ['▁이', '건', '▁왜', '▁이렇게', '▁되는', '걸', '까']
# '건'

# %%
s = spm.SentencePieceProcessor()
s.Load('korean_spm.model')
sp_tokenize(s,['아버지가방에들어가신다.'])[0][0]

# SentencePiece를 활용한 sentence -> encoded pieces
# print(s.SampleEncodeAsPieces('아버지가방에들어가신다.',1, 0.0))

# print(s.DecodeIds(sp_tokenize(s,'아버지가방에들어가신다.')[0]))
# print(sp_tokenize(s,'아버지가방에들어가신다.')[0])
# sp_tokenize(s,'아버지가방에들어가신다.')[0][0:]

# tokenize('아버지가방에들어가신다.')[1]
# Out:
# array([1243,   11,  302,    7, 3608,   11,  287,   38,    3], dtype=int32)

# %% [markdown]
# # 1. 데이터 호출 및 전처리
# - 네이버 영화 감성리뷰 호출
# - 말뭉치 특수문자 제거
# - 불용어 처리

# %% [markdown]
# ## 1-1 데이터 호출

# %%
import urllib

urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7fe4e6a64a00>)

# %%
import pandas as pd
train_data = pd.read_table('ratings_train.txt')
test_data = pd.read_table('ratings_test.txt')

# %%
train_data.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
print('훈련용 리뷰 개수 :',len(train_data)) # 훈련용 리뷰 개수 출력
# Out:
# 훈련용 리뷰 개수 : 150000

# %%
print('테스트용 리뷰 개수 :',len(test_data)) # 테스트용 리뷰 개수 출력
# Out:
# 테스트용 리뷰 개수 : 50000

# %%
# document 열과 label 열의 중복을 제외한 값의 개수
train_data['document'].nunique(), train_data['label'].nunique()
# Out:
# (146182, 2)

# %%
# document 열의 중복 제거
train_data.drop_duplicates(subset=['document'], inplace=True)

# %%
print('총 샘플의 수 :',len(train_data))
# Out:
# 총 샘플의 수 : 146183

# %%
train_data['label'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
print(train_data.groupby('label').size().reset_index(name = 'count'))
# Out:
#    label  count
# 0      0  73342
# 1      1  72841

# %%
print(train_data.isnull().values.any())
# Out:
# True

# %%
print(train_data.isnull().sum())
# Out:
# id          0
# document    1
# label       0
# dtype: int64

# %%
# null값 확인
train_data.loc[train_data.document.isnull()]
# Out:
#             id document  label
# 25857  2172111      NaN      1

# %%
# Null값 제거
train_data = train_data.dropna(how = 'any') # Null 값이 존재하는 행 제거
print(train_data.isnull().values.any()) # Null 값이 존재하는지 확인
# Out:
# False

# %%
print(len(train_data))
# Out:
# 146182

# %% [markdown]
# ## 1-2 특수어 처리

# %%
# 한글과 공백을 제외하고 모두 제거
train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data[:5]
# Out:
# /tmp/ipykernel_30/3525229848.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# /tmp/ipykernel_30/3525229848.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
#          id                                           document  label
# 0   9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1   3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1

# %%
train_data['document'] = train_data['document'].str.replace('^ +', "") # white space 데이터를 empty value로 변경
train_data['document'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# id            0
# document    789
# label         0
# dtype: int64
# /tmp/ipykernel_30/2260017223.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['document'] = train_data['document'].str.replace('^ +', "") # white space 데이터를 empty value로 변경
# /tmp/ipykernel_30/2260017223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['document'] = train_data['document'].str.replace('^ +', "") # white space 데이터를 empty value로 변경
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
# 특수문자 및 공백 처리 후 null값 확인
train_data.loc[train_data.document.isnull()][:5]
# Out:
#            id document  label
# 404   4221289      NaN      0
# 412   9509970      NaN      1
# 470  10147571      NaN      1
# 584   7117896      NaN      0
# 593   6478189      NaN      0

# %%
# 잔여 null값 제거
train_data = train_data.dropna(how = 'any')
print(len(train_data))
# Out:
# 145393

# %% [markdown]
# ## 1-3 불용어 처리

# %%
# 불용어 설정
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
train_data
# Out:
#               id                                           document  label
# 0        9976970                                  아 더빙 진짜 짜증나네요 목소리      0
# 1        3819312                         흠포스터보고 초딩영화줄오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                          교도소 이야기구먼 솔직히 재미는 없다평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화스파이더맨에서 늙어보이기만 했던 커스틴 던...      1
# ...          ...                                                ...    ...
# 149995   6222902                                    인간이 문제지 소는 뭔죄인가      0
# 149996   8549745                                         평점이 너무 낮아서      1
# 149997   9311800                      이게 뭐요 한국인은 거들먹거리고 필리핀 혼혈은 착하다      0
# 149998   2376369                         청춘 영화의 최고봉방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [145393 rows x 3 columns]

# %% [markdown]
# ## 1-4 Sentence Piece 생성 및 토큰화

# %%
#전처리된 document를 저장
with open('naver_review.txt', 'w', encoding='utf8') as f:
    f.write('\n'.join(train_data['document']))

# %%
#해당파일을 호출하여 학습진행

temp_file = 'naver_review.txt'
vocab_size = 8000

spm.SentencePieceTrainer.Train(
    '--input={} --model_prefix=korean_spm --vocab_size={}'.format(temp_file, vocab_size)    
)
#위 Train에서  --model_type = unigram이 디폴트 적용되어 있습니다. --model_type = bpe로 옵션을 주어 변경할 수 있습니다.

# !ls -l korean_spm*
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=naver_review.txt --model_prefix=korean_spm --vocab_size=8000
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: naver_review.txt
#   input_format:
#   model_prefix: korean_spm
#   model_type: UNIGRAM
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: naver_review.txt
# trainer_interface.cc(385) LOG(INFO) Loaded all 145393 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=4944911
# trainer_interface.cc(477) LOG(INFO) Done: 99.95% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=1550
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.9995
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 145393 sentences.
# unigram_model_trainer.cc(139) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(143) LOG(INFO) Extracting frequent sub strings...
# unigram_model_trainer.cc(194) LOG(INFO) Initialized 317695 seed sentencepieces
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 145393
# trainer_interface.cc(537) LOG(INFO) Done! 299292
# unigram_model_trainer.cc(489) LOG(INFO) Using 299292 sentences for EM training
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=154308 obj=13.9864 num_tokens=624105 num_tokens/piece=4.04454
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=142006 obj=13.0761 num_tokens=627169 num_tokens/piece=4.4165
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=106439 obj=13.1581 num_tokens=658989 num_tokens/piece=6.19124
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=106198 obj=13.1042 num_tokens=659398 num_tokens/piece=6.20914
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=79643 obj=13.3211 num_tokens=698587 num_tokens/piece=8.77148
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=79634 obj=13.2608 num_tokens=698754 num_tokens/piece=8.77457
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=59725 obj=13.498 num_tokens=735665 num_tokens/piece=12.3175
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=59725 obj=13.4376 num_tokens=735673 num_tokens/piece=12.3177
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=44793 obj=13.7112 num_tokens=774873 num_tokens/piece=17.299
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=44793 obj=13.6487 num_tokens=774896 num_tokens/piece=17.2995
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=33594 obj=13.9502 num_tokens=814972 num_tokens/piece=24.2595
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=33594 obj=13.8865 num_tokens=814956 num_tokens/piece=24.259
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=25195 obj=14.2185 num_tokens=855998 num_tokens/piece=33.9749
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=25195 obj=14.1493 num_tokens=856090 num_tokens/piece=33.9786
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=18896 obj=14.5122 num_tokens=899658 num_tokens/piece=47.611
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=18896 obj=14.4347 num_tokens=899747 num_tokens/piece=47.6157
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=14172 obj=14.8297 num_tokens=944864 num_tokens/piece=66.6712
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=14172 obj=14.7422 num_tokens=944875 num_tokens/piece=66.672
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=10629 obj=15.1831 num_tokens=993298 num_tokens/piece=93.4517
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=10629 obj=15.0777 num_tokens=993452 num_tokens/piece=93.4662
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=0 size=8800 obj=15.3793 num_tokens=1025495 num_tokens/piece=116.534
# unigram_model_trainer.cc(505) LOG(INFO) EM sub_iter=1 size=8800 obj=15.3119 num_tokens=1025685 num_tokens/piece=116.555
# trainer_interface.cc(615) LOG(INFO) Saving model: korean_spm.model
# trainer_interface.cc(626) LOG(INFO) Saving vocabs: korean_spm.vocab
# -rw-r--r-- 1 root root 377765 Nov  7 05:44 korean_spm.model
# -rw-r--r-- 1 root root 147291 Nov  7 05:44 korean_spm.vocab

# %%
import csv
vocab_list = pd.read_csv('korean_spm.vocab', sep='\t', header=None, quoting=csv.QUOTE_NONE)
# Out:
#        0        1
# 0  <unk>  0.00000
# 1    <s>  0.00000
# 2   </s>  0.00000
# 3      ▁ -3.35737
# 4      이 -4.28745

# %%
len(vocab_list)
# Out:
# 8000

# %%
# SentencePiece를 활용한 sentence -> encoding
tokensIDs = s.EncodeAsIds(train_data['document'][0])
print(tokensIDs)

# SentencePiece를 활용한 sentence -> encoded pieces
print(s.SampleEncodeAsPieces(train_data['document'][0],1, 0.0))

# SentencePiece를 활용한 encoding -> sentence 복원
print(s.DecodeIds(tokensIDs))
# Out:
# [141, 106, 2611, 912, 4856, 4, 4856, 752, 69, 554, 514, 2648]
# ['▁아', '▁더', '빙', '▁진', '짜', '▁', '짜', '증', '나', '네', '요', '▁목소리']
# 아 더빙 진짜 짜증나네요 목소리

# %%
X_sp_train = []
for sentence in tqdm(train_data['document']):
    tokenized_sentence = s.SampleEncodeAsPieces(sentence,1, 0.0)
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_sp_train.append(stopwords_removed_sentence)
    
X_sp_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = s.SampleEncodeAsPieces(sentence,1, 0.0)
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_sp_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 145393/145393 [00:04<00:00, 36094.31it/s]
# 100%|██████████| 48852/48852 [00:01<00:00, 35834.93it/s]

# %%
tokenizer_sp = Tokenizer()
tokenizer_sp.fit_on_texts(X_sp_train)

# %%
len(tokenizer_sp.word_index)
# Out:
# 8990

# %% [markdown]
# - [konlpy 태그 링크](https://konlpy.org/ko/latest/api/konlpy.tag/)
# - 매개변수의 경우 okt만 원형으로 출력하는 stem옵션이 있음

# %% [markdown]
# # 2. Konlpy 형태소 분석기 호출 및 전처리

# %%
#토크나이저 호출
from konlpy.tag import Hannanum,Kkma,Komoran,Mecab,Okt
okt = Okt()
han = Hannanum()
kkma = Kkma()
komo = Komoran()
mec = Mecab()

print(okt.morphs('와 이런 것도 영화라고 차라리 뮤직비디오를 만드는 게 나을 뻔', stem = True))
print(han.morphs('와 이런 것도 영화라고 차라리 뮤직비디오를 만드는 게 나을 뻔'))
print(kkma.morphs('와 이런 것도 영화라고 차라리 뮤직비디오를 만드는 게 나을 뻔'))
print(komo.morphs('와 이런 것도 영화라고 차라리 뮤직비디오를 만드는 게 나을 뻔'))
print(mec.morphs('와 이런 것도 영화라고 차라리 뮤직비디오를 만드는 게 나을 뻔'))
print(s.SampleEncodeAsPieces('와 이런 것도 영화라고 차라리 뮤직비디오를 만드는 게 나을 뻔',1, 0.0))
# Out:
# ['오다', '이렇다', '것', '도', '영화', '라고', '차라리', '뮤직비디오', '를', '만들다', '게', '나다', '뻔']
# ['오', '아', '이런', '것', '도', '영화', '이', '라', '고', '차라리', '뮤직비디오', '를', '만들', '는', '것', '이', '나', 'ㄹ', '뻔']
# ['오', '아', '이렇', 'ㄴ', '것', '도', '영화', '라고', '차라리', '뮤직', '비디오', '를', '만들', '는', '것', '이', '낫', '을', '뻔']
# ['오', '아', '이런', '것', '도', '영화', '이', '라고', '차라리', '뮤직비디오', '를', '만들', '는', '게', '나', '을', '뻔']
# ['와', '이런', '것', '도', '영화', '라고', '차라리', '뮤직', '비디오', '를', '만드', '는', '게', '나을', '뻔']
# ['▁', '와', '▁이런', '▁것', '도', '▁영화', '라고', '▁차', '라', '리', '▁', '뮤', '직', '비', '디', '오', '를', '▁만드는', '▁게', '▁나', '을', '▁', '뻔']

# %%
# test데이터의 가공
test_data.drop_duplicates(subset = ['document'], inplace=True) # document 열에서 중복인 내용이 있다면 중복 제거
test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['document'] = test_data['document'].str.replace('^ +', "") # 공백은 empty 값으로 변경
test_data['document'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 48852
# /tmp/ipykernel_30/3570305079.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
# /tmp/ipykernel_30/3570305079.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['document'] = test_data['document'].str.replace('^ +', "") # 공백은 empty 값으로 변경

# %%
#okt 토크나이저
from tqdm import tqdm
X_okt_train = []
for sentence in tqdm(train_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_okt_train.append(stopwords_removed_sentence)

X_okt_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_okt_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 145393/145393 [11:58<00:00, 202.28it/s]
# 100%|██████████| 48852/48852 [04:13<00:00, 192.44it/s]

# %%
#Hannanum 토크나이저
from tqdm import tqdm
X_han_train = []
for sentence in tqdm(train_data['document']):
    tokenized_sentence = han.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_han_train.append(stopwords_removed_sentence)

X_han_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = han.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_han_test.append(stopwords_removed_sentence)
# Out:
#   5%|▍         | 6944/145393 [00:35<15:16, 151.07it/s]java.lang.ArrayIndexOutOfBoundsException
#  11%|█         | 16041/145393 [01:23<06:37, 325.79it/s]java.lang.ArrayIndexOutOfBoundsException
#  17%|█▋        | 24460/145393 [02:06<14:55, 135.03it/s]java.lang.ArrayIndexOutOfBoundsException
#  18%|█▊        | 25600/145393 [02:13<24:28, 81.59it/s] java.lang.ArrayIndexOutOfBoundsException
#  31%|███       | 44466/145393 [03:54<20:48, 80.82it/s] java.lang.ArrayIndexOutOfBoundsException
#  39%|███▉      | 56568/145393 [04:56<10:01, 147.74it/s]java.lang.ArrayIndexOutOfBoundsException
#  40%|████      | 58618/145393 [05:06<06:02, 239.59it/s]java.lang.ArrayIndexOutOfBoundsException
#  43%|████▎     | 62140/145393 [05:26<06:31, 212.84it/s]java.lang.ArrayIndexOutOfBoundsException
#  52%|█████▏    | 75242/145393 [06:35<04:36, 253.67it/s]java.lang.ArrayIndexOutOfBoundsException
#  56%|█████▌    | 81370/145393 [07:09<09:33, 111.69it/s]java.lang.ArrayIndexOutOfBoundsException
#  57%|█████▋    | 82296/145393 [07:14<04:00, 262.78it/s]java.lang.ArrayIndexOutOfBoundsException
#  60%|█████▉    | 86553/145393 [07:38<08:50, 110.94it/s]java.lang.ArrayIndexOutOfBoundsException
#  60%|██████    | 87562/145393 [07:46<10:06, 95.34it/s] java.lang.ArrayIndexOutOfBoundsException
#  64%|██████▍   | 93422/145393 [08:18<02:53, 299.35it/s]java.lang.ArrayIndexOutOfBoundsException
#  66%|██████▌   | 95876/145393 [08:31<05:45, 143.13it/s]java.lang.ArrayIndexOutOfBoundsException
#  67%|██████▋   | 97971/145393 [08:43<04:07, 191.83it/s]java.lang.ArrayIndexOutOfBoundsException
#  68%|██████▊   | 98581/145393 [08:47<04:10, 187.09it/s]java.lang.ArrayIndexOutOfBoundsException
#  73%|███████▎  | 106753/145393 [09:38<07:36, 84.68it/s] java.lang.ArrayIndexOutOfBoundsException
#  74%|███████▍  | 107568/145393 [09:43<02:11, 287.60it/s]java.lang.ArrayIndexOutOfBoundsException
#  80%|███████▉  | 116154/145393 [10:32<01:35, 307.23it/s]java.lang.ArrayIndexOutOfBoundsException
#  82%|████████▏ | 119625/145393 [10:52<05:31, 77.74it/s] java.lang.ArrayIndexOutOfBoundsException
#  83%|████████▎ | 121189/145393 [11:00<01:19, 304.32it/s]java.lang.ArrayIndexOutOfBoundsException
#  84%|████████▍ | 122825/145393 [11:11<01:41, 223.18it/s]java.lang.ArrayIndexOutOfBoundsException
#  88%|████████▊ | 127794/145393 [11:39<01:16, 231.26it/s]java.lang.ArrayIndexOutOfBoundsException
#  96%|█████████▌| 139433/145393 [12:43<00:20, 293.60it/s]java.lang.ArrayIndexOutOfBoundsException
# 100%|██████████| 145393/145393 [13:16<00:00, 182.53it/s]
#  18%|█▊        | 8553/48852 [00:44<02:38, 254.70it/s]java.lang.ArrayIndexOutOfBoundsException
#  19%|█▊        | 9047/48852 [00:48<04:55, 134.80it/s]java.lang.ArrayIndexOutOfBoundsException
#  25%|██▍       | 12057/48852 [01:05<04:54, 125.13it/s]java.lang.ArrayIndexOutOfBoundsException
#  29%|██▉       | 14082/48852 [01:19<06:11, 93.70it/s] java.lang.ArrayIndexOutOfBoundsException
#  70%|██████▉   | 33967/48852 [03:12<02:22, 104.16it/s]java.lang.ArrayIndexOutOfBoundsException
#  72%|███████▏  | 35033/48852 [03:19<01:04, 213.36it/s]java.lang.ArrayIndexOutOfBoundsException
#  82%|████████▏ | 39956/48852 [03:47<00:25, 343.76it/s]java.lang.ArrayIndexOutOfBoundsException
#  95%|█████████▍| 46224/48852 [04:21<00:11, 219.94it/s]java.lang.ArrayIndexOutOfBoundsException
# 100%|██████████| 48852/48852 [04:36<00:00, 176.53it/s]

# %%
#kkma 토크나이저
#중간에 메모리부족 애러..
#https://developer111.tistory.com/34
from tqdm import tqdm
X_kkma_train = []
for sentence in tqdm(train_data['document']):
    tokenized_sentence = kkma.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_kkma_train.append(stopwords_removed_sentence)

X_kkma_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = kkma.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_kkma_test.append(stopwords_removed_sentence)
# Out:
#  27%|██▋       | 39648/145393 [31:17<1:23:27, 21.12it/s]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in kr.lucypark.kkma.KkmaInterface.morphAnalyzer()
#
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in org.snu.ids.ha.ma.MorphemeAnalyzer.analyze()
#
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in org.snu.ids.ha.ma.MorphemeAnalyzer.analyze()
#
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in java.lang.StringBuilder.append()
#
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in java.lang.String.valueOf()
#
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in org.snu.ids.ha.ma.MExpression.toString()
#
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in java.lang.StringBuffer.append()
#
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in java.lang.AbstractStringBuilder.append()
#
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in java.lang.AbstractStringBuilder.ensureCapacityInternal()
#
# /opt/conda/lib/python3.9/site-packages/_jpype.cpython-39-x86_64-linux-gnu.so in java.util.Arrays.copyOf()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.OutOfMemoryError                Traceback (most recent call last)
# /tmp/ipykernel_30/2432893484.py in <module>
#       3 X_kkma_train = []
#       4 for sentence in tqdm(train_data['document']):
# ----> 5     tokenized_sentence = kkma.morphs(sentence) # 토큰화
#       6     stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
#       7     X_kkma_train.append(stopwords_removed_sentence)
#
# /opt/conda/lib/python3.9/site-packages/konlpy/tag/_kkma.py in morphs(self, phrase)
#      82         """Parse phrase to morphemes."""
#      83
# ---> 84         return [s for s, t in self.pos(phrase)]
#      85
#      86     def sentences(self, phrase):
#
# /opt/conda/lib/python3.9/site-packages/konlpy/tag/_kkma.py in pos(self, phrase, flatten, join)
#      53         """
#      54
# ---> 55         sentences = self.jki.morphAnalyzer(phrase)
#      56         morphemes = []
#      57         if not sentences:
#
# java.lang.OutOfMemoryError: java.lang.OutOfMemoryError: Java heap space

# %%
#komoran 토크나이저
from tqdm import tqdm
X_komo_train = []
for sentence in tqdm(train_data['document']):
    tokenized_sentence = komo.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_komo_train.append(stopwords_removed_sentence)

X_komo_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = komo.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_komo_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 145393/145393 [02:41<00:00, 900.67it/s]
# 100%|██████████| 48852/48852 [00:56<00:00, 865.35it/s]

# %%
#Mecab 토크나이저
from tqdm import tqdm
X_mec_train = []
for sentence in tqdm(train_data['document']):
    tokenized_sentence = mec.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_mec_train.append(stopwords_removed_sentence)

X_mec_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = mec.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_mec_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 145393/145393 [00:14<00:00, 10221.43it/s]
# 100%|██████████| 48852/48852 [00:04<00:00, 10277.36it/s]

# %%
print(X_okt_train[0])
print(X_han_train[0])
print(X_komo_train[0])
print(X_mec_train[0])
# Out:
# ['아', '더빙', '진짜', '짜증나다', '목소리']
# ['아', '더빙', '진짜', '짜증나', '네', '요', '목소리']
# ['아', '더빙', '진짜', '짜증', '나', '네요', '목소리']
# ['아', '더', '빙', '진짜', '짜증', '나', '네요', '목소리']

# %%
import copy
X_sp_train_copy = copy.deepcopy(X_sp_train)
X_okt_train_copy = copy.deepcopy(X_okt_train)
X_han_train_copy = copy.deepcopy(X_han_train)
X_komo_train_copy = copy.deepcopy(X_komo_train)
X_mec_train_copy = copy.deepcopy(X_mec_train)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_okt_train)

# %%
tokenizer_okt = Tokenizer()
tokenizer_han = Tokenizer()
tokenizer_komo = Tokenizer()
tokenizer_mec = Tokenizer()
tokenizer_okt.fit_on_texts(X_okt_train)
tokenizer_han.fit_on_texts(X_han_train)
tokenizer_komo.fit_on_texts(X_komo_train)
tokenizer_mec.fit_on_texts(X_mec_train)

# %%
print('sp word index : '+str(len(tokenizer_sp.word_index)))
print('okt word index : '+str(len(tokenizer_okt.word_index)))
print('hannanum word index : '+str(len(tokenizer_han.word_index)))
print('komoran word index : '+str(len(tokenizer_komo.word_index)))
print('mecab word index : '+str(len(tokenizer_mec.word_index)))
# Out:
# sp word index : 8990
# okt word index : 43752
# hannanum word index : 178333
# komoran word index : 54414
# mecab word index : 49946

# %% [markdown]
# ### 본 실험에서는 Sentence peice와의 비교를 위하여 vocab_size를 8000으로 고정하고자 함

# %%
vocab_size = 8000 + 1 

X_sp_train = tokenizer_sp.texts_to_sequences(X_sp_train)
X_sp_test = tokenizer_sp.texts_to_sequences(X_sp_test)

X_okt_train = tokenizer_okt.texts_to_sequences(X_okt_train)
X_okt_test = tokenizer_okt.texts_to_sequences(X_okt_test)

X_han_train = tokenizer_han.texts_to_sequences(X_han_train)
X_han_test = tokenizer_han.texts_to_sequences(X_han_test)

X_komo_train = tokenizer_komo.texts_to_sequences(X_komo_train)
X_komo_test = tokenizer_komo.texts_to_sequences(X_komo_test)

X_mec_train = tokenizer_mec.texts_to_sequences(X_mec_train)
X_mec_test = tokenizer_mec.texts_to_sequences(X_mec_test)

# %%
X_mec_train[0]
X_sp_train[2]
# Out:
# [30, 106, 4944, 331, 88, 174, 20, 27, 69, 6, 325, 746, 446]

# %%
y_sp_train = np.array(train_data['label'])
y_okt_train = np.array(train_data['label'])
y_han_train = np.array(train_data['label'])
y_komo_train = np.array(train_data['label'])
y_mec_train = np.array(train_data['label'])

y_sp_test = np.array(test_data['label'])
y_okt_test = np.array(test_data['label'])
y_han_test = np.array(test_data['label'])
y_komo_test = np.array(test_data['label'])
y_mec_test = np.array(test_data['label'])

# %%
#빈 샘플 확인
drop_sp_train = [index for index, sentence in enumerate(X_sp_train) if len(sentence) < 1]
drop_okt_train = [index for index, sentence in enumerate(X_okt_train) if len(sentence) < 1]
drop_han_train = [index for index, sentence in enumerate(X_han_train) if len(sentence) < 1]
drop_komo_train = [index for index, sentence in enumerate(X_komo_train) if len(sentence) < 1]
drop_mec_train = [index for index, sentence in enumerate(X_mec_train) if len(sentence) < 1]
print(len(drop_sp_train))
print(len(drop_okt_train))
print(len(drop_han_train))
print(len(drop_komo_train))
print(len(drop_mec_train))
# Out:
# 0
# 13
# 38
# 7
# 13

# %%
# 빈 샘플들을 제거
X_sp_train = np.delete(X_sp_train, drop_sp_train, axis=0)
X_okt_train = np.delete(X_okt_train, drop_okt_train, axis=0)
X_han_train = np.delete(X_han_train, drop_han_train, axis=0)
X_komo_train = np.delete(X_komo_train, drop_komo_train, axis=0)
X_mec_train = np.delete(X_mec_train, drop_mec_train, axis=0)

y_sp_train = np.delete(y_sp_train, drop_sp_train, axis=0)
y_okt_train = np.delete(y_sp_train, drop_okt_train, axis=0)
y_han_train = np.delete(y_sp_train, drop_han_train, axis=0)
y_komo_train = np.delete(y_sp_train, drop_komo_train, axis=0)
y_mec_train = np.delete(y_sp_train, drop_mec_train, axis=0)

# %% [markdown]
# ### 문장 내 단어의 최대길이 설정
# - 금번 비교는 형태소분석기의 성능 비교를 위한 실험으로 추출된 문장 길이들이 잘리지 않는 기준으로 설정
# - 각 도출된 결과값의 최대 길이로 설정함

# %%
#padding
import matplotlib.pyplot as plt

def plt_data(name,data):
    print('리뷰의 최대 길이 :',max(len(review) for review in data))
    print('리뷰의 평균 길이 :',sum(map(len, X_sp_train))/len(data))
    plt.hist([len(review) for review in X_sp_train], bins=50)
    plt.xlabel('length of samples')
    plt.ylabel('number of samples')
    plt.title('{0}'.format(name))
    plt.show()

print(plt_data('sentence piece',X_sp_train))
print(plt_data('okt',X_okt_train))
print(plt_data('hannamum',X_han_train))
print(plt_data('komoran',X_komo_train))
print(plt_data('mecab',X_mec_train))
# Out:
# 리뷰의 최대 길이 : 116
# 리뷰의 평균 길이 : 18.636873852248733
# None
# 리뷰의 최대 길이 : 72
# 리뷰의 평균 길이 : 18.638540376943183
# None
# 리뷰의 최대 길이 : 72
# 리뷰의 평균 길이 : 18.641746069966633
# None
# 리뷰의 최대 길이 : 104
# 리뷰의 평균 길이 : 18.63777117466606
# None
# 리뷰의 최대 길이 : 83
# 리뷰의 평균 길이 : 18.638540376943183
# None

# %%
X_sp_train = pad_sequences(X_sp_train, maxlen=116)
X_okt_train = pad_sequences(X_okt_train, maxlen=72)
X_han_train = pad_sequences(X_han_train, maxlen=72)
X_komo_train = pad_sequences(X_komo_train, maxlen=104)
X_mec_train = pad_sequences(X_mec_train, maxlen=84)


X_sp_test = pad_sequences(X_sp_test, maxlen=116)
X_okt_test = pad_sequences(X_okt_test, maxlen=72)
X_han_test = pad_sequences(X_han_test, maxlen=72)
X_komo_test = pad_sequences(X_komo_test, maxlen=104)
X_mec_test = pad_sequences(X_mec_test, maxlen=84)

# %%
print(plt_data('sentence piece',X_sp_train))
print(plt_data('okt',X_okt_train))
print(plt_data('hannamum',X_han_train))
print(plt_data('komoran',X_komo_train))
print(plt_data('mecab',X_mec_train))
# Out:
# 리뷰의 최대 길이 : 116
# 리뷰의 평균 길이 : 116.0
# None
# 리뷰의 최대 길이 : 72
# 리뷰의 평균 길이 : 116.01037281606824
# None
# 리뷰의 최대 길이 : 72
# 리뷰의 평균 길이 : 116.03032575418803
# None
# 리뷰의 최대 길이 : 104
# 리뷰의 평균 길이 : 116.00558513199346
# None
# 리뷰의 최대 길이 : 84
# 리뷰의 평균 길이 : 116.01037281606824
# None

# %% [markdown]
# # 3. 모델 학습

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

embedding_dim = 100
hidden_units = 128

model_sp = Sequential()
model_sp.add(Embedding(vocab_size, embedding_dim))
model_sp.add(LSTM(hidden_units))
model_sp.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_sp_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model_sp.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history_sp = model_sp.fit(X_sp_train, y_sp_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 1818/1818 [==============================] - 31s 12ms/step - loss: 0.4233 - acc: 0.8042 - val_loss: 0.3772 - val_acc: 0.8313
#
# Epoch 00001: val_acc improved from -inf to 0.83132, saving model to best_sp_model.h5
# Epoch 2/15
# 1818/1818 [==============================] - 17s 10ms/step - loss: 0.3620 - acc: 0.8384 - val_loss: 0.3654 - val_acc: 0.8369
#
# Epoch 00002: val_acc improved from 0.83132 to 0.83686, saving model to best_sp_model.h5
# Epoch 3/15
# 1818/1818 [==============================] - 16s 9ms/step - loss: 0.3384 - acc: 0.8513 - val_loss: 0.3509 - val_acc: 0.8428
#
# Epoch 00003: val_acc improved from 0.83686 to 0.84277, saving model to best_sp_model.h5
# Epoch 4/15
# 1818/1818 [==============================] - 16s 9ms/step - loss: 0.3211 - acc: 0.8603 - val_loss: 0.3604 - val_acc: 0.8420
#
# Epoch 00004: val_acc did not improve from 0.84277
# Epoch 5/15
# 1818/1818 [==============================] - 16s 9ms/step - loss: 0.3068 - acc: 0.8681 - val_loss: 0.3409 - val_acc: 0.8498
#
# Epoch 00005: val_acc improved from 0.84277 to 0.84982, saving model to best_sp_model.h5
# Epoch 6/15
# 1818/1818 [==============================] - 16s 9ms/step - loss: 0.2933 - acc: 0.8755 - val_loss: 0.3426 - val_acc: 0.8454
#
# Epoch 00006: val_acc did not improve from 0.84982
# Epoch 7/15
# 1818/1818 [==============================] - 16s 9ms/step - loss: 0.2795 - acc: 0.8828 - val_loss: 0.3415 - val_acc: 0.8524
#
# Epoch 00007: val_acc improved from 0.84982 to 0.85237, saving model to best_sp_model.h5
# Epoch 8/15
# 1818/1818 [==============================] - 16s 9ms/step - loss: 0.2648 - acc: 0.8907 - val_loss: 0.3496 - val_acc: 0.8505
#
# Epoch 00008: val_acc did not improve from 0.85237
# Epoch 9/15
# 1818/1818 [==============================] - 16s 9ms/step - loss: 0.2496 - acc: 0.8977 - val_loss: 0.3587 - val_acc: 0.8485
#
# Epoch 00009: val_acc did not improve from 0.85237
# Epoch 00009: early stopping

# %%
embedding_dim = 100
hidden_units = 128

model_okt = Sequential()
model_okt.add(Embedding(vocab_size, embedding_dim))
model_okt.add(LSTM(hidden_units))
model_okt.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_okt_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model_okt.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history_okt = model_okt.fit(X_okt_train, y_okt_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 1818/1818 [==============================] - 15s 7ms/step - loss: 0.3940 - acc: 0.8225 - val_loss: 0.3647 - val_acc: 0.8392
#
# Epoch 00001: val_acc improved from -inf to 0.83918, saving model to best_okt_model.h5
# Epoch 2/15
# 1818/1818 [==============================] - 13s 7ms/step - loss: 0.3329 - acc: 0.8543 - val_loss: 0.3396 - val_acc: 0.8519
#
# Epoch 00002: val_acc improved from 0.83918 to 0.85194, saving model to best_okt_model.h5
# Epoch 3/15
# 1818/1818 [==============================] - 13s 7ms/step - loss: 0.3117 - acc: 0.8656 - val_loss: 0.3284 - val_acc: 0.8569
#
# Epoch 00003: val_acc improved from 0.85194 to 0.85689, saving model to best_okt_model.h5
# Epoch 4/15
# 1818/1818 [==============================] - 13s 7ms/step - loss: 0.2978 - acc: 0.8724 - val_loss: 0.3254 - val_acc: 0.8578
#
# Epoch 00004: val_acc improved from 0.85689 to 0.85775, saving model to best_okt_model.h5
# Epoch 5/15
# 1818/1818 [==============================] - 13s 7ms/step - loss: 0.2859 - acc: 0.8791 - val_loss: 0.3321 - val_acc: 0.8578
#
# Epoch 00005: val_acc did not improve from 0.85775
# Epoch 6/15
# 1818/1818 [==============================] - 13s 7ms/step - loss: 0.2747 - acc: 0.8845 - val_loss: 0.3378 - val_acc: 0.8565
#
# Epoch 00006: val_acc did not improve from 0.85775
# Epoch 7/15
# 1818/1818 [==============================] - 13s 7ms/step - loss: 0.2639 - acc: 0.8904 - val_loss: 0.3326 - val_acc: 0.8581
#
# Epoch 00007: val_acc improved from 0.85775 to 0.85806, saving model to best_okt_model.h5
# Epoch 8/15
# 1818/1818 [==============================] - 13s 7ms/step - loss: 0.2528 - acc: 0.8948 - val_loss: 0.3379 - val_acc: 0.8571
#
# Epoch 00008: val_acc did not improve from 0.85806
# Epoch 00008: early stopping

# %%
embedding_dim = 100
hidden_units = 128

model_han = Sequential()
model_han.add(Embedding(vocab_size, embedding_dim))
model_han.add(LSTM(hidden_units))
model_han.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_han_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model_han.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history_han = model_han.fit(X_han_train, y_han_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 1817/1817 [==============================] - 15s 7ms/step - loss: 0.4577 - acc: 0.7750 - val_loss: 0.4240 - val_acc: 0.7965
#
# Epoch 00001: val_acc improved from -inf to 0.79653, saving model to best_han_model.h5
# Epoch 2/15
# 1817/1817 [==============================] - 13s 7ms/step - loss: 0.3975 - acc: 0.8125 - val_loss: 0.4009 - val_acc: 0.8075
#
# Epoch 00002: val_acc improved from 0.79653 to 0.80751, saving model to best_han_model.h5
# Epoch 3/15
# 1817/1817 [==============================] - 13s 7ms/step - loss: 0.3765 - acc: 0.8245 - val_loss: 0.3919 - val_acc: 0.8146
#
# Epoch 00003: val_acc improved from 0.80751 to 0.81463, saving model to best_han_model.h5
# Epoch 4/15
# 1817/1817 [==============================] - 13s 7ms/step - loss: 0.3626 - acc: 0.8312 - val_loss: 0.3876 - val_acc: 0.8161
#
# Epoch 00004: val_acc improved from 0.81463 to 0.81607, saving model to best_han_model.h5
# Epoch 5/15
# 1817/1817 [==============================] - 13s 7ms/step - loss: 0.3512 - acc: 0.8378 - val_loss: 0.3853 - val_acc: 0.8174
#
# Epoch 00005: val_acc improved from 0.81607 to 0.81738, saving model to best_han_model.h5
# Epoch 6/15
# 1817/1817 [==============================] - 13s 7ms/step - loss: 0.3409 - acc: 0.8432 - val_loss: 0.3880 - val_acc: 0.8167
#
# Epoch 00006: val_acc did not improve from 0.81738
# Epoch 7/15
# 1817/1817 [==============================] - 13s 7ms/step - loss: 0.3315 - acc: 0.8484 - val_loss: 0.3912 - val_acc: 0.8148
#
# Epoch 00007: val_acc did not improve from 0.81738
# Epoch 8/15
# 1817/1817 [==============================] - 13s 7ms/step - loss: 0.3220 - acc: 0.8528 - val_loss: 0.3891 - val_acc: 0.8160
#
# Epoch 00008: val_acc did not improve from 0.81738
# Epoch 9/15
# 1817/1817 [==============================] - 13s 7ms/step - loss: 0.3121 - acc: 0.8573 - val_loss: 0.3932 - val_acc: 0.8144
#
# Epoch 00009: val_acc did not improve from 0.81738
# Epoch 00009: early stopping

# %%
embedding_dim = 100
hidden_units = 128

model_komo = Sequential()
model_komo.add(Embedding(vocab_size, embedding_dim))
model_komo.add(LSTM(hidden_units))
model_komo.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_komo_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model_komo.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history_komo = model_komo.fit(X_komo_train, y_komo_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 1818/1818 [==============================] - 19s 10ms/step - loss: 0.4082 - acc: 0.8119 - val_loss: 0.3919 - val_acc: 0.8209
#
# Epoch 00001: val_acc improved from -inf to 0.82093, saving model to best_komo_model.h5
# Epoch 2/15
# 1818/1818 [==============================] - 15s 8ms/step - loss: 0.3463 - acc: 0.8463 - val_loss: 0.3448 - val_acc: 0.8472
#
# Epoch 00002: val_acc improved from 0.82093 to 0.84717, saving model to best_komo_model.h5
# Epoch 3/15
# 1818/1818 [==============================] - 15s 8ms/step - loss: 0.3227 - acc: 0.8582 - val_loss: 0.3442 - val_acc: 0.8460
#
# Epoch 00003: val_acc did not improve from 0.84717
# Epoch 4/15
# 1818/1818 [==============================] - 15s 8ms/step - loss: 0.3061 - acc: 0.8679 - val_loss: 0.3300 - val_acc: 0.8527
#
# Epoch 00004: val_acc improved from 0.84717 to 0.85267, saving model to best_komo_model.h5
# Epoch 5/15
# 1818/1818 [==============================] - 15s 8ms/step - loss: 0.2928 - acc: 0.8749 - val_loss: 0.3333 - val_acc: 0.8559
#
# Epoch 00005: val_acc improved from 0.85267 to 0.85587, saving model to best_komo_model.h5
# Epoch 6/15
# 1818/1818 [==============================] - 15s 8ms/step - loss: 0.2807 - acc: 0.8811 - val_loss: 0.3394 - val_acc: 0.8549
#
# Epoch 00006: val_acc did not improve from 0.85587
# Epoch 7/15
# 1818/1818 [==============================] - 15s 8ms/step - loss: 0.2699 - acc: 0.8860 - val_loss: 0.3337 - val_acc: 0.8549
#
# Epoch 00007: val_acc did not improve from 0.85587
# Epoch 8/15
# 1818/1818 [==============================] - 15s 8ms/step - loss: 0.2582 - acc: 0.8924 - val_loss: 0.3532 - val_acc: 0.8455
#
# Epoch 00008: val_acc did not improve from 0.85587
# Epoch 00008: early stopping

# %%
embedding_dim = 100
hidden_units = 128

model_mec = Sequential()
model_mec.add(Embedding(vocab_size, embedding_dim))
model_mec.add(LSTM(hidden_units))
model_mec.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_mec_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

model_mec.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history_mec = model_mec.fit(X_mec_train, y_mec_train, epochs=15, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/15
# 1818/1818 [==============================] - 18s 9ms/step - loss: 0.3934 - acc: 0.8215 - val_loss: 0.3648 - val_acc: 0.8433
#
# Epoch 00001: val_acc improved from -inf to 0.84327, saving model to best_mec_model.h5
# Epoch 2/15
# 1818/1818 [==============================] - 14s 8ms/step - loss: 0.3280 - acc: 0.8563 - val_loss: 0.3256 - val_acc: 0.8578
#
# Epoch 00002: val_acc improved from 0.84327 to 0.85779, saving model to best_mec_model.h5
# Epoch 3/15
# 1818/1818 [==============================] - 14s 8ms/step - loss: 0.3044 - acc: 0.8692 - val_loss: 0.3175 - val_acc: 0.8616
#
# Epoch 00003: val_acc improved from 0.85779 to 0.86157, saving model to best_mec_model.h5
# Epoch 4/15
# 1818/1818 [==============================] - 14s 8ms/step - loss: 0.2876 - acc: 0.8776 - val_loss: 0.3160 - val_acc: 0.8647
#
# Epoch 00004: val_acc improved from 0.86157 to 0.86473, saving model to best_mec_model.h5
# Epoch 5/15
# 1818/1818 [==============================] - 14s 8ms/step - loss: 0.2753 - acc: 0.8844 - val_loss: 0.3163 - val_acc: 0.8651
#
# Epoch 00005: val_acc improved from 0.86473 to 0.86508, saving model to best_mec_model.h5
# Epoch 6/15
# 1818/1818 [==============================] - 14s 8ms/step - loss: 0.2641 - acc: 0.8903 - val_loss: 0.3195 - val_acc: 0.8626
#
# Epoch 00006: val_acc did not improve from 0.86508
# Epoch 7/15
# 1818/1818 [==============================] - 14s 8ms/step - loss: 0.2538 - acc: 0.8956 - val_loss: 0.3190 - val_acc: 0.8623
#
# Epoch 00007: val_acc did not improve from 0.86508
# Epoch 8/15
# 1818/1818 [==============================] - 14s 8ms/step - loss: 0.2425 - acc: 0.9009 - val_loss: 0.3177 - val_acc: 0.8634
#
# Epoch 00008: val_acc did not improve from 0.86508
# Epoch 00008: early stopping

# %% [markdown]
# # 4. 결과 확인 및 회고
# - 성능자체는 mecab의 성능이 가장 높게 나온것을 확인했다.
# - 토큰화 과정간의 처리 속도는 sentence piece(4sec) >  mecab(14sec) > komoran(2m 41sec) > okt(11m 58sec)> hannamum(13m 16sec) > kkoma(메모리 에러로 인한 학습불가) 순으로 차이가 있음
# - 각각의 토큰화 방법에 따라 결과값이 다르게 평가되는 것을 확인하였지만 sentence piece의 장점을 확인하긴 어려웠음.
# - 추가 진행으로 vocab size를 변경하여 추가 학습을 진행하고자 함

# %%
loaded_sp_model = load_model('best_sp_model.h5')
loaded_okt_model = load_model('best_okt_model.h5')
loaded_han_model = load_model('best_han_model.h5')
loaded_komo_model = load_model('best_komo_model.h5')
loaded_mec_model = load_model('best_mec_model.h5')

print("\n sp 테스트 정확도: %.4f" % (loaded_sp_model.evaluate(X_sp_test, y_sp_test)[1]))
print("\n okt 테스트 정확도: %.4f" % (loaded_okt_model.evaluate(X_okt_test, y_okt_test)[1]))
print("\n han 테스트 정확도: %.4f" % (loaded_han_model.evaluate(X_han_test, y_han_test)[1]))
print("\n komo 테스트 정확도: %.4f" % (loaded_komo_model.evaluate(X_komo_test, y_komo_test)[1]))
print("\n mec 테스트 정확도: %.4f" % (loaded_mec_model.evaluate(X_mec_test, y_mec_test)[1]))
# Out:
# 1527/1527 [==============================] - 6s 4ms/step - loss: 0.3444 - acc: 0.8487
#
#  sp 테스트 정확도: 0.8487
# 1527/1527 [==============================] - 5s 3ms/step - loss: 0.3413 - acc: 0.8560
#
#  okt 테스트 정확도: 0.8560
# 1527/1527 [==============================] - 5s 3ms/step - loss: 0.3914 - acc: 0.8167
#
#  han 테스트 정확도: 0.8167
# 1527/1527 [==============================] - 5s 3ms/step - loss: 0.3370 - acc: 0.8535
#
#  komo 테스트 정확도: 0.8535
# 1527/1527 [==============================] - 5s 3ms/step - loss: 0.3212 - acc: 0.8625
#
#  mec 테스트 정확도: 0.8625
